# %% [markdown]
# # Divergence Analysis
#
# ## First look at the Data

# %%
import json
#import numpy as np
#import pandas as pd
#from tqdm import tqdm
#import os
#import statistics
from collections import OrderedDict

# %%
amer_directory = '../Ngrams/amer_unigram_data/'
brit_directory = '../Ngrams/brit_unigram_data/'

def open_json(directory,file_path):
    with open(directory+file_path,'r') as f:
        json_dictionary = json.load(f)
        f.close()
    return json_dictionary

# %% [markdown]
# 1801-1850 Set Analysis

# %%
BRIT_1801_1850_STEP1 = open_json(brit_directory,'LEXICON_1801-1850_STEP1.json')
AMER_1801_1850_STEP1 = open_json(amer_directory,'LEXICON_1801-1850_STEP1.json')

brit_1801_1850_s1 = set(BRIT_1801_1850_STEP1.keys())
amer_1801_1850_s1 = set(AMER_1801_1850_STEP1.keys())

intersection_1801_1850 = brit_1801_1850_s1.intersection(amer_1801_1850_s1)
amer_unique_1801_1850_s1 = amer_1801_1850_s1.difference(intersection_1801_1850)
brit_unique_1801_1850_s1 = brit_1801_1850_s1.difference(intersection_1801_1850)

# %%
len(brit_1801_1850_s1),len(intersection_1801_1850),len(amer_1801_1850_s1)
# Out:
# (106474, 37196, 37694)

# %%
len(amer_unique_1801_1850_s1),len(brit_unique_1801_1850_s1)
# Out:
# (498, 69278)

# %%
#amer_unique_1801_1850_s1

# %%
#brit_unique_1801_1850_s1

# %% [markdown]
# 1851-1900 Set Analysis

# %%
BRIT_1851_1900_STEP1 = open_json(brit_directory,'LEXICON_1851-1900_STEP1.json')
AMER_1851_1900_STEP1 = open_json(amer_directory,'LEXICON_1851-1900_STEP1.json')

brit_1851_1900_s1 = set(BRIT_1851_1900_STEP1.keys())
amer_1851_1900_s1 = set(AMER_1851_1900_STEP1.keys())

intersection_1851_1900 = brit_1851_1900_s1.intersection(amer_1851_1900_s1)
amer_unique_1851_1900_s1 = amer_1851_1900_s1.difference(intersection_1851_1900)
brit_unique_1851_1900_s1 = brit_1851_1900_s1.difference(intersection_1851_1900)

# %%
len(brit_1851_1900_s1),len(intersection_1851_1900),len(amer_1851_1900_s1)
# Out:
# (244666, 183790, 230103)

# %%
len(amer_unique_1851_1900_s1),len(brit_unique_1851_1900_s1)
# Out:
# (46313, 60876)

# %% [markdown]
# 1901-1950 Set Analysis

# %%
BRIT_1901_1950_STEP1 = open_json(brit_directory,'LEXICON_1901-1950_STEP1.json')
AMER_1901_1950_STEP1 = open_json(amer_directory,'LEXICON_1901-1950_STEP1.json')

brit_1901_1950_s1 = set(BRIT_1901_1950_STEP1.keys())
amer_1901_1950_s1 = set(AMER_1901_1950_STEP1.keys())

intersection_1901_1950 = brit_1901_1950_s1.intersection(amer_1901_1950_s1)
amer_unique_1901_1950_s1 = amer_1901_1950_s1.difference(intersection_1901_1950)
brit_unique_1901_1950_s1 = brit_1901_1950_s1.difference(intersection_1901_1950)

# %%
len(brit_1901_1950_s1),len(intersection_1901_1950),len(amer_1901_1950_s1)
# Out:
# (174324, 164436, 451000)

# %%
len(amer_unique_1901_1950_s1),len(brit_unique_1901_1950_s1)
# Out:
# (286564, 9888)

# %%
#amer_unique_1901_1950_s1

# %%
#brit_unique_1901_1950_s1

# %% [markdown]
# 1951-2000 Set Analysis

# %%
BRIT_1951_2000_STEP1 = open_json(brit_directory,'LEXICON_1951-2000_STEP1.json')
AMER_1951_2000_STEP1 = open_json(amer_directory,'LEXICON_1951-2000_STEP1.json')

brit_1951_2000_s1 = set(BRIT_1951_2000_STEP1.keys())
amer_1951_2000_s1 = set(AMER_1951_2000_STEP1.keys())

intersection_1951_2000 = brit_1951_2000_s1.intersection(amer_1951_2000_s1)
amer_unique_1951_2000_s1 = amer_1951_2000_s1.difference(intersection_1951_2000)
brit_unique_1951_2000_s1 = brit_1951_2000_s1.difference(intersection_1951_2000)

# %%
len(brit_1951_2000_s1),len(intersection_1951_2000),len(amer_1951_2000_s1)
# Out:
# (281984, 268910, 777075)

# %%
len(amer_unique_1951_2000_s1),len(brit_unique_1951_2000_s1)
# Out:
# (508165, 13074)

# %%
#amer_unique_1951_2000_s1

# %%
#brit_unique_1951_2000_s1

# %% [markdown]
# All of the unique words

# %%
amer_unique = amer_unique_1951_2000_s1.intersection(amer_unique_1901_1950_s1,amer_unique_1851_1900_s1,amer_unique_1801_1850_s1)

# %%
brit_unique = brit_unique_1951_2000_s1.intersection(brit_unique_1901_1950_s1,brit_unique_1851_1900_s1,brit_unique_1801_1850_s1)

# %%
len(amer_unique),len(brit_unique)
# Out:
# (72, 147)

# %%
amer_unique
# Out:
# {'abeel_NOUN',
#  'agawam_NOUN',
#  'agreea_NOUN',
#  'alatamaha_NOUN',
#  'amendatory_ADJ',
#  'amendatory_NOUN',
#  'bioren_NOUN',
#  'boudinot_NOUN',
#  'chenango_NOUN',
#  'chilicothe_NOUN',
#  'deposeth_NOUN',
#  'dutchess_ADJ',
#  'edenton_NOUN',
#  'ferriage_NOUN',
#  'governeur_NOUN',
#  'gpd_NOUN',
#  'harrisburgh_NOUN',
#  'haverstraw_NOUN',
#  'hopkinton_NOUN',
#  'hunterdon_NOUN',
#  'inhab_ADJ',
#  'kaskaskias_NOUN',
#  'kennebeck_NOUN',
#  'kennebunk_NOUN',
#  'ladelphia_NOUN',
#  'lansingburgh_NOUN',
#  'lewistown_NOUN',
#  'lumbia_NOUN',
#  'machias_NOUN',
#  'massac_NOUN',
#  'medfield_NOUN',
#  'mohegan_NOUN',
#  'natches_NOUN',
#  'necticut_NOUN',
#  'newhampshire_NOUN',
#  'newjersey_NOUN',
#  'newlondon_NOUN',
#  'neworleans_NOUN',
#  'northamerica_NOUN',
#  'northcarolina_NOUN',
#  'oconee_NOUN',
#  'olence_NOUN',
#  'onondago_NOUN',
#  'pascalis_NOUN',
#  'pittstown_NOUN',
#  'puking_NOUN',
#  'purviance_NOUN',
#  'rhodeisland_NOUN',
#  'rockbridge_NOUN',
#  'rolina_NOUN',
#  'sachusetts_NOUN',
#  'saluda_NOUN',
#  'schoharie_NOUN',
#  'segars_NOUN',
#  'shajl_VERB',
#  'shawanese_NOUN',
#  'simsbury_NOUN',
#  'sollowing_VERB',
#  'southcarolina_NOUN',
#  'stoddert_NOUN',
#  'stratham_NOUN',
#  'surther_VERB',
#  'swartwout_NOUN',
#  'tennesse_NOUN',
#  'ticut_NOUN',
#  'truxton_NOUN',
#  'varnum_NOUN',
#  'warrantee_NOUN',
#  'weathersfield_NOUN',
#  'whitestown_NOUN',
#  'yadkin_NOUN',
#  'yea_NUM'}

# %%
brit_unique
# Out:
# {'aberlady_NOUN',
#  'accompte_NOUN',
#  'addingham_NOUN',
#  'alphage_NOUN',
#  'annuatim_X',
#  'aprilis_X',
#  'aucht_NOUN',
#  'avourable_ADJ',
#  'bassishaw_NOUN',
#  'bathwick_NOUN',
#  'befoir_ADP',
#  'begyn_VERB',
#  'benefice_ADP',
#  'boxhill_NOUN',
#  'burgi_X',
#  'bwlch_NOUN',
#  'cambuskenneth_NOUN',
#  'campvere_NOUN',
#  'cawsand_NOUN',
#  'cerrig_NOUN',
#  'chalder_NOUN',
#  'chapelries_NOUN',
#  'clipstone_NOUN',
#  'coldham_NOUN',
#  'colourmen_NOUN',
#  'contynue_VERB',
#  'courtown_NOUN',
#  'croftes_NOUN',
#  'dalswinton_NOUN',
#  'dapifer_NOUN',
#  'decern_VERB',
#  'drummore_NOUN',
#  'dunging_NOUN',
#  'dunstanville_NOUN',
#  'easingwold_NOUN',
#  'edwardi_X',
#  'eglwys_NOUN',
#  'exciseable_ADJ',
#  'favourites_VERB',
#  'feuars_NOUN',
#  'feued_VERB',
#  'fiars_NOUN',
#  'flixton_NOUN',
#  'fornham_NOUN',
#  'fourtie_NUM',
#  'galfrid_NOUN',
#  'glatton_NOUN',
#  'gwennap_NOUN',
#  'haughs_NOUN',
#  'hawise_NOUN',
#  'highworth_NOUN',
#  'hildersham_NOUN',
#  'hilsea_NOUN',
#  'hitcham_NOUN',
#  'holbourne_NOUN',
#  'humberston_NOUN',
#  'humbie_NOUN',
#  'iabour_NOUN',
#  'infeft_VERB',
#  'infeftment_NOUN',
#  'inspeximus_NOUN',
#  'kennoway_NOUN',
#  'kilmaine_NOUN',
#  'kinfauns_NOUN',
#  'kircudbright_NOUN',
#  'kirkmichael_NOUN',
#  'lanthony_NOUN',
#  'lexden_NOUN',
#  'llandilo_NOUN',
#  'madocks_NOUN',
#  'mapletoft_NOUN',
#  'measham_NOUN',
#  'meigle_NOUN',
#  'merks_VERB',
#  'methwold_NOUN',
#  'micklegate_NOUN',
#  'modbury_NOUN',
#  'monopolising_NOUN',
#  'mornynge_NOUN',
#  'multure_NOUN',
#  'murdac_NOUN',
#  'nelthorpe_NOUN',
#  'nemorum_NOUN',
#  'netherbow_NOUN',
#  'newbottle_NOUN',
#  'newenden_NOUN',
#  'northwold_NOUN',
#  'ochtertyre_NOUN',
#  'ombersley_NOUN',
#  'oxendon_NOUN',
#  'pairt_VERB',
#  'parliamentum_NOUN',
#  'paroch_NOUN',
#  'patrington_NOUN',
#  'pechell_NOUN',
#  'pemb_NOUN',
#  'pencaitland_NOUN',
#  'penmaen_NOUN',
#  'pittenweem_NOUN',
#  'portioner_NOUN',
#  'portioners_NOUN',
#  'portsoy_NOUN',
#  'prebendal_NOUN',
#  'presentlie_NOUN',
#  'presteign_NOUN',
#  'protulit_X',
#  'provyde_VERB',
#  'quhen_ADV',
#  'quhen_X',
#  'quhilk_VERB',
#  'repayred_VERB',
#  'ridware_NOUN',
#  'righthon_NOUN',
#  'sedgmoor_NOUN',
#  'shacklewell_NOUN',
#  'soche_ADJ',
#  'southover_NOUN',
#  'speciallie_NOUN',
#  'spithead_VERB',
#  'splendour_ADV',
#  'stretham_NOUN',
#  'teinds_NOUN',
#  'thame_PRON',
#  'thame_VERB',
#  'thatcham_NOUN',
#  'thornham_NOUN',
#  'thornhaugh_NOUN',
#  'thyngs_NOUN',
#  'tillicoultry_NOUN',
#  'tinwald_NOUN',
#  'tokenhouse_NOUN',
#  'traeth_NOUN',
#  'ulbster_NOUN',
#  'unfavour_ADJ',
#  'uponthames_NOUN',
#  'upontweed_NOUN',
#  'upwell_NOUN',
#  'warblington_NOUN',
#  'warnford_NOUN',
#  'whittlebury_NOUN',
#  'widmore_NOUN',
#  'wilsden_NOUN',
#  'winchelsey_NOUN',
#  'wingerworth_NOUN',
#  'wolsingham_NOUN',
#  'woodchurch_NOUN',
#  'woolled_VERB'}

# %% [markdown]
# ## Analysis of Divergence
# As the datasets are extremely imbalanced in terms of size, we will only investigate the differences between the 1851-1900 sets as they are the most closely balanced.
#
# We will
# 1. calculate Jaccard similarity index
# 2. calculate Wright's Fixation Index (a measure of how different the alleles in each population are)
# 3. plot the Zipfian distribution of both of these sets
# 4. take a qualitative look into the similarities and differences between the British and American English words.

# %% [markdown]
# ### 1. Jaccard Similarity Index

# %%
jaccard = len(intersection_1851_1900)/len(brit_1851_1900_s1.union(amer_1851_1900_s1))
print('The Jaccard similarity of the British and American lexicons in 1851-1900 is', "{:.2f}".format(jaccard*100),'%')
# Out:
# The Jaccard similarity of the British and American lexicons in 1851-1900 is 63.16 %

# %% [markdown]
# ### 2. Wright's Fixation Index $F_{ST}$
#
# Wright's Fixation Index is a measure of how different the alleles in each population are.
#
# $$F_{ST} = \frac{H_T-H_S}{H_T}$$
#
# Where heterozygosity $H$ is measured as
# $$1-\sum(f^2)$$
#
# $H_T$ is the heterozygosity of the entire population. $H_S$ is the weighted heterozygosity of each individual population

# %% [markdown]
# ### Pairwise Frequency-Dependent Similarity
#
# $$1-\sum(f_1-f_2)^2$$

# %%
sqd_diff = sum([(BRIT_1851_1900_STEP1[word]['frequency']-AMER_1851_1900_STEP1[word]['frequency'])**2 for word in intersection_1851_1900])
#These two would be subtracting by zero frequency from other set
sqd_diff += sum((BRIT_1851_1900_STEP1[word]['frequency'])**2 for word in brit_unique_1851_1900_s1)
sqd_diff += sum((AMER_1851_1900_STEP1[word]['frequency'])**2 for word in amer_unique_1851_1900_s1)
print(1-sqd_diff)
# Out:
# 0.9998546209144011

# %%
from scipy.stats import chisquare

# %%
chi_sqd = sum([(AMER_1851_1900_STEP1[word]['frequency'] if word in AMER_1851_1900_STEP1.keys() else 0 
               - 
               BRIT_1851_1900_STEP1[word]['frequency'] if word in BRIT_1851_1900_STEP1.keys() else 0)**2 
               
               for word in set(BRIT_1851_1900_STEP1.keys()).union(set(AMER_1851_1900_STEP1.keys()))
              / 
              BRIT_1851_1900_STEP1[word]['frequency'] if word in BRIT_1851_1900_STEP1.keys() else 0])
# Out:
#   File "C:\Users\wzkar\AppData\Local\Temp/ipykernel_8372/3194956322.py", line 7
#     BRIT_1851_1900_STEP1[word]['frequency'] if word in BRIT_1851_1900_STEP1.keys() else 0])
#                                                                                    ^
# SyntaxError: invalid syntax

# %%
for word in set(BRIT_1851_1900_STEP1.keys()).union(set(AMER_1851_1900_STEP1.keys())):
    print(word)
# Out:
# oook_NOUN

# %%
def heterozygosity(freq_iter):
    return 1 - sum([f^2 for f in freq_iter])

# %%
amer_unique_1851_1900_s1
# Out:
# {'broaddus_NOUN',
#  'mittances_NOUN',
#  'tippah_NOUN',
#  'haydenville_NOUN',
#  'lieves_ADJ',
#  'era_ADJ',
#  'alka_DET',
#  'edgetools_NOUN',
#  'oslin_NOUN',
#  'aspirated_NOUN',
#  'elderkin_NOUN',
#  'andbe_VERB',
#  'reasoni_NOUN',
#  'lillis_NOUN',
#  'imilitary_ADJ',
#  'ctrine_NOUN',
#  'juae_NOUN',
#  'matthisson_NOUN',
#  'eulogistic_NOUN',
#  'motherwort_NOUN',
#  'democratie_NOUN',
#  'avcrment_NOUN',
#  'intereourse_NOUN',
#  'crawfordville_NOUN',
#  'morelos_NOUN',
#  'towar_VERB',
#  'alenc_NOUN',
#  'soriously_ADV',
#  'aci_X',
#  'aecursed_VERB',
#  'critchlow_NOUN',
#  'vitiatc_VERB',
#  'manycolored_VERB',
#  'keang_NOUN',
#  'aflidavit_VERB',
#  'committecs_NOUN',
#  'hillegas_NOUN',
#  'demonstrativeness_NOUN',
#  'lorent_NOUN',
#  'similc_ADJ',
#  'shaii_VERB',
#  'jimeson_NOUN',
#  'gtain_NOUN',
#  'enfeoffment_NOUN',
#  'goodnight_ADJ',
#  'nrw_ADJ',
#  'dve_ADJ',
#  'seeknofurther_NOUN',
#  'losee_NOUN',
#  'irre_VERB',
#  'rtnd_VERB',
#  'mport_NOUN',
#  'propaga_NOUN',
#  'respecta_ADJ',
#  'conferee_NOUN',
#  'eontinned_VERB',
#  'bockland_NOUN',
#  'milley_NOUN',
#  'abort_ADP',
#  'mellett_NOUN',
#  'terrc_NOUN',
#  'unfrozen_ADV',
#  'hypoc_NOUN',
#  'breadstufls_NOUN',
#  'tient_ADJ',
#  'aunts_VERB',
#  'itated_ADJ',
#  'igher_ADJ',
#  'karris_NOUN',
#  'onment_X',
#  'limitable_ADJ',
#  'slo_ADJ',
#  'vendce_NOUN',
#  'jurisiction_NOUN',
#  'trape_NOUN',
#  'galuppi_NOUN',
#  'jerusha_NOUN',
#  'abclard_NOUN',
#  'cyzicenus_NOUN',
#  'pennsy_NOUN',
#  'cotrustees_NOUN',
#  'branchville_NOUN',
#  'ancients_VERB',
#  'cargoes_VERB',
#  'imbursement_ADJ',
#  'syphilides_NOUN',
#  'olficially_ADV',
#  'abandone_NOUN',
#  'pausa_NOUN',
#  'interblending_VERB',
#  'mosher_NOUN',
#  'ntially_ADV',
#  'outdoors_ADV',
#  'presidentpro_NOUN',
#  'possibili_NOUN',
#  'adage_ADJ',
#  'neu_VERB',
#  'impossibilia_X',
#  'acure_NOUN',
#  'colector_NOUN',
#  'carnification_NOUN',
#  'keitt_NOUN',
#  'rctorted_VERB',
#  'pcrley_NOUN',
#  'commuter_NOUN',
#  'munfordsville_NOUN',
#  'satford_NOUN',
#  'poiton_NOUN',
#  'menobranchus_NOUN',
#  'omro_NOUN',
#  'heartand_NOUN',
#  'meder_NOUN',
#  'mpathies_NOUN',
#  'susquehan_NOUN',
#  'tieated_VERB',
#  'defectives_NOUN',
#  'counrv_NOUN',
#  'insterburg_NOUN',
#  'previde_VERB',
#  'mislaying_NOUN',
#  'odicers_NOUN',
#  'barnyard_ADJ',
#  'relatious_NOUN',
#  'pnle_NOUN',
#  'drier_VERB',
#  'resolver_NOUN',
#  'profondeur_X',
#  'samucl_NOUN',
#  'glick_NOUN',
#  'pentangular_ADJ',
#  'phylarchus_NOUN',
#  'freeth_VERB',
#  'pounding_NOUN',
#  'lmnd_NOUN',
#  'consecu_ADJ',
#  'messico_NOUN',
#  'gressional_ADJ',
#  'criptures_NOUN',
#  'matne_NOUN',
#  'aldert_NOUN',
#  'allud_VERB',
#  'strictl_ADV',
#  'distrib_ADJ',
#  'appar_ADV',
#  'matcrial_ADJ',
#  'woodrutf_NOUN',
#  'brazilwood_NOUN',
#  'ndrew_NOUN',
#  'intenser_ADV',
#  'taliafero_NOUN',
#  'hornung_NOUN',
#  'hiy_NOUN',
#  'brethreu_NOUN',
#  'congar_NOUN',
#  'limonite_NOUN',
#  'missent_NOUN',
#  'compassest_VERB',
#  'nueces_NOUN',
#  'gilleland_NOUN',
#  'custodv_NOUN',
#  'paty_NOUN',
#  'ality_X',
#  'tleman_X',
#  'bold_NOUN',
#  'exhibiters_NOUN',
#  'sefiores_NOUN',
#  'agair_ADV',
#  'boquets_NOUN',
#  'rozell_NOUN',
#  'kiw_NOUN',
#  'inculeated_VERB',
#  'provincetown_NOUN',
#  'pathway_VERB',
#  'uz_X',
#  'truxton_NOUN',
#  'scretary_NOUN',
#  'alabaina_NOUN',
#  'twentyfour_ADJ',
#  'iiio_NOUN',
#  'foust_NOUN',
#  'ponchartrain_NOUN',
#  'carmalt_NOUN',
#  'ringbones_NOUN',
#  'snarly_ADJ',
#  'itichmond_NOUN',
#  'peopic_NOUN',
#  'fraterna_NOUN',
#  'hydrant_ADJ',
#  'congressin_NOUN',
#  'fronv_ADP',
#  'rootstown_NOUN',
#  'leurn_VERB',
#  'papula_NOUN',
#  'reaeh_NOUN',
#  'erward_NOUN',
#  'mornlng_NOUN',
#  'pontoosuc_NOUN',
#  'medley_PRON',
#  'siarth_NOUN',
#  'locatiou_NOUN',
#  'incorporat_NOUN',
#  'dletown_NOUN',
#  'pamelia_NOUN',
#  'archemorus_NOUN',
#  'scientifics_NOUN',
#  'prono_NOUN',
#  'formey_NOUN',
#  'urrection_NOUN',
#  'resscd_NOUN',
#  'ffrancis_VERB',
#  'intui_ADJ',
#  'forand_NOUN',
#  'helievers_NOUN',
#  'mclanc_NOUN',
#  'parking_NOUN',
#  'eutering_VERB',
#  'amaz_ADJ',
#  'informational_ADJ',
#  'plea_X',
#  'scrve_VERB',
#  'pnetors_NOUN',
#  'mcginn_NOUN',
#  'silvee_NOUN',
#  'fiie_VERB',
#  'iousness_NOUN',
#  'periors_NOUN',
#  'inadvertantly_ADV',
#  'iail_NOUN',
#  'commorant_NOUN',
#  'harrv_NOUN',
#  'rivertown_NOUN',
#  'rranged_VERB',
#  'ulcere_NOUN',
#  'emment_ADJ',
#  'aldermcn_NOUN',
#  'presdent_NOUN',
#  'cassopolis_NOUN',
#  'closen_VERB',
#  'nouvelles_ADJ',
#  'meachum_NOUN',
#  'inlisted_VERB',
#  'swaar_NOUN',
#  'ailroad_NOUN',
#  'rhap_NOUN',
#  'pensons_NOUN',
#  'hera_ADV',
#  'coutinue_VERB',
#  'whitneyville_NOUN',
#  'alwas_NOUN',
#  'ribault_NOUN',
#  'wituess_VERB',
#  'fety_NOUN',
#  'slandering_ADJ',
#  'peritonaeum_NOUN',
#  'ncement_NOUN',
#  'thejustice_DET',
#  'interferance_NOUN',
#  'puie_NOUN',
#  'lucins_NOUN',
#  'oldier_NOUN',
#  'pastorius_NOUN',
#  'stimated_VERB',
#  'allotropism_NOUN',
#  'crip_VERB',
#  'musser_NOUN',
#  'obserration_NOUN',
#  'whitcfield_NOUN',
#  'johnb_NOUN',
#  'dved_VERB',
#  'nasn_NOUN',
#  'seuate_NOUN',
#  'wappinger_NOUN',
#  'eripuit_NOUN',
#  'payday_NOUN',
#  'buttermaking_NOUN',
#  'indoctrinating_NOUN',
#  'crimpled_VERB',
#  'paraiso_NOUN',
#  'seasoin_NOUN',
#  'pursuin_VERB',
#  'generalife_NOUN',
#  'complcte_NOUN',
#  'inanifested_VERB',
#  'nnns_NOUN',
#  'nellis_NOUN',
#  'nier_X',
#  'muskcts_NOUN',
#  'amelung_NOUN',
#  'confederatcs_NOUN',
#  'ichat_ADP',
#  'ilagar_NOUN',
#  'monse_NOUN',
#  'follbwing_NOUN',
#  'choteau_NOUN',
#  'sheath_ADJ',
#  'formi_ADV',
#  'terrifie_NOUN',
#  'parchaser_NOUN',
#  'desola_ADJ',
#  'toombs_NOUN',
#  'dervis_NOUN',
#  'tillary_NOUN',
#  'strob_NOUN',
#  'progressional_ADJ',
#  'rit_ADJ',
#  'sebec_NOUN',
#  'committoo_NOUN',
#  'kiersted_NOUN',
#  'falley_NOUN',
#  'discomfitted_ADJ',
#  'rliode_NOUN',
#  'polleys_NOUN',
#  'winfleld_NOUN',
#  'cracken_NOUN',
#  'orcible_ADJ',
#  'yoko_NOUN',
#  'tinguishment_NOUN',
#  'eformed_VERB',
#  'larjre_ADJ',
#  'catoctin_NOUN',
#  'adwise_VERB',
#  'assections_NOUN',
#  'thereot_ADV',
#  'iiundreds_NOUN',
#  'tbo_PRT',
#  'odiorne_NOUN',
#  'flander_NOUN',
#  'whitestown_NOUN',
#  'freemansburg_NOUN',
#  'hicksville_NOUN',
#  'keiffer_NOUN',
#  'dcsire_NOUN',
#  'thorn_X',
#  'frinch_NOUN',
#  'laminze_NOUN',
#  'tribumal_NOUN',
#  'unsinged_VERB',
#  'fagle_NOUN',
#  'rcco_NOUN',
#  'emmitt_NOUN',
#  'exclusire_NOUN',
#  'delaficld_NOUN',
#  'situdes_NOUN',
#  'typhoidal_ADJ',
#  'encmata_NOUN',
#  'dys_VERB',
#  'yclept_VERB',
#  'deshon_NOUN',
#  'cheery_VERB',
#  'foushee_NOUN',
#  'anama_NOUN',
#  'trunkmaker_NOUN',
#  'grd_NOUN',
#  'hershey_NOUN',
#  'eauses_VERB',
#  'outto_PRT',
#  'gelatiniform_NOUN',
#  'lick_ADV',
#  'instrusted_VERB',
#  'averell_NOUN',
#  'quors_NOUN',
#  'appropi_NOUN',
#  'ingersoli_NOUN',
#  'whorn_ADV',
#  'hoads_NOUN',
#  'forkful_NOUN',
#  'amns_NOUN',
#  'carnuntum_NOUN',
#  'agreea_DET',
#  'bedquilt_NOUN',
#  'ainc_NOUN',
#  'muhlenburg_NOUN',
#  'superinducing_NOUN',
#  'aifect_NOUN',
#  'estored_VERB',
#  'xvlll_NOUN',
#  'corlis_NOUN',
#  'offiling_VERB',
#  'caucus_VERB',
#  'sessments_NOUN',
#  'thar_PRON',
#  'uniformity_VERB',
#  'minthorne_NOUN',
#  'rnan_ADJ',
#  'schuman_NOUN',
#  'verrazani_NOUN',
#  'fresher_VERB',
#  'unparal_ADJ',
#  'deferent_NOUN',
#  'determiue_VERB',
#  'hrve_VERB',
#  'munsees_NOUN',
#  'jhad_NOUN',
#  'olated_VERB',
#  'hellman_NOUN',
#  'menuments_NOUN',
#  'wakeful_VERB',
#  'rounsville_NOUN',
#  'construet_VERB',
#  'deaton_NOUN',
#  'exbausted_VERB',
#  'chanic_NOUN',
#  'receivcd_NOUN',
#  'purbach_NOUN',
#  'liuve_VERB',
#  'lamott_NOUN',
#  'octobert_NOUN',
#  'cacalia_NOUN',
#  'hizo_NOUN',
#  'churchwell_NOUN',
#  'reg_ADV',
#  'verally_ADV',
#  'geveral_ADJ',
#  'ackerly_NOUN',
#  'fullblooded_ADJ',
#  'williarns_NOUN',
#  'disinte_NOUN',
#  'fairminded_VERB',
#  'azedarach_NOUN',
#  'guzmans_NOUN',
#  'croir_NOUN',
#  'pario_NOUN',
#  'decadence_X',
#  'whirh_VERB',
#  'arvine_NOUN',
#  'ceeds_ADJ',
#  'aade_VERB',
#  'conduire_NOUN',
#  'urch_VERB',
#  'rms_ADJ',
#  'qut_ADJ',
#  'builion_NOUN',
#  'sortifications_NOUN',
#  'sustaiu_VERB',
#  'thouglit_NOUN',
#  'edenburg_NOUN',
#  'yoe_NOUN',
#  'oolor_NOUN',
#  'moyamensing_NOUN',
#  'physioian_NOUN',
#  'eveh_ADV',
#  'jouett_NOUN',
#  'enciente_ADV',
#  'jusjurandum_NOUN',
#  'pictur_ADJ',
#  'nniversally_ADV',
#  'privil_ADJ',
#  'retary_VERB',
#  'hollinger_NOUN',
#  'adiourn_VERB',
#  'velsor_NOUN',
#  'ngree_VERB',
#  'gratui_NOUN',
#  'pefore_VERB',
#  'licr_ADP',
#  'inelosed_ADJ',
#  'inanners_NOUN',
#  'dicial_NOUN',
#  'blackhawk_NOUN',
#  'hubbardston_NOUN',
#  'cabeza_X',
#  'willams_NOUN',
#  'vcxation_NOUN',
#  'slayton_NOUN',
#  'cqunty_NOUN',
#  'jehovah_X',
#  'irenams_NOUN',
#  'norristown_NOUN',
#  'apologet_NOUN',
#  'cmbracing_VERB',
#  'yaphank_NOUN',
#  'finery_ADV',
#  'remediless_ADJ',
#  'sonl_ADJ',
#  'likin_VERB',
#  'kinkle_NOUN',
#  'uavy_NOUN',
#  'ncre_NOUN',
#  'thfl_VERB',
#  'muldrow_NOUN',
#  'legare_NOUN',
#  'monroeville_NOUN',
#  'bouchette_NOUN',
#  'fostoria_NOUN',
#  'davidsons_NOUN',
#  'heeney_NOUN',
#  'noae_NOUN',
#  'iioratio_NOUN',
#  'influcnce_NOUN',
#  'unul_ADJ',
#  'floridan_NOUN',
#  'glenmary_NOUN',
#  'oping_NOUN',
#  'juhe_NOUN',
#  'papiria_NOUN',
#  'neces_ADJ',
#  'teeling_NOUN',
#  'ict_X',
#  'marbourg_NOUN',
#  'balcs_NOUN',
#  'jusi_NOUN',
#  'finil_VERB',
#  'mccrary_NOUN',
#  'rootless_NOUN',
#  'huestis_NOUN',
#  'hanah_NOUN',
#  'endeav_VERB',
#  'appara_X',
#  'servances_NOUN',
#  'conce_VERB',
#  'ptople_NOUN',
#  'hamus_NOUN',
#  'rhodanus_NOUN',
#  'thd_DET',
#  'dcmanded_VERB',
#  'tezas_NOUN',
#  'foretaste_VERB',
#  'dauiel_NOUN',
#  'musconetcong_NOUN',
#  'ancurism_NOUN',
#  'honss_NOUN',
#  'chainman_NOUN',
#  'daga_NOUN',
#  'persecting_VERB',
#  'shclburne_NOUN',
#  'ruckman_NOUN',
#  'benamin_NOUN',
#  'fessendcn_NOUN',
#  'wrightman_NOUN',
#  'eountries_NOUN',
#  'harmstead_NOUN',
#  'ininded_ADJ',
#  'refusod_VERB',
#  'ohap_X',
#  'sowu_NOUN',
#  'lamon_NOUN',
#  'ubout_PRT',
#  'ehancery_NOUN',
#  'ybu_NOUN',
#  'ebery_ADJ',
#  'mobocratic_ADJ',
#  'hhall_VERB',
#  'washingt_NOUN',
#  'hepp_NOUN',
#  'ture_ADV',
#  'hainilton_NOUN',
#  'mizzen_NUM',
#  'broom_VERB',
#  'resid_VERB',
#  'vestigio_X',
#  'arsdale_NOUN',
#  'practition_NOUN',
#  'spitler_NOUN',
#  'nection_VERB',
#  'boettcher_NOUN',
#  'riehardson_NOUN',
#  'insano_NOUN',
#  'exsiccate_VERB',
#  'forfcitures_NOUN',
#  'forgetfnlness_NOUN',
#  'josr_NOUN',
#  'felter_NOUN',
#  'conucted_VERB',
#  'thorize_NOUN',
#  'lilth_NOUN',
#  'seves_NOUN',
#  'mbia_NOUN',
#  'cce_NOUN',
#  'cmbankments_NOUN',
#  'abody_ADV',
#  'thejustice_NOUN',
#  'ligature_X',
#  'vroom_NOUN',
#  'iladley_NOUN',
#  'incumbrauce_NOUN',
#  'nesto_NOUN',
#  'groff_NOUN',
#  'talesman_NOUN',
#  'thanged_VERB',
#  'principlesof_NOUN',
#  'lext_NOUN',
#  'anthelminticum_NOUN',
#  'mquire_VERB',
#  'crable_ADJ',
#  'holty_NOUN',
#  'uegroes_NOUN',
#  'agcnt_NOUN',
#  'nolen_NOUN',
#  'andbe_DET',
#  'oolored_ADJ',
#  'watcli_VERB',
#  'ledbetter_NOUN',
#  'haekett_NOUN',
#  'senac_NOUN',
#  'convictiou_NOUN',
#  'deto_VERB',
#  'frontera_NOUN',
#  'rightand_NOUN',
#  'istration_ADJ',
#  'madamoiselle_NOUN',
#  'yetthe_DET',
#  'linet_NOUN',
#  'triai_NOUN',
#  'regetable_ADJ',
#  'territoiy_NOUN',
#  'entine_ADJ',
#  'mcclel_NOUN',
#  'untit_VERB',
#  'vandervoort_NOUN',
#  'beeome_NOUN',
#  'hopefield_NOUN',
#  'gradior_NOUN',
#  'saidhe_NOUN',
#  'llie_X',
#  'hif_VERB',
#  'wintbrop_NOUN',
#  'locofocos_NOUN',
#  'calorem_X',
#  'ncr_ADJ',
#  'curtisville_NOUN',
#  'yrork_NOUN',
#  'donbtless_VERB',
#  'bladensburgh_NOUN',
#  'mcrrimac_NOUN',
#  'abattle_NOUN',
#  'ncar_ADJ',
#  'woodless_ADJ',
#  'iissouri_NOUN',
#  'geeene_NOUN',
#  'washiugton_NOUN',
#  'rockett_NOUN',
#  'bursted_ADJ',
#  'kerioth_NOUN',
#  'plentier_ADJ',
#  'cieza_NOUN',
#  'pusson_NOUN',
#  'nees_X',
#  'zachos_NOUN',
#  'campville_NOUN',
#  'willimantic_NOUN',
#  'peopleof_NOUN',
#  'dutcher_NOUN',
#  'frcsh_ADJ',
#  'broadaxe_NOUN',
#  'authorily_NOUN',
#  'ific_NOUN',
#  'tlass_NOUN',
#  'fcnd_VERB',
#  'enrollment_VERB',
#  'currences_NOUN',
#  'fishbough_NOUN',
#  'appropri_ADV',
#  'genevae_NOUN',
#  'vvayne_NOUN',
#  'eiferson_NUM',
#  'presant_ADJ',
#  'perpet_ADJ',
#  'infelice_NOUN',
#  'beei_ADV',
#  'limest_ADJ',
#  'gousset_NOUN',
#  'gacity_NOUN',
#  'ows_ADV',
#  'liabil_ADJ',
#  'pensi_NOUN',
#  'bokkelen_NOUN',
#  'armon_NOUN',
#  'townsen_NOUN',
#  'vvhcn_NOUN',
#  'ofindividuals_NOUN',
#  'chaldce_NOUN',
#  'reetitude_NOUN',
#  'perman_ADJ',
#  'nuremberg_ADJ',
#  'nything_VERB',
#  'pulsat_NOUN',
#  'brownville_NOUN',
#  'febiger_NOUN',
#  'deadl_VERB',
#  'praator_NOUN',
#  'villiarns_NOUN',
#  'otherwis_ADJ',
#  'alabamian_NOUN',
#  'incar_NOUN',
#  'conversed_NOUN',
#  'litth_ADJ',
#  'respectully_ADV',
#  'uritans_NOUN',
#  'jumonville_NOUN',
#  'nabas_NOUN',
#  'toxas_NOUN',
#  'hjm_VERB',
#  'tru_ADJ',
#  'whittcmore_NOUN',
#  'salse_ADJ',
#  'acterize_VERB',
#  'crystalized_ADJ',
#  'hcn_NOUN',
#  'beeh_ADP',
#  'otra_ADJ',
#  'paptr_NOUN',
#  'ilove_VERB',
#  'artil_ADJ',
#  'latane_NOUN',
#  'pel_ADV',
#  'priestlike_ADJ',
#  'ervin_NOUN',
#  'governinents_NOUN',
#  'cinaloa_NOUN',
#  'dnr_NOUN',
#  'tolles_NOUN',
#  'soregoing_NOUN',
#  'encroachinents_NOUN',
#  'mcelroy_NOUN',
#  'peyster_NOUN',
#  'eline_NOUN',
#  'rollest_ADJ',
#  'aied_VERB',
#  'ihee_NOUN',
#  'importation_ADJ',
#  'vnited_NOUN',
#  'instantl_NOUN',
#  'gislative_ADJ',
#  'nnan_NOUN',
#  'larned_NOUN',
#  'manl_ADJ',
#  'exccpt_NOUN',
#  'amzi_NOUN',
#  'oroform_NOUN',
#  'incumbranees_NOUN',
#  'sutfer_NOUN',
#  'westeott_NOUN',
#  'whitcom_NOUN',
#  'moial_ADJ',
#  'mcalister_NOUN',
#  'assassi_NOUN',
#  'anfi_DET',
#  'curring_ADJ',
#  'minkler_NOUN',
#  'doten_NOUN',
#  'analyzation_NOUN',
#  'raub_NOUN',
#  'phidippides_NOUN',
#  'cual_X',
#  'cluims_NOUN',
#  'misissippi_NOUN',
#  'homet_NOUN',
#  'brittanica_NOUN',
#  'dnnn_NOUN',
#  'daingerfield_NOUN',
#  'jegean_ADJ',
#  'thenco_NOUN',
#  'nfay_VERB',
#  'roadily_ADV',
#  'recreating_NOUN',
#  'frecdom_NOUN',
#  'angie_NOUN',
#  'ostile_ADJ',
#  'approf_NOUN',
#  'pharus_NOUN',
#  'rhall_NOUN',
#  'foreknows_NOUN',
#  'laring_VERB',
#  'mqre_NOUN',
#  'fcar_NOUN',
#  'stevia_NOUN',
#  'comforta_ADJ',
#  'inquirin_VERB',
#  'mandatary_NOUN',
#  'bushcls_NOUN',
#  'odenheimer_NOUN',
#  'lackawana_NOUN',
#  'pkarm_NOUN',
#  'milhau_NOUN',
#  'giblites_NOUN',
#  'spcaker_NOUN',
#  'nilcs_NOUN',
#  'ofjudges_NOUN',
#  'brooksville_NOUN',
#  'infilled_VERB',
#  'aeceptance_NOUN',
#  'occurrunt_X',
#  'inprisoned_VERB',
#  'wuh_ADV',
#  'laselle_NOUN',
#  'fnm_VERB',
#  'prudden_NOUN',
#  'dishonorable_NOUN',
#  'darrein_VERB',
#  'expccted_VERB',
#  'lilinois_NOUN',
#  'izing_ADJ',
#  'hardenbergh_NOUN',
#  'sssignee_NOUN',
#  'humoral_NOUN',
#  'dowdney_NOUN',
#  'tlue_ADJ',
#  'equita_NOUN',
#  'disenthrall_VERB',
#  'ratify_ADJ',
#  'villet_NOUN',
#  'milldale_NOUN',
#  'vinculis_NOUN',
#  'forseveral_ADJ',
#  'characier_NOUN',
#  'ning_X',
#  'cubist_NOUN',
#  'runniug_NOUN',
#  'mcfingal_NOUN',
#  'masher_NOUN',
#  'pnrchaser_NOUN',
#  'cumston_NOUN',
#  'mported_VERB',
#  'tiller_ADP',
#  'macaulny_NOUN',
#  'kilow_VERB',
#  'environed_ADJ',
#  'futer_NOUN',
#  'gruman_NOUN',
#  'lorillard_NOUN',
#  'shehan_NOUN',
#  'pntnam_NOUN',
#  'broadwav_NOUN',
#  'stcbbins_NOUN',
#  'percus_NOUN',
#  'licanism_NOUN',
#  'conseqence_NOUN',
#  'inachines_NOUN',
#  'rpose_VERB',
#  'sweney_NOUN',
#  'riot_ADJ',
#  'rosekrans_NOUN',
#  'priu_NOUN',
#  'frcquently_ADV',
#  'dockage_NOUN',
#  'bulstr_NOUN',
#  'gitimate_VERB',
#  'fayerweather_NOUN',
#  'arnol_NOUN',
#  'raddle_NOUN',
#  'nicotina_NOUN',
#  'ivt_NOUN',
#  'indigent_X',
#  'fargo_NOUN',
#  'puberty_ADV',
#  'srom_ADV',
#  'lidity_NOUN',
#  'polyglottus_NOUN',
#  'doption_NOUN',
#  'campbellsville_NOUN',
#  'iinmediately_ADV',
#  'dreer_NOUN',
#  'atchinson_NOUN',
#  'paers_NOUN',
#  'learing_NOUN',
#  'conset_NOUN',
#  'muscogee_NOUN',
#  'monikins_NOUN',
#  'thcol_NOUN',
#  'thent_DET',
#  'diffculties_NOUN',
#  'vilages_NOUN',
#  'positious_ADJ',
#  'ordeis_NOUN',
#  'tripolitan_NOUN',
#  'charriere_NOUN',
#  'meagerness_NOUN',
#  'variola_VERB',
#  'pyxis_NOUN',
#  'nealy_NOUN',
#  'cuvillier_NOUN',
#  'whr_NOUN',
#  'despotism_VERB',
#  'offens_NOUN',
#  'perfluous_ADJ',
#  'ishcd_NOUN',
#  'tortions_NOUN',
#  'partlow_NOUN',
#  'burled_ADJ',
#  'defrand_VERB',
#  'schenectady_ADJ',
#  'lawyersville_NOUN',
#  'dclos_NOUN',
#  'eufchatel_NOUN',
#  'eslate_NOUN',
#  'thenccforth_DET',
#  'jogues_NOUN',
#  'kandall_NOUN',
#  'seleu_NOUN',
#  'busbee_NOUN',
#  'repertoire_X',
#  'clairns_NOUN',
#  'receiva_VERB',
#  'barnnm_NOUN',
#  'lbe_ADJ',
#  'renewings_NOUN',
#  'sonrel_NOUN',
#  'atlast_VERB',
#  'pluperfect_X',
#  'mcharg_NOUN',
#  'accessable_ADJ',
#  'yarieties_NOUN',
#  'weirich_NOUN',
#  'hankercher_NOUN',
#  'rict_VERB',
#  'vhenever_ADP',
#  'foad_NOUN',
#  'ohina_NOUN',
#  'nebber_ADV',
#  'germana_NOUN',
#  'ordar_NOUN',
#  'amenta_NOUN',
#  'lafavette_NOUN',
#  'blooil_NOUN',
#  'vanhorn_NOUN',
#  'hullers_NOUN',
#  'texa_NOUN',
#  'mountai_NOUN',
#  'udi_ADJ',
#  'suttered_VERB',
#  'demaud_VERB',
#  'agesipolis_NOUN',
#  'centurics_NOUN',
#  'insuro_VERB',
#  'hurl_ADJ',
#  'nooga_NOUN',
#  'mortised_ADJ',
#  'diathcsis_NOUN',
#  'behooves_NOUN',
#  'pughtown_NOUN',
#  'aia_ADP',
#  'llc_ADJ',
#  'disorganizes_NOUN',
#  'honorto_NOUN',
#  'thejournals_NOUN',
#  'readoption_NOUN',
#  'tui_ADJ',
#  'smits_NOUN',
#  'cureulio_NOUN',
#  'grealer_ADJ',
#  'reargue_VERB',
#  'tinre_NOUN',
#  'predation_NOUN',
#  'nast_ADV',
#  'bellport_NOUN',
#  'curts_NOUN',
#  'hearti_NOUN',
#  'floodwood_NOUN',
#  'perrill_NOUN',
#  'dran_VERB',
#  'ercise_VERB',
#  'residingin_VERB',
#  'itures_NOUN',
#  'desiguated_VERB',
#  'mornent_NOUN',
#  'sacrum_ADJ',
#  'hurning_NOUN',
#  'rivei_NOUN',
#  'waynesburg_NOUN',
#  'anoverdue_NOUN',
#  'reemelin_NOUN',
#  'anew_ADP',
#  'auv_VERB',
#  'skc_NOUN',
#  'barvard_NOUN',
#  'hazelhurst_NOUN',
#  'wincing_ADJ',
#  'fortney_NOUN',
#  'terryville_NOUN',
#  'satd_NOUN',
#  'hairl_NOUN',
#  'wormseed_NOUN',
#  'asual_ADJ',
#  'factual_ADJ',
#  'privale_ADJ',
#  'satissaction_NOUN',
#  'dillman_NOUN',
#  'isracl_NOUN',
#  'rensellaer_NOUN',
#  'presidtnt_NOUN',
#  'desira_ADJ',
#  'naragansett_NOUN',
#  'notj_VERB',
#  'rewere_VERB',
#  'cumscribed_VERB',
#  'sloat_NOUN',
#  'hreaking_VERB',
#  'rountree_NOUN',
#  'stoies_NOUN',
#  'impanneling_NOUN',
#  'trogyllium_NOUN',
#  'greenbush_NOUN',
#  'structcd_NOUN',
#  'ciency_VERB',
#  'hoj_NOUN',
#  'baktlett_NOUN',
#  'unsavorable_ADJ',
#  'accumbent_NOUN',
#  'iays_NOUN',
#  'frasier_NOUN',
#  ...}

# %%
brit_unique_1851_1900_s1
# Out:
# {'cercopithecus_NOUN',
#  'mounteney_NOUN',
#  'shanking_NOUN',
#  'floccose_NOUN',
#  'mosse_X',
#  'scotophilus_NOUN',
#  'saltmarket_NOUN',
#  'opusculum_NOUN',
#  'leguminosse_NOUN',
#  'marcas_NOUN',
#  'obstantibus_X',
#  'imam_X',
#  'kente_NOUN',
#  'wellsustained_ADJ',
#  'cypricardia_NOUN',
#  'bellezza_X',
#  'carcinus_NOUN',
#  'gelt_ADJ',
#  'aart_NOUN',
#  'topping_NOUN',
#  'appellent_X',
#  'outragious_ADJ',
#  'ronson_NOUN',
#  'jopling_NOUN',
#  'funus_NOUN',
#  'illfavoured_VERB',
#  'wastell_NOUN',
#  'denbigh_ADJ',
#  'approched_VERB',
#  'impersonator_NOUN',
#  'titian_ADP',
#  'byeword_NOUN',
#  'obliger_NOUN',
#  'meidias_NOUN',
#  'helichrysum_NOUN',
#  'thurgood_NOUN',
#  'abundle_NOUN',
#  'bridg_ADJ',
#  'carp_ADJ',
#  'lasst_X',
#  'wiixiam_NOUN',
#  'wyne_VERB',
#  'coneludes_NOUN',
#  'clod_VERB',
#  'bamian_NOUN',
#  'pindee_NOUN',
#  'salu_X',
#  'schooten_NOUN',
#  'dinting_NOUN',
#  'diatom_NOUN',
#  'illogan_NOUN',
#  'puauc_NOUN',
#  'chastitie_NOUN',
#  'bicardo_NOUN',
#  'homb_NOUN',
#  'hermajesty_NOUN',
#  'eyeservice_NOUN',
#  'hunde_NOUN',
#  'lowd_ADJ',
#  'rchbishop_NOUN',
#  'geddington_NOUN',
#  'neilston_NOUN',
#  'hopen_VERB',
#  'preposterous_NOUN',
#  'kanta_NOUN',
#  'registro_NOUN',
#  'encrinite_NOUN',
#  'andlords_NOUN',
#  'triumphos_X',
#  'snaw_ADJ',
#  'plotted_ADJ',
#  'nio_VERB',
#  'liquorice_ADJ',
#  'cinderford_NOUN',
#  'doneaster_NOUN',
#  'woollacott_NOUN',
#  'hagh_NOUN',
#  'cleres_NOUN',
#  'winglet_NOUN',
#  'aneuch_NOUN',
#  'mamun_NOUN',
#  'aequali_X',
#  'sarvants_NOUN',
#  'palamcotta_NOUN',
#  'suraj_NOUN',
#  'fidgetting_VERB',
#  'brownsmith_NOUN',
#  'knaw_X',
#  'undre_VERB',
#  'contrat_X',
#  'kto_NOUN',
#  'widower_ADP',
#  'rappel_NOUN',
#  'saltpetre_ADJ',
#  'perer_NOUN',
#  'ferrous_ADJ',
#  'spinose_NOUN',
#  'olergyman_NOUN',
#  'littleham_NOUN',
#  'artificers_VERB',
#  'bourhood_VERB',
#  'gladstanes_NOUN',
#  'pontormo_NOUN',
#  'traitor_CONJ',
#  'sayth_ADJ',
#  'bastick_NOUN',
#  'accompamed_VERB',
#  'simoniacally_ADV',
#  'ericetorum_NOUN',
#  'harlcy_NOUN',
#  'falsed_VERB',
#  'salzwedel_NOUN',
#  'tidemark_NOUN',
#  'lopt_VERB',
#  'portuguese_ADV',
#  'dilli_NOUN',
#  'racteristic_ADJ',
#  'cranwell_NOUN',
#  'meltingpoint_NOUN',
#  'pensionnaires_NOUN',
#  'trifoliolate_NOUN',
#  'ehrenb_NOUN',
#  'watir_NOUN',
#  'relicks_NOUN',
#  'blacke_VERB',
#  'anyl_DET',
#  'drawes_NOUN',
#  'gratid_VERB',
#  'culta_X',
#  'archieology_NOUN',
#  'prayes_NOUN',
#  'inimici_NOUN',
#  'keusington_NOUN',
#  'loyall_ADJ',
#  'benche_NOUN',
#  'undelayed_ADJ',
#  'syllable_X',
#  'saki_NOUN',
#  'quatuordecim_X',
#  'barow_NOUN',
#  'beiog_ADP',
#  'arbutlmot_NOUN',
#  'grit_X',
#  'orove_NOUN',
#  'younker_ADJ',
#  'macrocarpum_NOUN',
#  'xothing_NOUN',
#  'tall_NOUN',
#  'fluviatilis_NOUN',
#  'cabossed_VERB',
#  'cumsean_NOUN',
#  'rogavit_X',
#  'victoeia_NOUN',
#  'hanky_NOUN',
#  'formerlie_NOUN',
#  'invalided_NOUN',
#  'laas_NOUN',
#  'stuttgart_ADJ',
#  'recont_NOUN',
#  'glowin_VERB',
#  'kosen_NOUN',
#  'daylabourers_NOUN',
#  'fient_NOUN',
#  'jiddah_NOUN',
#  'deckt_NOUN',
#  'growe_ADJ',
#  'biisching_NOUN',
#  'blidah_NOUN',
#  'serpyllum_NOUN',
#  'cameram_X',
#  'tottenbam_NOUN',
#  'deceivest_VERB',
#  'gualtier_NOUN',
#  'munere_ADJ',
#  'australie_NOUN',
#  'apologetica_NOUN',
#  'darin_X',
#  'mensch_X',
#  'thereand_CONJ',
#  'hnmber_NOUN',
#  'lyers_NOUN',
#  'formuke_NOUN',
#  'accelerative_ADJ',
#  'philomathic_NOUN',
#  'taties_NOUN',
#  'rupe_X',
#  'swordes_NOUN',
#  'ambassades_NOUN',
#  'eneland_NOUN',
#  'tractatum_X',
#  'pontifici_X',
#  'godr_NOUN',
#  'bevil_ADJ',
#  'redentore_NOUN',
#  'hannr_NOUN',
#  'eomney_NOUN',
#  'woeful_NOUN',
#  'ornement_X',
#  'collegio_X',
#  'marigold_ADJ',
#  'wissenschaft_X',
#  'boords_NOUN',
#  'haldin_NOUN',
#  'flosh_NOUN',
#  'ochrida_NOUN',
#  'koval_NOUN',
#  'voluerint_X',
#  'bilh_NOUN',
#  'cloveshoo_NOUN',
#  'lexilogus_NOUN',
#  'salf_NOUN',
#  'pennyworth_ADJ',
#  'sparsis_X',
#  'saccolabium_NOUN',
#  'uth_ADV',
#  'manicata_NOUN',
#  'reame_NOUN',
#  'irone_NOUN',
#  'halic_NOUN',
#  'glatton_NOUN',
#  'remuneratively_ADV',
#  'odcombe_NOUN',
#  'beatum_NOUN',
#  'oonnexion_NOUN',
#  'systema_X',
#  'meadowsweet_NOUN',
#  'peize_NOUN',
#  'gat_X',
#  'cockennouth_NOUN',
#  'pohce_NOUN',
#  'emall_ADJ',
#  'alberi_NOUN',
#  'kiltearn_NOUN',
#  'paraffine_ADJ',
#  'binger_NOUN',
#  'ignoraunce_NOUN',
#  'sliabh_NOUN',
#  'piesse_NOUN',
#  'shepherd_ADV',
#  'wavelike_ADJ',
#  'wildbore_NOUN',
#  'stampt_ADJ',
#  'adaptor_NOUN',
#  'disapeared_VERB',
#  'bhitish_NOUN',
#  'ovo_ADV',
#  'rawing_ADJ',
#  'meredyth_NOUN',
#  'borrer_NOUN',
#  'obscurum_X',
#  'headfort_NOUN',
#  'bodie_VERB',
#  'livret_NOUN',
#  'naturelles_X',
#  'nettlested_NOUN',
#  'willelmo_X',
#  'ehemical_ADJ',
#  'slunk_ADV',
#  'expectod_VERB',
#  'bala_X',
#  'arepresentation_NOUN',
#  'alloweth_ADV',
#  'repori_NOUN',
#  'euskin_NOUN',
#  'klizabeth_NOUN',
#  'bookbinding_VERB',
#  'cicindelidae_NOUN',
#  'cadley_NOUN',
#  'tost_X',
#  'amoris_VERB',
#  'carhaix_NOUN',
#  'treveri_NOUN',
#  'verbenaceae_NOUN',
#  'stonard_NOUN',
#  'wbight_NOUN',
#  'capiunt_X',
#  'gren_ADJ',
#  'refuso_NOUN',
#  'regulariter_NOUN',
#  'milneedwards_NOUN',
#  'prestes_NOUN',
#  'incrassato_X',
#  'chargeth_NOUN',
#  'ispute_NOUN',
#  'fraas_NOUN',
#  'baronct_NOUN',
#  'commendatio_X',
#  'bucknall_NOUN',
#  'mittheilungen_X',
#  'ehenish_NOUN',
#  'enanthe_NOUN',
#  'guerchy_NOUN',
#  'bilingual_NOUN',
#  'effeteness_NOUN',
#  'issimo_NOUN',
#  'hangit_NOUN',
#  'quatford_NOUN',
#  'moden_NOUN',
#  'invariabl_NOUN',
#  'weatherglass_NOUN',
#  'nostell_NOUN',
#  'counsellers_NOUN',
#  'preventible_NOUN',
#  'chapuy_NOUN',
#  'nazing_NOUN',
#  'grouse_VERB',
#  'nagar_NOUN',
#  'relatum_X',
#  'gammarus_NOUN',
#  'monumcnta_NOUN',
#  'remanent_ADJ',
#  'westgate_ADJ',
#  'circumscribed_NOUN',
#  'sixpennyworth_NOUN',
#  'aenea_NOUN',
#  'kyrke_NOUN',
#  'fiftene_NUM',
#  'mercuric_NOUN',
#  'phaed_NOUN',
#  'climbe_VERB',
#  'sarnen_NOUN',
#  'quocunque_ADJ',
#  'gight_NOUN',
#  'shute_VERB',
#  'pedicellate_VERB',
#  'pochin_NOUN',
#  'pyridine_NOUN',
#  'centres_ADJ',
#  'inventionem_NOUN',
#  'praeclara_X',
#  'dumbshow_NOUN',
#  'ncwcastle_ADJ',
#  'cooly_ADJ',
#  'fala_NOUN',
#  'gierusalemme_NOUN',
#  'omissa_X',
#  'emoirs_NOUN',
#  'oificial_NOUN',
#  'rarotongan_NOUN',
#  'hada_DET',
#  'solvendo_X',
#  'malae_X',
#  'ornate_X',
#  'expenments_NOUN',
#  'firat_ADV',
#  'virgine_ADJ',
#  'prophesie_NOUN',
#  'bradney_NOUN',
#  'nabonidus_NOUN',
#  'tisa_NOUN',
#  'pacified_ADJ',
#  'galwa_NOUN',
#  'iche_NOUN',
#  'concessi_X',
#  'bayth_NOUN',
#  'waly_NOUN',
#  'xx_ADP',
#  'blaeu_NOUN',
#  'apterya_NOUN',
#  'squaee_NOUN',
#  'concaved_VERB',
#  'thirsty_PRON',
#  'gravesend_ADJ',
#  'solatium_ADJ',
#  'victob_NOUN',
#  'fuerunt_VERB',
#  'ourselvos_NOUN',
#  'bedder_NOUN',
#  'factorum_X',
#  'undersurface_NOUN',
#  'hevy_ADJ',
#  'broch_NOUN',
#  'pisolitic_ADJ',
#  'stickland_NOUN',
#  'confarreatio_NOUN',
#  'moonstone_NOUN',
#  'papilionaceous_NOUN',
#  'keillor_NOUN',
#  'feilding_NOUN',
#  'teversham_NOUN',
#  'ronny_NOUN',
#  'yielde_VERB',
#  'rectorof_NOUN',
#  'thoseof_DET',
#  'ashwin_NOUN',
#  'hydrographie_NOUN',
#  'anstie_NOUN',
#  'alverstoke_NOUN',
#  'wyves_NOUN',
#  'jointings_NOUN',
#  'singeth_ADJ',
#  'castaneus_NOUN',
#  'draper_VERB',
#  'execucion_NOUN',
#  'longitudinis_X',
#  'plag_NOUN',
#  'adur_NOUN',
#  'frediano_NOUN',
#  'cospatric_NOUN',
#  'olium_NOUN',
#  'padma_NOUN',
#  'appy_NOUN',
#  'gladwell_NOUN',
#  'omparative_ADJ',
#  'kite_X',
#  'motya_NOUN',
#  'lingam_NOUN',
#  'sehwan_NOUN',
#  'protag_NOUN',
#  'molliter_X',
#  'kinsky_NOUN',
#  'doctoris_X',
#  'planco_NOUN',
#  'latif_NOUN',
#  'bose_ADJ',
#  'gerardiana_NOUN',
#  'chiefe_VERB',
#  'rangiferina_NOUN',
#  'bogey_NOUN',
#  'frap_NOUN',
#  'rollock_NOUN',
#  'lucens_NOUN',
#  'mailbag_NOUN',
#  'meridionalis_NOUN',
#  'hadar_NOUN',
#  'taryed_VERB',
#  'edgitha_NOUN',
#  'dngald_NOUN',
#  'andsocket_ADJ',
#  'innocently_ADJ',
#  'caoutchouc_VERB',
#  'hypsiprymnus_NOUN',
#  'jacqueminot_NOUN',
#  'kearsey_NOUN',
#  'traiteur_NOUN',
#  'mixbury_NOUN',
#  'controuled_VERB',
#  'sensitiveness_ADJ',
#  'chenpside_NOUN',
#  'organum_X',
#  'tegulae_NOUN',
#  'locatelli_NOUN',
#  'tunga_NOUN',
#  'ravenshaw_NOUN',
#  'dundases_NOUN',
#  'theophila_NOUN',
#  'jacere_NOUN',
#  'rudkin_NOUN',
#  'superare_NOUN',
#  'disconnexion_NOUN',
#  'boko_NOUN',
#  'llanbadarn_NOUN',
#  'elspet_NOUN',
#  'wassell_NOUN',
#  'lorsque_NOUN',
#  'tubulated_VERB',
#  'pecock_NOUN',
#  'novorum_NOUN',
#  'harcourts_NOUN',
#  'compt_ADJ',
#  'surveyorship_NOUN',
#  'patrocinio_X',
#  'moit_NOUN',
#  'amusineg_VERB',
#  'northesk_NOUN',
#  'monastica_NOUN',
#  'simone_X',
#  'novatianism_NOUN',
#  'arbnthnot_NOUN',
#  'gutta_VERB',
#  'kiog_NOUN',
#  'septembris_X',
#  'asad_NOUN',
#  'ambrosiaster_NOUN',
#  'kindlier_NOUN',
#  'annuitie_NOUN',
#  'evelegh_NOUN',
#  'betwa_NOUN',
#  'sectile_NOUN',
#  'nycholas_NOUN',
#  'allcard_NOUN',
#  'centro_ADJ',
#  'rathlin_NOUN',
#  'intin_NOUN',
#  'hereditary_VERB',
#  'strret_NOUN',
#  'bettering_ADJ',
#  'latinise_VERB',
#  'revien_NOUN',
#  'verning_VERB',
#  'desford_NOUN',
#  'nour_X',
#  'tausch_NOUN',
#  'dilectione_X',
#  'sennight_NOUN',
#  'melanura_NOUN',
#  'tinca_NOUN',
#  'indumentum_X',
#  'nonionina_NOUN',
#  'docere_NOUN',
#  'bradshawe_NOUN',
#  'bestias_X',
#  'rudyerd_NOUN',
#  'ornamentists_NOUN',
#  'deliciae_NOUN',
#  'incorrodible_ADJ',
#  'lxxiil_NOUN',
#  'rowlinson_NOUN',
#  'martyne_NOUN',
#  'pbofessob_NOUN',
#  'procuratores_NOUN',
#  'devouport_NOUN',
#  'jlj_NOUN',
#  'tkl_NOUN',
#  'sorbet_NOUN',
#  'veritables_X',
#  'westell_NOUN',
#  'btems_NOUN',
#  'stogursey_NOUN',
#  'norice_NOUN',
#  'waterfloods_NOUN',
#  'alci_NOUN',
#  'heire_VERB',
#  'macular_NOUN',
#  'rugs_VERB',
#  'wauxhall_NOUN',
#  'plainlie_NOUN',
#  'quaeque_ADJ',
#  'walgrave_NOUN',
#  'nuper_CONJ',
#  'elaeagnus_NOUN',
#  'satisfaire_X',
#  'obdeb_NOUN',
#  'parlane_NOUN',
#  'humea_NOUN',
#  'blne_NOUN',
#  'erskin_NOUN',
#  'parri_NOUN',
#  'threed_NOUN',
#  'auximum_NOUN',
#  'arthuri_NOUN',
#  'yitruvius_NOUN',
#  'itur_NOUN',
#  'owne_ADV',
#  'linemen_NOUN',
#  'felpham_NOUN',
#  'himselfe_ADV',
#  'medio_VERB',
#  'gallinae_NOUN',
#  'chaunter_NOUN',
#  'iest_VERB',
#  'gingle_NOUN',
#  'cleobury_NOUN',
#  'esquyer_NOUN',
#  'morinda_NOUN',
#  'tuberosus_NOUN',
#  'aequor_X',
#  'abhorrer_NOUN',
#  'perinaeal_ADJ',
#  'beforementioned_ADJ',
#  'scrofa_NOUN',
#  'quingentesimo_X',
#  'musikalische_NOUN',
#  'behnes_NOUN',
#  'coalminers_NOUN',
#  'compeared_VERB',
#  'pinnatus_NOUN',
#  'laciniata_X',
#  'enmore_NOUN',
#  'avoi_X',
#  'humilitate_X',
#  'lntrod_NOUN',
#  'voler_NOUN',
#  'horum_NOUN',
#  'brainsick_NOUN',
#  'assimilis_VERB',
#  'ouvert_NOUN',
#  'tije_DET',
#  'underlined_ADJ',
#  'somme_DET',
#  'macro_X',
#  'tilsley_NOUN',
#  'josling_NOUN',
#  'uninterruptedly_ADJ',
#  'succour_PRON',
#  'enwn_NOUN',
#  'appere_NOUN',
#  'abercom_NOUN',
#  'hayre_NOUN',
#  'dutye_NOUN',
#  'blumei_NOUN',
#  'picturis_X',
#  'prioratus_NOUN',
#  'dodonaeus_NOUN',
#  'fouler_NOUN',
#  'advaunce_VERB',
#  'lengthways_ADV',
#  'computus_NOUN',
#  'monogram_VERB',
#  'cythere_NOUN',
#  'holboen_NOUN',
#  'ruman_NOUN',
#  'fastigio_X',
#  'foumart_NOUN',
#  'wynnes_NOUN',
#  'eastington_NOUN',
#  'onby_ADP',
#  'secunderabad_NOUN',
#  'noncompletion_NOUN',
#  'finshury_NOUN',
#  'borna_NOUN',
#  'robissos_NOUN',
#  'beilage_NOUN',
#  'castlecomer_NOUN',
#  'porcian_NOUN',
#  'besyde_ADP',
#  'xxxvii_VERB',
#  'stackyards_NOUN',
#  'anguste_DET',
#  'phillack_NOUN',
#  'univcrsity_NOUN',
#  'whereu_ADV',
#  'accordthe_DET',
#  'hauts_NOUN',
#  'dipladenia_NOUN',
#  'sempill_NOUN',
#  'headforemost_ADV',
#  'ultimatum_ADJ',
#  'kidderpore_NOUN',
#  'halloo_ADV',
#  'unchronicled_VERB',
#  'whewcll_NOUN',
#  'fidelitate_X',
#  'houbc_NOUN',
#  'subjectis_VERB',
#  'lossie_NOUN',
#  'humboldtii_NOUN',
#  'wonld_ADJ',
#  'jouin_NOUN',
#  'pnnciple_NOUN',
#  'sumburgh_NOUN',
#  'toth_ADJ',
#  'meate_ADV',
#  'geobgb_NOUN',
#  'egi_NOUN',
#  'tragiques_NOUN',
#  'crich_NOUN',
#  'oxfo_NOUN',
#  'mendax_NOUN',
#  'diflicultly_ADV',
#  'wyt_VERB',
#  'islington_ADP',
#  'hunnis_NOUN',
#  'thaines_NOUN',
#  'rgument_NOUN',
#  'materno_X',
#  'illinc_X',
#  'widville_NOUN',
#  'confirmare_X',
#  'parkhouse_NOUN',
#  'arabat_NOUN',
#  'oxydising_VERB',
#  'radialis_X',
#  'discrimina_X',
#  'obeyeth_ADP',
#  'lawtie_NOUN',
#  'regtet_NOUN',
#  'latinum_ADJ',
#  'maittaire_NOUN',
#  'keythorpe_NOUN',
#  'cheu_NOUN',
#  'disfavour_ADJ',
#  'woodcut_ADJ',
#  'wonford_NOUN',
#  'translat_NOUN',
#  'balistae_NOUN',
#  'evaristus_NOUN',
#  'kesident_NOUN',
#  'comtek_NOUN',
#  'merentur_X',
#  'menstrie_NOUN',
#  'vulgarise_VERB',
#  'eightly_ADV',
#  'wherry_VERB',
#  'liliacea_NOUN',
#  'troyon_NOUN',
#  'willinge_NOUN',
#  'refonnation_NOUN',
#  'selfhumiliation_NOUN',
#  'istoric_ADJ',
#  'fronde_X',
#  'rufis_NOUN',
#  'worthe_VERB',
#  'secretari_NOUN',
#  'alcudia_NOUN',
#  'mushroom_VERB',
#  'pakefield_NOUN',
#  'stevin_NOUN',
#  'joyfullest_ADJ',
#  'kyme_NOUN',
#  'arpa_NOUN',
#  'leventhorp_NOUN',
#  'significationem_X',
#  'lalng_NOUN',
#  'cyprinidae_NOUN',
#  'purchace_NOUN',
#  'catteris_X',
#  'bierlow_NOUN',
#  'solleret_NOUN',
#  'vhalley_NOUN',
#  'wellwooded_VERB',
#  'habitum_NOUN',
#  'uudor_ADP',
#  'subsalts_NOUN',
#  'selfe_X',
#  'hlmself_PRON',
#  'aurinia_NOUN',
#  'avillage_NOUN',
#  'keepinge_NOUN',
#  'peucedanum_NOUN',
#  'feste_VERB',
#  'busman_NOUN',
#  'servabit_X',
#  'conposition_NOUN',
#  'ueher_NOUN',
#  'weri_VERB',
#  'insieme_ADJ',
#  'falcatus_NOUN',
#  'shehad_VERB',
#  'peray_NOUN',
#  'righte_VERB',
#  'taly_ADV',
#  'overtaketh_ADV',
#  'galwny_NOUN',
#  'nonus_NOUN',
#  'iun_VERB',
#  'emptie_VERB',
#  'erical_ADJ',
#  'patroness_ADJ',
#  'hackwood_NOUN',
#  'vessex_NOUN',
#  'foreshowing_NOUN',
#  'cadwaladr_NOUN',
#  'comprehende_VERB',
#  'vincing_NOUN',
#  'oubril_NOUN',
#  'deformity_ADJ',
#  'gwyther_NOUN',
#  'nodis_X',
#  'etv_NOUN',
#  'unstinting_ADJ',
#  'unsportsmanlike_ADJ',
#  'llary_NOUN',
#  'anglcterre_NOUN',
#  'carmunnock_NOUN',
#  'apoda_NOUN',
#  'gweedore_NOUN',
#  'reflexion_VERB',
#  'londoo_NOUN',
#  'steill_NOUN',
#  'unsifted_VERB',
#  'oldman_NOUN',
#  'vedantists_NOUN',
#  'pughe_NOUN',
#  'cusparia_NOUN',
#  'birdcatchers_NOUN',
#  'pretendit_NOUN',
#  'tendit_X',
#  'jurisprudents_NOUN',
#  'settembre_NOUN',
#  'prankt_NOUN',
#  'harmonising_NOUN',
#  'justled_VERB',
#  'torthorwald_NOUN',
#  'verschoyle_NOUN',
#  'maroc_NOUN',
#  'densiflorum_NOUN',
#  'cornopean_NOUN',
#  'apiocrinus_NOUN',
#  'xvijth_NOUN',
#  'weddington_NOUN',
#  'britannice_NOUN',
#  'fld_ADV',
#  'lepido_NOUN',
#  'suppressive_ADJ',
#  'fagged_ADJ',
#  'doppler_NOUN',
#  'tricoupi_NOUN',
#  'sorciers_NOUN',
#  'divel_NOUN',
#  'hypogea_NOUN',
#  'tetty_NOUN',
#  'antwerpiae_NOUN',
#  'donderry_NOUN',
#  'britayne_NOUN',
#  'carriageroad_NOUN',
#  'penlee_NOUN',
#  'commers_NOUN',
#  'tomkyns_NOUN',
#  'estoppel_ADJ',
#  'raisable_NOUN',
#  'tabbe_NOUN',
#  'attendaunce_NOUN',
#  'dispels_NOUN',
#  'jamar_NOUN',
#  'dubing_NOUN',
#  'finsbury_ADJ',
#  'manockjee_NOUN',
#  'womica_NOUN',
#  'bignesse_NOUN',
#  'dusart_NOUN',
#  'everdingen_NOUN',
#  'tuto_PRT',
#  'underlyne_NOUN',
#  'dedita_X',
#  'disegno_NOUN',
#  'madhu_NOUN',
#  'tonning_NOUN',
#  'loninox_NOUN',
#  'tobermory_NOUN',
#  'caligraphic_ADJ',
#  'shillibeer_NOUN',
#  'statoment_NOUN',
#  'slabby_ADJ',
#  'antennis_VERB',
#  'ellerman_NOUN',
#  'laneous_NOUN',
#  'taedium_NOUN',
#  'borodale_NOUN',
#  'iough_ADP',
#  'jousters_NOUN',
#  'soumettre_X',
#  'gunne_NOUN',
#  'malcolms_NOUN',
#  'letizia_NOUN',
#  'schottus_NOUN',
#  'sequent_X',
#  'amne_X',
#  'verygreat_NOUN',
#  'northwold_NOUN',
#  'benholme_NOUN',
#  'asserunt_X',
#  'concione_X',
#  'donshire_NOUN',
#  'cobts_NOUN',
#  'ramsgill_NOUN',
#  'combretum_NOUN',
#  'rtion_VERB',
#  'cernis_X',
#  'uii_X',
#  'baffaelle_NOUN',
#  'altrincham_NOUN',
#  'contulit_NOUN',
#  'fosteriana_NOUN',
#  'torksey_NOUN',
#  'puerile_ADV',
#  'gaetulians_NOUN',
#  'muthill_NOUN',
#  'yelept_ADP',
#  'claydon_NOUN',
#  'bashall_NOUN',
#  'moones_NOUN',
#  'inthey_NOUN',
#  'ouvirandra_NOUN',
#  'beatorum_X',
#  'anythe_DET',
#  'relinquit_NOUN',
#  'flyeth_VERB',
#  'catena_X',
#  'palacky_NOUN',
#  'dicti_VERB',
#  'batailles_NOUN',
#  'supercargo_VERB',
#  'pallipes_NOUN',
#  'thedirectors_NOUN',
#  'voglio_X',
#  'urraca_NOUN',
#  'maills_NOUN',
#  'commentarios_NOUN',
#  'bearsted_NOUN',
#  'emended_ADJ',
#  'lion_X',
#  'besurrection_NOUN',
#  'oleifera_NOUN',
#  'eumpe_NOUN',
#  'hochheimer_NOUN',
#  'unkindled_VERB',
#  'principaliter_X',
#  'doa_VERB',
#  'runne_NOUN',
#  'yew_NUM',
#  'giardino_NOUN',
#  'wattr_NOUN',
#  'zua_NOUN',
#  'pleins_X',
#  'dispaire_NOUN',
#  'forchammer_NOUN',
#  'halfyear_ADJ',
#  'opprest_ADP',
#  'pearch_NOUN',
#  'cantreds_NOUN',
#  'cheynell_NOUN',
#  'grosrenor_NOUN',
#  'xij_X',
#  'misdemean_VERB',
#  'lautour_NOUN',
#  'barwicke_NOUN',
#  'aspdin_NOUN',
#  'pridmore_NOUN',
#  'edlin_NOUN',
#  'reinet_NOUN',
#  'biseiop_NOUN',
#  'bellon_NOUN',
#  'preit_NOUN',
#  'ntent_NOUN',
#  'keevil_NOUN',
#  'chaunce_VERB',
#  'tropicus_NOUN',
#  'othes_VERB',
#  'uet_VERB',
#  'culliford_NOUN',
#  'geffery_NOUN',
#  'vetusta_NOUN',
#  'ormston_NOUN',
#  'selous_NOUN',
#  'edgware_ADJ',
#  'bagborough_NOUN',
#  'llle_X',
#  'nowthe_DET',
#  'fordshire_NUM',
#  'sirnamed_VERB',
#  'bergue_NOUN',
#  'apostolicam_NOUN',
#  'fust_ADV',
#  'ndently_ADV',
#  'seil_X',
#  'corngrowing_NOUN',
#  'bcott_NOUN',
#  'pondichery_NOUN',
#  'dissimulating_NOUN',
#  'concavo_X',
#  'rustat_NOUN',
#  'andwhite_ADJ',
#  'graystock_NOUN',
#  'englandand_NOUN',
#  'mappe_NOUN',
#  'bolinbroke_NOUN',
#  'ipsissima_X',
#  'girdlestone_NOUN',
#  'creich_NOUN',
#  'jnn_ADV',
#  'haill_DET',
#  'partc_ADJ',
#  'unfortuuately_ADV',
#  'anwoth_NOUN',
#  'brahmanical_NOUN',
#  'acquapendente_NOUN',
#  'alfgar_NOUN',
#  'falcate_VERB',
#  'shamefull_ADJ',
#  'inedita_X',
#  'coy_VERB',
#  'seealso_NOUN',
#  'fae_ADV',
#  'beccafumi_NOUN',
#  'antiphonary_NOUN',
#  'bewept_ADP',
#  'burgum_NOUN',
#  'vetus_ADJ',
#  'volatilisation_NOUN',
#  'mortmain_VERB',
#  'suddaine_ADJ',
#  'ecclesle_NOUN',
#  'abershaw_NOUN',
#  'understandest_ADP',
#  'redacta_X',
#  'mislikes_VERB',
#  'fierie_NOUN',
#  'soveraign_NOUN',
#  'spectaculis_NOUN',
#  'gosden_NOUN',
#  'cesarewitch_NOUN',
#  'europam_NOUN',
#  'adulterio_X',
#  'rupibus_X',
#  'lectus_NOUN',
#  'vasis_X',
#  'ovalau_NOUN',
#  'edica_NOUN',
#  'testes_VERB',
#  'convolvulaceae_NOUN',
#  'consignation_NOUN',
#  'bueton_NOUN',
#  'reoognised_VERB',
#  'waile_VERB',
#  'gisters_NOUN',
#  'courtmartial_ADJ',
#  'aemilian_NOUN',
#  'clamour_ADJ',
#  'lyinge_NOUN',
#  ...}

# %%
def top_counts(dictionary, count_type, num_hits=500, head = True):
    return OrderedDict(sorted(dictionary.items(), key=lambda x: x[1][count_type], reverse=head)[:num_hits])

# %%
amer_uniq_median_usage = {word:AMER_1851_1900_STEP1[word]['median_usage'] for word in amer_unique_1851_1900_s1}
amer_uniq_median_usage
# Out:
# {'broaddus_NOUN': 155.5,
#  'mittances_NOUN': 9.5,
#  'tippah_NOUN': 152.5,
#  'haydenville_NOUN': 86.5,
#  'lieves_ADJ': 15.5,
#  'era_ADJ': 12.5,
#  'alka_DET': 7.5,
#  'edgetools_NOUN': 11.0,
#  'oslin_NOUN': 13.0,
#  'aspirated_NOUN': 47.5,
#  'elderkin_NOUN': 192.0,
#  'andbe_VERB': 18.0,
#  'reasoni_NOUN': 10.0,
#  'lillis_NOUN': 46.0,
#  'imilitary_ADJ': 12.0,
#  'ctrine_NOUN': 12.0,
#  'juae_NOUN': 11.0,
#  'matthisson_NOUN': 19.0,
#  'eulogistic_NOUN': 23.5,
#  'motherwort_NOUN': 28.5,
#  'democratie_NOUN': 14.0,
#  'avcrment_NOUN': 27.0,
#  'intereourse_NOUN': 38.5,
#  'crawfordville_NOUN': 60.0,
#  'morelos_NOUN': 146.0,
#  'towar_VERB': 14.0,
#  'alenc_NOUN': 10.5,
#  'soriously_ADV': 7.0,
#  'aci_X': 10.0,
#  'aecursed_VERB': 7.0,
#  'critchlow_NOUN': 72.5,
#  'vitiatc_VERB': 8.0,
#  'manycolored_VERB': 28.5,
#  'keang_NOUN': 63.5,
#  'aflidavit_VERB': 36.5,
#  'committecs_NOUN': 7.5,
#  'hillegas_NOUN': 107.5,
#  'demonstrativeness_NOUN': 55.5,
#  'lorent_NOUN': 14.0,
#  'similc_ADJ': 13.0,
#  'shaii_VERB': 34.5,
#  'jimeson_NOUN': 17.0,
#  'gtain_NOUN': 9.0,
#  'enfeoffment_NOUN': 14.0,
#  'goodnight_ADJ': 14.0,
#  'nrw_ADJ': 7.0,
#  'dve_ADJ': 9.5,
#  'seeknofurther_NOUN': 16.0,
#  'losee_NOUN': 222.5,
#  'irre_VERB': 11.0,
#  'rtnd_VERB': 8.0,
#  'mport_NOUN': 8.0,
#  'propaga_NOUN': 14.0,
#  'respecta_ADJ': 26.0,
#  'conferee_NOUN': 1204.5,
#  'eontinned_VERB': 7.0,
#  'bockland_NOUN': 20.0,
#  'milley_NOUN': 28.0,
#  'abort_ADP': 8.5,
#  'mellett_NOUN': 56.0,
#  'terrc_NOUN': 26.0,
#  'unfrozen_ADV': 10.0,
#  'hypoc_NOUN': 7.0,
#  'breadstufls_NOUN': 25.0,
#  'tient_ADJ': 31.5,
#  'aunts_VERB': 15.0,
#  'itated_ADJ': 11.0,
#  'igher_ADJ': 9.0,
#  'karris_NOUN': 12.5,
#  'onment_X': 16.5,
#  'limitable_ADJ': 15.0,
#  'slo_ADJ': 16.0,
#  'vendce_NOUN': 56.0,
#  'jurisiction_NOUN': 19.5,
#  'trape_NOUN': 9.5,
#  'galuppi_NOUN': 26.5,
#  'jerusha_NOUN': 590.0,
#  'abclard_NOUN': 12.0,
#  'cyzicenus_NOUN': 23.0,
#  'pennsy_NOUN': 95.0,
#  'cotrustees_NOUN': 25.5,
#  'branchville_NOUN': 186.5,
#  'ancients_VERB': 12.0,
#  'cargoes_VERB': 34.5,
#  'imbursement_ADJ': 70.5,
#  'syphilides_NOUN': 156.5,
#  'olficially_ADV': 7.5,
#  'abandone_NOUN': 13.0,
#  'pausa_NOUN': 14.0,
#  'interblending_VERB': 18.5,
#  'mosher_NOUN': 1616.0,
#  'ntially_ADV': 29.5,
#  'outdoors_ADV': 53.0,
#  'presidentpro_NOUN': 10.5,
#  'possibili_NOUN': 19.0,
#  'adage_ADJ': 11.0,
#  'neu_VERB': 18.0,
#  'impossibilia_X': 17.5,
#  'acure_NOUN': 9.5,
#  'colector_NOUN': 17.0,
#  'carnification_NOUN': 25.0,
#  'keitt_NOUN': 220.5,
#  'rctorted_VERB': 8.0,
#  'pcrley_NOUN': 8.5,
#  'commuter_NOUN': 77.0,
#  'munfordsville_NOUN': 53.5,
#  'satford_NOUN': 19.5,
#  'poiton_NOUN': 11.0,
#  'menobranchus_NOUN': 47.0,
#  'omro_NOUN': 184.0,
#  'heartand_NOUN': 7.0,
#  'meder_NOUN': 38.0,
#  'mpathies_NOUN': 12.0,
#  'susquehan_NOUN': 9.0,
#  'tieated_VERB': 10.0,
#  'defectives_NOUN': 61.0,
#  'counrv_NOUN': 16.0,
#  'insterburg_NOUN': 16.0,
#  'previde_VERB': 18.0,
#  'mislaying_NOUN': 12.5,
#  'odicers_NOUN': 51.0,
#  'barnyard_ADJ': 381.0,
#  'relatious_NOUN': 36.5,
#  'pnle_NOUN': 6.0,
#  'drier_VERB': 31.5,
#  'resolver_NOUN': 20.0,
#  'profondeur_X': 13.0,
#  'samucl_NOUN': 20.0,
#  'glick_NOUN': 89.5,
#  'pentangular_ADJ': 13.5,
#  'phylarchus_NOUN': 20.0,
#  'freeth_VERB': 9.0,
#  'pounding_NOUN': 18.0,
#  'lmnd_NOUN': 8.5,
#  'consecu_ADJ': 17.5,
#  'messico_NOUN': 62.0,
#  'gressional_ADJ': 98.0,
#  'criptures_NOUN': 9.0,
#  'matne_NOUN': 6.0,
#  'aldert_NOUN': 17.0,
#  'allud_VERB': 10.0,
#  'strictl_ADV': 10.5,
#  'distrib_ADJ': 61.0,
#  'appar_ADV': 37.0,
#  'matcrial_ADJ': 12.0,
#  'woodrutf_NOUN': 30.0,
#  'brazilwood_NOUN': 19.5,
#  'ndrew_NOUN': 9.5,
#  'intenser_ADV': 8.0,
#  'taliafero_NOUN': 36.5,
#  'hornung_NOUN': 28.0,
#  'hiy_NOUN': 12.0,
#  'brethreu_NOUN': 10.5,
#  'congar_NOUN': 89.5,
#  'limonite_NOUN': 724.5,
#  'missent_NOUN': 57.5,
#  'compassest_VERB': 17.5,
#  'nueces_NOUN': 652.0,
#  'gilleland_NOUN': 96.5,
#  'custodv_NOUN': 16.5,
#  'paty_NOUN': 135.5,
#  'ality_X': 11.0,
#  'tleman_X': 17.5,
#  'bold_NOUN': 13.5,
#  'exhibiters_NOUN': 88.5,
#  'sefiores_NOUN': 18.5,
#  'agair_ADV': 13.0,
#  'boquets_NOUN': 56.0,
#  'rozell_NOUN': 32.0,
#  'kiw_NOUN': 10.5,
#  'inculeated_VERB': 21.0,
#  'provincetown_NOUN': 1256.0,
#  'pathway_VERB': 12.0,
#  'uz_X': 20.5,
#  'truxton_NOUN': 313.0,
#  'scretary_NOUN': 8.0,
#  'alabaina_NOUN': 16.0,
#  'twentyfour_ADJ': 18.0,
#  'iiio_NOUN': 22.0,
#  'foust_NOUN': 214.5,
#  'ponchartrain_NOUN': 133.5,
#  'carmalt_NOUN': 100.5,
#  'ringbones_NOUN': 27.5,
#  'snarly_ADJ': 10.5,
#  'itichmond_NOUN': 22.5,
#  'peopic_NOUN': 7.0,
#  'fraterna_NOUN': 34.0,
#  'hydrant_ADJ': 448.0,
#  'congressin_NOUN': 16.0,
#  'fronv_ADP': 5.0,
#  'rootstown_NOUN': 26.0,
#  'leurn_VERB': 10.0,
#  'papula_NOUN': 51.0,
#  'reaeh_NOUN': 11.0,
#  'erward_NOUN': 9.5,
#  'mornlng_NOUN': 7.0,
#  'pontoosuc_NOUN': 65.0,
#  'medley_PRON': 8.0,
#  'siarth_NOUN': 16.5,
#  'locatiou_NOUN': 48.5,
#  'incorporat_NOUN': 14.0,
#  'dletown_NOUN': 12.0,
#  'pamelia_NOUN': 210.0,
#  'archemorus_NOUN': 8.0,
#  'scientifics_NOUN': 80.0,
#  'prono_NOUN': 11.5,
#  'formey_NOUN': 26.0,
#  'urrection_NOUN': 22.5,
#  'resscd_NOUN': 6.0,
#  'ffrancis_VERB': 29.5,
#  'intui_ADJ': 12.0,
#  'forand_NOUN': 10.0,
#  'helievers_NOUN': 9.0,
#  'mclanc_NOUN': 13.0,
#  'parking_NOUN': 156.0,
#  'eutering_VERB': 26.0,
#  'amaz_ADJ': 9.0,
#  'informational_ADJ': 15.0,
#  'plea_X': 12.0,
#  'scrve_VERB': 10.5,
#  'pnetors_NOUN': 9.5,
#  'mcginn_NOUN': 115.5,
#  'silvee_NOUN': 13.5,
#  'fiie_VERB': 10.0,
#  'iousness_NOUN': 13.5,
#  'periors_NOUN': 8.5,
#  'inadvertantly_ADV': 30.0,
#  'iail_NOUN': 26.0,
#  'commorant_NOUN': 26.0,
#  'harrv_NOUN': 26.5,
#  'rivertown_NOUN': 9.5,
#  'rranged_VERB': 13.0,
#  'ulcere_NOUN': 20.0,
#  'emment_ADJ': 19.0,
#  'aldermcn_NOUN': 17.5,
#  'presdent_NOUN': 42.0,
#  'cassopolis_NOUN': 111.0,
#  'closen_VERB': 9.5,
#  'nouvelles_ADJ': 10.5,
#  'meachum_NOUN': 12.5,
#  'inlisted_VERB': 68.0,
#  'swaar_NOUN': 127.0,
#  'ailroad_NOUN': 126.5,
#  'rhap_NOUN': 7.0,
#  'pensons_NOUN': 12.0,
#  'hera_ADV': 10.0,
#  'coutinue_VERB': 49.5,
#  'whitneyville_NOUN': 73.5,
#  'alwas_NOUN': 14.0,
#  'ribault_NOUN': 244.0,
#  'wituess_VERB': 12.5,
#  'fety_NOUN': 11.5,
#  'slandering_ADJ': 9.0,
#  'peritonaeum_NOUN': 440.0,
#  'ncement_NOUN': 9.0,
#  'thejustice_DET': 16.0,
#  'interferance_NOUN': 14.0,
#  'puie_NOUN': 11.0,
#  'lucins_NOUN': 50.0,
#  'oldier_NOUN': 8.0,
#  'pastorius_NOUN': 116.0,
#  'stimated_VERB': 26.5,
#  'allotropism_NOUN': 59.5,
#  'crip_VERB': 8.0,
#  'musser_NOUN': 375.5,
#  'obserration_NOUN': 12.0,
#  'whitcfield_NOUN': 11.5,
#  'johnb_NOUN': 21.0,
#  'dved_VERB': 7.0,
#  'nasn_NOUN': 12.5,
#  'seuate_NOUN': 186.0,
#  'wappinger_NOUN': 176.0,
#  'eripuit_NOUN': 20.5,
#  'payday_NOUN': 23.0,
#  'buttermaking_NOUN': 21.0,
#  'indoctrinating_NOUN': 10.0,
#  'crimpled_VERB': 16.0,
#  'paraiso_NOUN': 11.0,
#  'seasoin_NOUN': 9.0,
#  'pursuin_VERB': 17.5,
#  'generalife_NOUN': 59.5,
#  'complcte_NOUN': 8.5,
#  'inanifested_VERB': 10.0,
#  'nnns_NOUN': 9.0,
#  'nellis_NOUN': 402.0,
#  'nier_X': 12.0,
#  'muskcts_NOUN': 18.0,
#  'amelung_NOUN': 47.5,
#  'confederatcs_NOUN': 11.0,
#  'ichat_ADP': 9.0,
#  'ilagar_NOUN': 12.5,
#  'monse_NOUN': 15.0,
#  'follbwing_NOUN': 5.5,
#  'choteau_NOUN': 215.5,
#  'sheath_ADJ': 29.0,
#  'formi_ADV': 15.5,
#  'terrifie_NOUN': 8.5,
#  'parchaser_NOUN': 13.5,
#  'desola_ADJ': 9.0,
#  'toombs_NOUN': 1341.0,
#  'dervis_NOUN': 26.0,
#  'tillary_NOUN': 25.0,
#  'strob_NOUN': 257.0,
#  'progressional_ADJ': 14.5,
#  'rit_ADJ': 10.0,
#  'sebec_NOUN': 79.0,
#  'committoo_NOUN': 13.0,
#  'kiersted_NOUN': 156.0,
#  'falley_NOUN': 125.0,
#  'discomfitted_ADJ': 10.0,
#  'rliode_NOUN': 13.0,
#  'polleys_NOUN': 59.5,
#  'winfleld_NOUN': 62.0,
#  'cracken_NOUN': 22.5,
#  'orcible_ADJ': 9.0,
#  'yoko_NOUN': 12.0,
#  'tinguishment_NOUN': 11.5,
#  'eformed_VERB': 9.0,
#  'larjre_ADJ': 13.0,
#  'catoctin_NOUN': 120.0,
#  'adwise_VERB': 8.0,
#  'assections_NOUN': 15.0,
#  'thereot_ADV': 52.5,
#  'iiundreds_NOUN': 6.0,
#  'tbo_PRT': 17.0,
#  'odiorne_NOUN': 278.5,
#  'flander_NOUN': 21.0,
#  'whitestown_NOUN': 376.0,
#  'freemansburg_NOUN': 30.0,
#  'hicksville_NOUN': 125.5,
#  'keiffer_NOUN': 42.5,
#  'dcsire_NOUN': 14.0,
#  'thorn_X': 12.0,
#  'frinch_NOUN': 11.0,
#  'laminze_NOUN': 10.0,
#  'tribumal_NOUN': 15.5,
#  'unsinged_VERB': 14.0,
#  'fagle_NOUN': 9.0,
#  'rcco_NOUN': 8.5,
#  'emmitt_NOUN': 67.0,
#  'exclusire_NOUN': 11.0,
#  'delaficld_NOUN': 8.0,
#  'situdes_NOUN': 15.0,
#  'typhoidal_ADJ': 44.5,
#  'encmata_NOUN': 12.0,
#  'dys_VERB': 13.0,
#  'yclept_VERB': 11.5,
#  'deshon_NOUN': 134.5,
#  'cheery_VERB': 25.0,
#  'foushee_NOUN': 22.5,
#  'anama_NOUN': 15.0,
#  'trunkmaker_NOUN': 26.0,
#  'grd_NOUN': 100.5,
#  'hershey_NOUN': 292.5,
#  'eauses_VERB': 8.0,
#  'outto_PRT': 12.5,
#  'gelatiniform_NOUN': 49.5,
#  'lick_ADV': 9.0,
#  'instrusted_VERB': 15.0,
#  'averell_NOUN': 217.5,
#  'quors_NOUN': 23.5,
#  'appropi_NOUN': 11.0,
#  'ingersoli_NOUN': 29.0,
#  'whorn_ADV': 8.0,
#  'hoads_NOUN': 13.0,
#  'forkful_NOUN': 39.5,
#  'amns_NOUN': 10.5,
#  'carnuntum_NOUN': 17.0,
#  'agreea_DET': 10.0,
#  'bedquilt_NOUN': 42.0,
#  'ainc_NOUN': 7.5,
#  'muhlenburg_NOUN': 259.0,
#  'superinducing_NOUN': 15.0,
#  'aifect_NOUN': 7.5,
#  'estored_VERB': 7.0,
#  'xvlll_NOUN': 10.0,
#  'corlis_NOUN': 40.0,
#  'offiling_VERB': 23.5,
#  'caucus_VERB': 86.0,
#  'sessments_NOUN': 66.5,
#  'thar_PRON': 26.5,
#  'uniformity_VERB': 12.0,
#  'minthorne_NOUN': 28.5,
#  'rnan_ADJ': 12.0,
#  'schuman_NOUN': 91.0,
#  'verrazani_NOUN': 22.0,
#  'fresher_VERB': 24.5,
#  'unparal_ADJ': 15.0,
#  'deferent_NOUN': 11.0,
#  'determiue_VERB': 48.0,
#  'hrve_VERB': 10.5,
#  'munsees_NOUN': 134.0,
#  'jhad_NOUN': 7.0,
#  'olated_VERB': 8.0,
#  'hellman_NOUN': 182.0,
#  'menuments_NOUN': 8.0,
#  'wakeful_VERB': 12.0,
#  'rounsville_NOUN': 13.0,
#  'construet_VERB': 6.0,
#  'deaton_NOUN': 48.0,
#  'exbausted_VERB': 13.0,
#  'chanic_NOUN': 32.0,
#  'receivcd_NOUN': 6.0,
#  'purbach_NOUN': 18.0,
#  'liuve_VERB': 11.5,
#  'lamott_NOUN': 21.0,
#  'octobert_NOUN': 12.0,
#  'cacalia_NOUN': 40.0,
#  'hizo_NOUN': 9.5,
#  'churchwell_NOUN': 39.0,
#  'reg_ADV': 24.5,
#  'verally_ADV': 6.0,
#  'geveral_ADJ': 10.5,
#  'ackerly_NOUN': 74.0,
#  'fullblooded_ADJ': 20.5,
#  'williarns_NOUN': 12.0,
#  'disinte_NOUN': 14.5,
#  'fairminded_VERB': 55.0,
#  'azedarach_NOUN': 20.0,
#  'guzmans_NOUN': 19.0,
#  'croir_NOUN': 19.0,
#  'pario_NOUN': 24.5,
#  'decadence_X': 12.0,
#  'whirh_VERB': 14.0,
#  'arvine_NOUN': 68.5,
#  'ceeds_ADJ': 14.0,
#  'aade_VERB': 6.0,
#  'conduire_NOUN': 11.5,
#  'urch_VERB': 10.0,
#  'rms_ADJ': 7.0,
#  'qut_ADJ': 9.0,
#  'builion_NOUN': 20.0,
#  'sortifications_NOUN': 38.5,
#  'sustaiu_VERB': 24.0,
#  'thouglit_NOUN': 7.0,
#  'edenburg_NOUN': 48.5,
#  'yoe_NOUN': 90.0,
#  'oolor_NOUN': 68.5,
#  'moyamensing_NOUN': 288.5,
#  'physioian_NOUN': 19.5,
#  'eveh_ADV': 16.5,
#  'jouett_NOUN': 163.5,
#  'enciente_ADV': 16.0,
#  'jusjurandum_NOUN': 14.0,
#  'pictur_ADJ': 29.0,
#  'nniversally_ADV': 6.0,
#  'privil_ADJ': 22.0,
#  'retary_VERB': 30.0,
#  'hollinger_NOUN': 89.5,
#  'adiourn_VERB': 19.5,
#  'velsor_NOUN': 17.5,
#  'ngree_VERB': 11.0,
#  'gratui_NOUN': 8.0,
#  'pefore_VERB': 18.0,
#  'licr_ADP': 18.0,
#  'inelosed_ADJ': 11.0,
#  'inanners_NOUN': 14.0,
#  'dicial_NOUN': 38.0,
#  'blackhawk_NOUN': 170.0,
#  'hubbardston_NOUN': 419.5,
#  'cabeza_X': 19.5,
#  'willams_NOUN': 26.0,
#  'vcxation_NOUN': 13.0,
#  'slayton_NOUN': 232.0,
#  'cqunty_NOUN': 6.0,
#  'jehovah_X': 18.5,
#  'irenams_NOUN': 21.0,
#  'norristown_NOUN': 938.5,
#  'apologet_NOUN': 16.5,
#  'cmbracing_VERB': 17.0,
#  'yaphank_NOUN': 32.0,
#  'finery_ADV': 13.0,
#  'remediless_ADJ': 43.5,
#  'sonl_ADJ': 11.0,
#  'likin_VERB': 21.5,
#  'kinkle_NOUN': 27.5,
#  'uavy_NOUN': 13.0,
#  'ncre_NOUN': 14.0,
#  'thfl_VERB': 7.0,
#  'muldrow_NOUN': 154.5,
#  'legare_NOUN': 347.5,
#  'monroeville_NOUN': 193.5,
#  'bouchette_NOUN': 41.0,
#  'fostoria_NOUN': 151.0,
#  'davidsons_NOUN': 19.5,
#  'heeney_NOUN': 46.0,
#  'noae_NOUN': 6.0,
#  'iioratio_NOUN': 17.5,
#  'influcnce_NOUN': 16.5,
#  'unul_ADJ': 10.0,
#  'floridan_NOUN': 30.5,
#  'glenmary_NOUN': 30.5,
#  'oping_NOUN': 11.5,
#  'juhe_NOUN': 9.0,
#  'papiria_NOUN': 26.5,
#  'neces_ADJ': 21.5,
#  'teeling_NOUN': 23.5,
#  'ict_X': 11.0,
#  'marbourg_NOUN': 30.5,
#  'balcs_NOUN': 8.0,
#  'jusi_NOUN': 11.0,
#  'finil_VERB': 11.0,
#  'mccrary_NOUN': 1868.0,
#  'rootless_NOUN': 16.0,
#  'huestis_NOUN': 117.5,
#  'hanah_NOUN': 33.0,
#  'endeav_VERB': 62.5,
#  'appara_X': 7.0,
#  'servances_NOUN': 11.5,
#  'conce_VERB': 14.0,
#  'ptople_NOUN': 10.5,
#  'hamus_NOUN': 12.5,
#  'rhodanus_NOUN': 32.5,
#  'thd_DET': 8.0,
#  'dcmanded_VERB': 11.0,
#  'tezas_NOUN': 9.5,
#  'foretaste_VERB': 8.0,
#  'dauiel_NOUN': 58.0,
#  'musconetcong_NOUN': 108.0,
#  'ancurism_NOUN': 14.0,
#  'honss_NOUN': 11.0,
#  'chainman_NOUN': 69.5,
#  'daga_NOUN': 20.5,
#  'persecting_VERB': 14.0,
#  'shclburne_NOUN': 12.5,
#  'ruckman_NOUN': 278.5,
#  'benamin_NOUN': 29.5,
#  'fessendcn_NOUN': 13.0,
#  'wrightman_NOUN': 21.5,
#  'eountries_NOUN': 25.5,
#  'harmstead_NOUN': 13.0,
#  'ininded_ADJ': 8.5,
#  'refusod_VERB': 6.5,
#  'ohap_X': 16.5,
#  'sowu_NOUN': 14.0,
#  'lamon_NOUN': 285.5,
#  'ubout_PRT': 12.0,
#  'ehancery_NOUN': 38.5,
#  'ybu_NOUN': 9.0,
#  'ebery_ADJ': 40.0,
#  'mobocratic_ADJ': 34.0,
#  'hhall_VERB': 9.0,
#  'washingt_NOUN': 82.0,
#  'hepp_NOUN': 55.0,
#  'ture_ADV': 9.0,
#  'hainilton_NOUN': 12.0,
#  'mizzen_NUM': 21.0,
#  'broom_VERB': 52.5,
#  'resid_VERB': 8.0,
#  'vestigio_X': 8.0,
#  'arsdale_NOUN': 221.5,
#  'practition_NOUN': 13.0,
#  'spitler_NOUN': 75.5,
#  'nection_VERB': 14.5,
#  'boettcher_NOUN': 92.0,
#  'riehardson_NOUN': 13.0,
#  'insano_NOUN': 16.5,
#  'exsiccate_VERB': 39.5,
#  'forfcitures_NOUN': 11.0,
#  'forgetfnlness_NOUN': 13.0,
#  'josr_NOUN': 10.0,
#  'felter_NOUN': 249.0,
#  'conucted_VERB': 10.0,
#  'thorize_NOUN': 19.5,
#  'lilth_NOUN': 18.5,
#  'seves_NOUN': 8.0,
#  'mbia_NOUN': 22.5,
#  'cce_NOUN': 9.0,
#  'cmbankments_NOUN': 10.0,
#  'abody_ADV': 11.5,
#  'thejustice_NOUN': 41.5,
#  'ligature_X': 24.0,
#  'vroom_NOUN': 931.5,
#  'iladley_NOUN': 34.5,
#  'incumbrauce_NOUN': 11.0,
#  'nesto_NOUN': 7.0,
#  'groff_NOUN': 307.0,
#  'talesman_NOUN': 96.0,
#  'thanged_VERB': 7.0,
#  'principlesof_NOUN': 9.5,
#  'lext_NOUN': 13.0,
#  'anthelminticum_NOUN': 17.0,
#  'mquire_VERB': 6.0,
#  'crable_ADJ': 9.0,
#  'holty_NOUN': 17.0,
#  'uegroes_NOUN': 25.5,
#  'agcnt_NOUN': 12.0,
#  'nolen_NOUN': 184.5,
#  'andbe_DET': 11.0,
#  'oolored_ADJ': 25.0,
#  'watcli_VERB': 9.0,
#  'ledbetter_NOUN': 125.0,
#  'haekett_NOUN': 22.5,
#  'senac_NOUN': 50.0,
#  'convictiou_NOUN': 25.0,
#  'deto_VERB': 10.0,
#  'frontera_NOUN': 125.5,
#  'rightand_NOUN': 14.0,
#  'istration_ADJ': 28.0,
#  'madamoiselle_NOUN': 23.0,
#  'yetthe_DET': 8.0,
#  'linet_NOUN': 10.0,
#  'triai_NOUN': 19.5,
#  'regetable_ADJ': 9.0,
#  'territoiy_NOUN': 10.0,
#  'entine_ADJ': 16.0,
#  'mcclel_NOUN': 45.5,
#  'untit_VERB': 7.5,
#  'vandervoort_NOUN': 141.5,
#  'beeome_NOUN': 18.5,
#  'hopefield_NOUN': 59.0,
#  'gradior_NOUN': 10.5,
#  'saidhe_NOUN': 10.0,
#  'llie_X': 10.5,
#  'hif_VERB': 8.0,
#  'wintbrop_NOUN': 16.5,
#  'locofocos_NOUN': 21.0,
#  'calorem_X': 25.5,
#  'ncr_ADJ': 10.0,
#  'curtisville_NOUN': 22.5,
#  'yrork_NOUN': 23.0,
#  'donbtless_VERB': 8.0,
#  'bladensburgh_NOUN': 42.0,
#  'mcrrimac_NOUN': 29.5,
#  'abattle_NOUN': 9.0,
#  'ncar_ADJ': 11.0,
#  'woodless_ADJ': 14.0,
#  'iissouri_NOUN': 20.0,
#  'geeene_NOUN': 12.5,
#  'washiugton_NOUN': 51.0,
#  'rockett_NOUN': 56.5,
#  'bursted_ADJ': 31.0,
#  'kerioth_NOUN': 43.0,
#  'plentier_ADJ': 25.0,
#  'cieza_NOUN': 55.5,
#  'pusson_NOUN': 50.5,
#  'nees_X': 9.0,
#  'zachos_NOUN': 60.0,
#  'campville_NOUN': 18.0,
#  'willimantic_NOUN': 539.5,
#  'peopleof_NOUN': 23.0,
#  'dutcher_NOUN': 1204.0,
#  'frcsh_ADJ': 9.0,
#  'broadaxe_NOUN': 19.5,
#  'authorily_NOUN': 9.0,
#  'ific_NOUN': 16.5,
#  'tlass_NOUN': 7.0,
#  'fcnd_VERB': 12.0,
#  'enrollment_VERB': 66.0,
#  'currences_NOUN': 18.0,
#  'fishbough_NOUN': 13.5,
#  'appropri_ADV': 46.5,
#  'genevae_NOUN': 14.0,
#  'vvayne_NOUN': 22.5,
#  'eiferson_NUM': 112.5,
#  'presant_ADJ': 15.0,
#  'perpet_ADJ': 30.0,
#  'infelice_NOUN': 16.0,
#  'beei_ADV': 9.0,
#  'limest_ADJ': 8.0,
#  'gousset_NOUN': 19.0,
#  'gacity_NOUN': 16.0,
#  'ows_ADV': 15.0,
#  'liabil_ADJ': 43.0,
#  'pensi_NOUN': 22.0,
#  'bokkelen_NOUN': 137.5,
#  'armon_NOUN': 23.0,
#  'townsen_NOUN': 56.0,
#  'vvhcn_NOUN': 11.0,
#  'ofindividuals_NOUN': 18.5,
#  'chaldce_NOUN': 14.0,
#  'reetitude_NOUN': 9.0,
#  'perman_ADJ': 14.5,
#  'nuremberg_ADJ': 11.5,
#  'nything_VERB': 8.5,
#  'pulsat_NOUN': 45.5,
#  'brownville_NOUN': 439.0,
#  'febiger_NOUN': 126.5,
#  'deadl_VERB': 7.0,
#  'praator_NOUN': 17.0,
#  'villiarns_NOUN': 7.5,
#  'otherwis_ADJ': 10.0,
#  'alabamian_NOUN': 130.5,
#  'incar_NOUN': 11.5,
#  'conversed_NOUN': 16.0,
#  'litth_ADJ': 9.0,
#  'respectully_ADV': 13.0,
#  'uritans_NOUN': 8.0,
#  'jumonville_NOUN': 152.5,
#  'nabas_NOUN': 8.0,
#  'toxas_NOUN': 28.5,
#  'hjm_VERB': 12.0,
#  'tru_ADJ': 6.5,
#  'whittcmore_NOUN': 12.5,
#  'salse_ADJ': 12.0,
#  'acterize_VERB': 15.0,
#  'crystalized_ADJ': 92.0,
#  'hcn_NOUN': 14.5,
#  'beeh_ADP': 7.0,
#  'otra_ADJ': 12.5,
#  'paptr_NOUN': 8.0,
#  'ilove_VERB': 14.0,
#  'artil_ADJ': 56.5,
#  'latane_NOUN': 49.0,
#  'pel_ADV': 19.0,
#  'priestlike_ADJ': 10.0,
#  'ervin_NOUN': 456.5,
#  'governinents_NOUN': 13.0,
#  'cinaloa_NOUN': 26.5,
#  'dnr_NOUN': 6.0,
#  'tolles_NOUN': 497.0,
#  'soregoing_NOUN': 30.5,
#  'encroachinents_NOUN': 8.0,
#  'mcelroy_NOUN': 1287.5,
#  'peyster_NOUN': 742.0,
#  'eline_NOUN': 12.5,
#  'rollest_ADJ': 16.5,
#  'aied_VERB': 15.0,
#  'ihee_NOUN': 9.0,
#  'importation_ADJ': 32.5,
#  'vnited_NOUN': 67.5,
#  'instantl_NOUN': 11.0,
#  'gislative_ADJ': 16.0,
#  'nnan_NOUN': 13.0,
#  'larned_NOUN': 1412.5,
#  'manl_ADJ': 8.0,
#  'exccpt_NOUN': 10.0,
#  'amzi_NOUN': 212.0,
#  'oroform_NOUN': 5.0,
#  'incumbranees_NOUN': 17.5,
#  'sutfer_NOUN': 18.0,
#  'westeott_NOUN': 25.5,
#  'whitcom_NOUN': 16.5,
#  'moial_ADJ': 11.0,
#  'mcalister_NOUN': 394.0,
#  'assassi_NOUN': 11.0,
#  'anfi_DET': 8.0,
#  'curring_ADJ': 30.5,
#  'minkler_NOUN': 98.0,
#  'doten_NOUN': 116.5,
#  'analyzation_NOUN': 58.0,
#  'raub_NOUN': 169.5,
#  'phidippides_NOUN': 15.0,
#  'cual_X': 23.5,
#  'cluims_NOUN': 11.0,
#  'misissippi_NOUN': 37.5,
#  'homet_NOUN': 14.0,
#  'brittanica_NOUN': 59.0,
#  'dnnn_NOUN': 25.0,
#  'daingerfield_NOUN': 67.0,
#  'jegean_ADJ': 10.5,
#  'thenco_NOUN': 11.0,
#  'nfay_VERB': 5.0,
#  'roadily_ADV': 8.5,
#  'recreating_NOUN': 14.0,
#  'frecdom_NOUN': 15.0,
#  'angie_NOUN': 266.5,
#  'ostile_ADJ': 11.0,
#  'approf_NOUN': 16.0,
#  'pharus_NOUN': 16.0,
#  'rhall_NOUN': 14.5,
#  'foreknows_NOUN': 12.0,
#  'laring_VERB': 14.0,
#  'mqre_NOUN': 9.0,
#  'fcar_NOUN': 11.5,
#  'stevia_NOUN': 28.5,
#  'comforta_ADJ': 24.5,
#  'inquirin_VERB': 12.0,
#  'mandatary_NOUN': 151.0,
#  'bushcls_NOUN': 13.5,
#  'odenheimer_NOUN': 123.0,
#  'lackawana_NOUN': 86.5,
#  'pkarm_NOUN': 10.0,
#  'milhau_NOUN': 146.5,
#  'giblites_NOUN': 16.5,
#  'spcaker_NOUN': 9.0,
#  'nilcs_NOUN': 22.0,
#  'ofjudges_NOUN': 33.0,
#  'brooksville_NOUN': 173.5,
#  'infilled_VERB': 10.0,
#  'aeceptance_NOUN': 11.0,
#  'occurrunt_X': 11.0,
#  'inprisoned_VERB': 9.0,
#  'wuh_ADV': 9.0,
#  'laselle_NOUN': 42.5,
#  'fnm_VERB': 10.0,
#  'prudden_NOUN': 174.5,
#  'dishonorable_NOUN': 21.5,
#  'darrein_VERB': 172.5,
#  'expccted_VERB': 10.5,
#  'lilinois_NOUN': 21.0,
#  'izing_ADJ': 42.5,
#  'hardenbergh_NOUN': 494.0,
#  'sssignee_NOUN': 14.5,
#  'humoral_NOUN': 13.5,
#  'dowdney_NOUN': 41.0,
#  'tlue_ADJ': 11.0,
#  'equita_NOUN': 11.5,
#  'disenthrall_VERB': 29.5,
#  'ratify_ADJ': 10.5,
#  'villet_NOUN': 12.0,
#  'milldale_NOUN': 30.0,
#  'vinculis_NOUN': 16.0,
#  'forseveral_ADJ': 15.5,
#  'characier_NOUN': 17.5,
#  'ning_X': 11.0,
#  'cubist_NOUN': 12.0,
#  'runniug_NOUN': 33.0,
#  'mcfingal_NOUN': 75.0,
#  'masher_NOUN': 55.5,
#  'pnrchaser_NOUN': 15.0,
#  'cumston_NOUN': 63.5,
#  'mported_VERB': 14.5,
#  'tiller_ADP': 16.0,
#  'macaulny_NOUN': 9.0,
#  'kilow_VERB': 11.0,
#  'environed_ADJ': 25.5,
#  'futer_NOUN': 19.5,
#  'gruman_NOUN': 24.0,
#  'lorillard_NOUN': 633.0,
#  'shehan_NOUN': 81.5,
#  'pntnam_NOUN': 25.0,
#  'broadwav_NOUN': 59.0,
#  'stcbbins_NOUN': 19.5,
#  'percus_NOUN': 16.0,
#  'licanism_NOUN': 11.0,
#  'conseqence_NOUN': 28.0,
#  'inachines_NOUN': 25.5,
#  'rpose_VERB': 6.5,
#  'sweney_NOUN': 82.0,
#  'riot_ADJ': 12.0,
#  'rosekrans_NOUN': 83.0,
#  'priu_NOUN': 12.0,
#  'frcquently_ADV': 12.0,
#  'dockage_NOUN': 435.0,
#  'bulstr_NOUN': 48.0,
#  'gitimate_VERB': 12.0,
#  'fayerweather_NOUN': 105.0,
#  'arnol_NOUN': 13.0,
#  'raddle_NOUN': 70.0,
#  'nicotina_NOUN': 15.0,
#  'ivt_NOUN': 13.0,
#  'indigent_X': 13.0,
#  'fargo_NOUN': 2067.5,
#  'puberty_ADV': 16.0,
#  'srom_ADV': 8.0,
#  'lidity_NOUN': 49.5,
#  'polyglottus_NOUN': 43.0,
#  'doption_NOUN': 9.0,
#  'campbellsville_NOUN': 100.0,
#  'iinmediately_ADV': 12.0,
#  'dreer_NOUN': 211.0,
#  'atchinson_NOUN': 115.0,
#  'paers_NOUN': 15.0,
#  'learing_NOUN': 15.0,
#  'conset_NOUN': 11.0,
#  'muscogee_NOUN': 573.0,
#  'monikins_NOUN': 27.0,
#  'thcol_NOUN': 23.0,
#  'thent_DET': 6.0,
#  'diffculties_NOUN': 10.0,
#  'vilages_NOUN': 20.0,
#  'positious_ADJ': 21.5,
#  'ordeis_NOUN': 17.0,
#  'tripolitan_NOUN': 211.0,
#  'charriere_NOUN': 50.0,
#  'meagerness_NOUN': 135.5,
#  'variola_VERB': 13.5,
#  'pyxis_NOUN': 15.5,
#  'nealy_NOUN': 62.5,
#  'cuvillier_NOUN': 23.0,
#  'whr_NOUN': 11.5,
#  'despotism_VERB': 13.5,
#  'offens_NOUN': 8.0,
#  'perfluous_ADJ': 11.0,
#  'ishcd_NOUN': 10.5,
#  'tortions_NOUN': 16.5,
#  'partlow_NOUN': 48.0,
#  'burled_ADJ': 16.5,
#  'defrand_VERB': 43.5,
#  'schenectady_ADJ': 37.0,
#  'lawyersville_NOUN': 11.5,
#  'dclos_NOUN': 12.5,
#  'eufchatel_NOUN': 6.0,
#  'eslate_NOUN': 19.0,
#  'thenccforth_DET': 7.0,
#  'jogues_NOUN': 320.5,
#  'kandall_NOUN': 40.0,
#  'seleu_NOUN': 8.0,
#  'busbee_NOUN': 99.0,
#  'repertoire_X': 31.0,
#  'clairns_NOUN': 11.0,
#  'receiva_VERB': 8.0,
#  'barnnm_NOUN': 21.0,
#  'lbe_ADJ': 26.0,
#  'renewings_NOUN': 16.0,
#  'sonrel_NOUN': 21.5,
#  'atlast_VERB': 12.0,
#  'pluperfect_X': 40.0,
#  'mcharg_NOUN': 106.5,
#  'accessable_ADJ': 25.5,
#  'yarieties_NOUN': 14.0,
#  'weirich_NOUN': 32.0,
#  'hankercher_NOUN': 15.5,
#  'rict_VERB': 10.5,
#  'vhenever_ADP': 31.5,
#  'foad_NOUN': 7.0,
#  'ohina_NOUN': 15.0,
#  'nebber_ADV': 38.5,
#  'germana_NOUN': 12.5,
#  'ordar_NOUN': 10.5,
#  'amenta_NOUN': 24.0,
#  'lafavette_NOUN': 33.0,
#  'blooil_NOUN': 7.5,
#  'vanhorn_NOUN': 192.0,
#  'hullers_NOUN': 39.5,
#  'texa_NOUN': 40.5,
#  'mountai_NOUN': 8.0,
#  'udi_ADJ': 12.0,
#  'suttered_VERB': 11.0,
#  'demaud_VERB': 33.5,
#  'agesipolis_NOUN': 49.0,
#  'centurics_NOUN': 12.0,
#  'insuro_VERB': 13.0,
#  'hurl_ADJ': 17.0,
#  'nooga_NOUN': 47.5,
#  'mortised_ADJ': 59.0,
#  'diathcsis_NOUN': 9.0,
#  'behooves_NOUN': 32.0,
#  'pughtown_NOUN': 18.0,
#  'aia_ADP': 5.5,
#  'llc_ADJ': 11.0,
#  'disorganizes_NOUN': 25.5,
#  'honorto_NOUN': 20.5,
#  'thejournals_NOUN': 9.0,
#  'readoption_NOUN': 28.5,
#  'tui_ADJ': 16.5,
#  'smits_NOUN': 29.0,
#  'cureulio_NOUN': 11.0,
#  'grealer_ADJ': 10.0,
#  'reargue_VERB': 34.0,
#  'tinre_NOUN': 7.0,
#  'predation_NOUN': 14.5,
#  'nast_ADV': 8.0,
#  'bellport_NOUN': 39.0,
#  'curts_NOUN': 54.5,
#  'hearti_NOUN': 12.5,
#  'floodwood_NOUN': 12.0,
#  'perrill_NOUN': 40.5,
#  'dran_VERB': 5.5,
#  'ercise_VERB': 38.0,
#  'residingin_VERB': 11.5,
#  'itures_NOUN': 27.0,
#  'desiguated_VERB': 28.0,
#  'mornent_NOUN': 8.0,
#  'sacrum_ADJ': 13.0,
#  'hurning_NOUN': 13.0,
#  'rivei_NOUN': 31.5,
#  'waynesburg_NOUN': 395.0,
#  'anoverdue_NOUN': 10.0,
#  'reemelin_NOUN': 59.5,
#  'anew_ADP': 19.5,
#  'auv_VERB': 22.0,
#  'skc_NOUN': 830.5,
#  'barvard_NOUN': 7.0,
#  'hazelhurst_NOUN': 71.5,
#  'wincing_ADJ': 13.0,
#  'fortney_NOUN': 62.0,
#  'terryville_NOUN': 60.0,
#  'satd_NOUN': 14.5,
#  'hairl_NOUN': 12.0,
#  'wormseed_NOUN': 48.5,
#  'asual_ADJ': 13.0,
#  'factual_ADJ': 27.5,
#  'privale_ADJ': 13.0,
#  'satissaction_NOUN': 16.0,
#  'dillman_NOUN': 120.5,
#  'isracl_NOUN': 21.5,
#  'rensellaer_NOUN': 44.5,
#  'presidtnt_NOUN': 11.5,
#  'desira_ADJ': 30.0,
#  'naragansett_NOUN': 19.0,
#  'notj_VERB': 6.0,
#  'rewere_VERB': 10.5,
#  'cumscribed_VERB': 12.5,
#  'sloat_NOUN': 327.5,
#  'hreaking_VERB': 19.0,
#  'rountree_NOUN': 382.5,
#  'stoies_NOUN': 10.0,
#  'impanneling_NOUN': 26.0,
#  'trogyllium_NOUN': 17.0,
#  'greenbush_NOUN': 970.0,
#  'structcd_NOUN': 7.0,
#  'ciency_VERB': 9.0,
#  'hoj_NOUN': 12.5,
#  'baktlett_NOUN': 19.0,
#  'unsavorable_ADJ': 19.0,
#  'accumbent_NOUN': 35.0,
#  'iays_NOUN': 13.5,
#  'frasier_NOUN': 107.0,
#  ...}

# %%
brit_uniq_median_usage = {word:BRIT_1851_1900_STEP1[word]['median_usage'] for word in brit_unique_1851_1900_s1}
brit_uniq_median_usage
# Out:
# {'cercopithecus_NOUN': 156.0,
#  'mounteney_NOUN': 53.0,
#  'shanking_NOUN': 17.5,
#  'floccose_NOUN': 41.0,
#  'mosse_X': 13.0,
#  'scotophilus_NOUN': 14.0,
#  'saltmarket_NOUN': 95.5,
#  'opusculum_NOUN': 39.0,
#  'leguminosse_NOUN': 37.0,
#  'marcas_NOUN': 31.0,
#  'obstantibus_X': 25.5,
#  'imam_X': 22.0,
#  'kente_NOUN': 32.0,
#  'wellsustained_ADJ': 14.0,
#  'cypricardia_NOUN': 41.0,
#  'bellezza_X': 16.0,
#  'carcinus_NOUN': 83.5,
#  'gelt_ADJ': 13.5,
#  'aart_NOUN': 31.0,
#  'topping_NOUN': 30.0,
#  'appellent_X': 15.5,
#  'outragious_ADJ': 68.5,
#  'ronson_NOUN': 9.5,
#  'jopling_NOUN': 132.5,
#  'funus_NOUN': 14.0,
#  'illfavoured_VERB': 29.0,
#  'wastell_NOUN': 65.0,
#  'denbigh_ADJ': 55.0,
#  'approched_VERB': 42.0,
#  'impersonator_NOUN': 47.5,
#  'titian_ADP': 14.0,
#  'byeword_NOUN': 63.5,
#  'obliger_NOUN': 19.0,
#  'meidias_NOUN': 48.5,
#  'helichrysum_NOUN': 67.5,
#  'thurgood_NOUN': 51.5,
#  'abundle_NOUN': 8.5,
#  'bridg_ADJ': 17.0,
#  'carp_ADJ': 40.5,
#  'lasst_X': 18.0,
#  'wiixiam_NOUN': 9.5,
#  'wyne_VERB': 57.0,
#  'coneludes_NOUN': 7.0,
#  'clod_VERB': 9.0,
#  'bamian_NOUN': 121.5,
#  'pindee_NOUN': 134.5,
#  'salu_X': 7.5,
#  'schooten_NOUN': 22.0,
#  'dinting_NOUN': 22.0,
#  'diatom_NOUN': 1378.0,
#  'illogan_NOUN': 55.5,
#  'puauc_NOUN': 14.5,
#  'chastitie_NOUN': 54.0,
#  'bicardo_NOUN': 34.0,
#  'homb_NOUN': 20.0,
#  'hermajesty_NOUN': 28.0,
#  'eyeservice_NOUN': 15.5,
#  'hunde_NOUN': 16.0,
#  'lowd_ADJ': 31.5,
#  'rchbishop_NOUN': 14.0,
#  'geddington_NOUN': 73.0,
#  'neilston_NOUN': 87.0,
#  'hopen_VERB': 11.5,
#  'preposterous_NOUN': 14.5,
#  'kanta_NOUN': 60.5,
#  'registro_NOUN': 35.5,
#  'encrinite_NOUN': 31.0,
#  'andlords_NOUN': 8.5,
#  'triumphos_X': 15.0,
#  'snaw_ADJ': 19.0,
#  'plotted_ADJ': 31.5,
#  'nio_VERB': 7.0,
#  'liquorice_ADJ': 11.5,
#  'cinderford_NOUN': 72.5,
#  'doneaster_NOUN': 27.5,
#  'woollacott_NOUN': 15.0,
#  'hagh_NOUN': 30.0,
#  'cleres_NOUN': 16.0,
#  'winglet_NOUN': 13.0,
#  'aneuch_NOUN': 23.0,
#  'mamun_NOUN': 61.0,
#  'aequali_X': 20.5,
#  'sarvants_NOUN': 16.0,
#  'palamcotta_NOUN': 21.0,
#  'suraj_NOUN': 60.0,
#  'fidgetting_VERB': 37.5,
#  'brownsmith_NOUN': 24.5,
#  'knaw_X': 27.5,
#  'undre_VERB': 25.0,
#  'contrat_X': 15.5,
#  'kto_NOUN': 9.0,
#  'widower_ADP': 14.0,
#  'rappel_NOUN': 38.5,
#  'saltpetre_ADJ': 35.0,
#  'perer_NOUN': 8.0,
#  'ferrous_ADJ': 2943.5,
#  'spinose_NOUN': 131.0,
#  'olergyman_NOUN': 7.0,
#  'littleham_NOUN': 36.0,
#  'artificers_VERB': 33.5,
#  'bourhood_VERB': 32.0,
#  'gladstanes_NOUN': 25.0,
#  'pontormo_NOUN': 77.0,
#  'traitor_CONJ': 10.5,
#  'sayth_ADJ': 34.0,
#  'bastick_NOUN': 41.5,
#  'accompamed_VERB': 12.0,
#  'simoniacally_ADV': 18.5,
#  'ericetorum_NOUN': 47.0,
#  'harlcy_NOUN': 18.5,
#  'falsed_VERB': 18.0,
#  'salzwedel_NOUN': 14.0,
#  'tidemark_NOUN': 31.5,
#  'lopt_VERB': 19.0,
#  'portuguese_ADV': 15.5,
#  'dilli_NOUN': 13.0,
#  'racteristic_ADJ': 50.5,
#  'cranwell_NOUN': 32.0,
#  'meltingpoint_NOUN': 73.5,
#  'pensionnaires_NOUN': 32.0,
#  'trifoliolate_NOUN': 17.0,
#  'ehrenb_NOUN': 45.5,
#  'watir_NOUN': 32.0,
#  'relicks_NOUN': 48.5,
#  'blacke_VERB': 51.0,
#  'anyl_DET': 12.5,
#  'drawes_NOUN': 27.0,
#  'gratid_VERB': 7.0,
#  'culta_X': 19.0,
#  'archieology_NOUN': 15.0,
#  'prayes_NOUN': 28.5,
#  'inimici_NOUN': 8.5,
#  'keusington_NOUN': 20.0,
#  'loyall_ADJ': 96.5,
#  'benche_NOUN': 25.0,
#  'undelayed_ADJ': 10.5,
#  'syllable_X': 24.5,
#  'saki_NOUN': 28.0,
#  'quatuordecim_X': 25.0,
#  'barow_NOUN': 14.0,
#  'beiog_ADP': 12.0,
#  'arbutlmot_NOUN': 7.0,
#  'grit_X': 37.5,
#  'orove_NOUN': 10.5,
#  'younker_ADJ': 12.0,
#  'macrocarpum_NOUN': 18.0,
#  'xothing_NOUN': 9.0,
#  'tall_NOUN': 8.0,
#  'fluviatilis_NOUN': 100.0,
#  'cabossed_VERB': 50.5,
#  'cumsean_NOUN': 9.0,
#  'rogavit_X': 15.5,
#  'victoeia_NOUN': 17.0,
#  'hanky_NOUN': 12.0,
#  'formerlie_NOUN': 24.5,
#  'invalided_NOUN': 31.5,
#  'laas_NOUN': 11.0,
#  'stuttgart_ADJ': 12.5,
#  'recont_NOUN': 11.0,
#  'glowin_VERB': 12.0,
#  'kosen_NOUN': 12.5,
#  'daylabourers_NOUN': 23.5,
#  'fient_NOUN': 15.0,
#  'jiddah_NOUN': 35.5,
#  'deckt_NOUN': 31.0,
#  'growe_ADJ': 15.0,
#  'biisching_NOUN': 21.5,
#  'blidah_NOUN': 87.5,
#  'serpyllum_NOUN': 22.0,
#  'cameram_X': 20.5,
#  'tottenbam_NOUN': 7.0,
#  'deceivest_VERB': 12.0,
#  'gualtier_NOUN': 54.5,
#  'munere_ADJ': 12.0,
#  'australie_NOUN': 24.5,
#  'apologetica_NOUN': 19.5,
#  'darin_X': 16.0,
#  'mensch_X': 20.5,
#  'thereand_CONJ': 6.0,
#  'hnmber_NOUN': 9.5,
#  'lyers_NOUN': 14.0,
#  'formuke_NOUN': 10.0,
#  'accelerative_ADJ': 56.5,
#  'philomathic_NOUN': 27.5,
#  'taties_NOUN': 27.0,
#  'rupe_X': 16.5,
#  'swordes_NOUN': 54.5,
#  'ambassades_NOUN': 19.5,
#  'eneland_NOUN': 9.0,
#  'tractatum_X': 23.5,
#  'pontifici_X': 16.5,
#  'godr_NOUN': 43.0,
#  'bevil_ADJ': 86.5,
#  'redentore_NOUN': 25.5,
#  'hannr_NOUN': 11.0,
#  'eomney_NOUN': 37.0,
#  'woeful_NOUN': 18.5,
#  'ornement_X': 11.0,
#  'collegio_X': 53.0,
#  'marigold_ADJ': 12.0,
#  'wissenschaft_X': 23.0,
#  'boords_NOUN': 20.0,
#  'haldin_NOUN': 102.5,
#  'flosh_NOUN': 5.0,
#  'ochrida_NOUN': 31.5,
#  'koval_NOUN': 22.5,
#  'voluerint_X': 38.0,
#  'bilh_NOUN': 6.0,
#  'cloveshoo_NOUN': 21.0,
#  'lexilogus_NOUN': 28.0,
#  'salf_NOUN': 13.5,
#  'pennyworth_ADJ': 21.5,
#  'sparsis_X': 36.5,
#  'saccolabium_NOUN': 85.0,
#  'uth_ADV': 5.0,
#  'manicata_NOUN': 30.0,
#  'reame_NOUN': 42.5,
#  'irone_NOUN': 13.0,
#  'halic_NOUN': 21.5,
#  'glatton_NOUN': 144.0,
#  'remuneratively_ADV': 57.0,
#  'odcombe_NOUN': 38.5,
#  'beatum_NOUN': 16.0,
#  'oonnexion_NOUN': 11.0,
#  'systema_X': 12.5,
#  'meadowsweet_NOUN': 28.5,
#  'peize_NOUN': 23.5,
#  'gat_X': 22.0,
#  'cockennouth_NOUN': 8.0,
#  'pohce_NOUN': 14.0,
#  'emall_ADJ': 10.5,
#  'alberi_NOUN': 27.0,
#  'kiltearn_NOUN': 23.0,
#  'paraffine_ADJ': 28.5,
#  'binger_NOUN': 41.0,
#  'ignoraunce_NOUN': 43.0,
#  'sliabh_NOUN': 24.0,
#  'piesse_NOUN': 162.0,
#  'shepherd_ADV': 19.0,
#  'wavelike_ADJ': 24.0,
#  'wildbore_NOUN': 43.0,
#  'stampt_ADJ': 15.0,
#  'adaptor_NOUN': 44.0,
#  'disapeared_VERB': 7.5,
#  'bhitish_NOUN': 9.5,
#  'ovo_ADV': 26.5,
#  'rawing_ADJ': 12.0,
#  'meredyth_NOUN': 111.5,
#  'borrer_NOUN': 186.5,
#  'obscurum_X': 23.5,
#  'headfort_NOUN': 92.0,
#  'bodie_VERB': 32.5,
#  'livret_NOUN': 13.0,
#  'naturelles_X': 26.0,
#  'nettlested_NOUN': 18.5,
#  'willelmo_X': 53.5,
#  'ehemical_ADJ': 7.0,
#  'slunk_ADV': 14.5,
#  'expectod_VERB': 9.5,
#  'bala_X': 23.0,
#  'arepresentation_NOUN': 7.0,
#  'alloweth_ADV': 17.5,
#  'repori_NOUN': 10.0,
#  'euskin_NOUN': 70.0,
#  'klizabeth_NOUN': 17.0,
#  'bookbinding_VERB': 32.0,
#  'cicindelidae_NOUN': 20.0,
#  'cadley_NOUN': 15.0,
#  'tost_X': 38.5,
#  'amoris_VERB': 30.0,
#  'carhaix_NOUN': 30.0,
#  'treveri_NOUN': 35.0,
#  'verbenaceae_NOUN': 16.5,
#  'stonard_NOUN': 25.5,
#  'wbight_NOUN': 21.0,
#  'capiunt_X': 15.5,
#  'gren_ADJ': 7.5,
#  'refuso_NOUN': 10.0,
#  'regulariter_NOUN': 19.0,
#  'milneedwards_NOUN': 78.0,
#  'prestes_NOUN': 109.0,
#  'incrassato_X': 62.5,
#  'chargeth_NOUN': 18.0,
#  'ispute_NOUN': 12.0,
#  'fraas_NOUN': 91.5,
#  'baronct_NOUN': 14.5,
#  'commendatio_X': 8.0,
#  'bucknall_NOUN': 256.5,
#  'mittheilungen_X': 72.0,
#  'ehenish_NOUN': 23.0,
#  'enanthe_NOUN': 44.5,
#  'guerchy_NOUN': 47.5,
#  'bilingual_NOUN': 40.5,
#  'effeteness_NOUN': 21.0,
#  'issimo_NOUN': 11.0,
#  'hangit_NOUN': 32.0,
#  'quatford_NOUN': 29.5,
#  'moden_NOUN': 17.0,
#  'invariabl_NOUN': 10.0,
#  'weatherglass_NOUN': 17.5,
#  'nostell_NOUN': 72.0,
#  'counsellers_NOUN': 45.5,
#  'preventible_NOUN': 30.0,
#  'chapuy_NOUN': 16.0,
#  'nazing_NOUN': 23.5,
#  'grouse_VERB': 57.5,
#  'nagar_NOUN': 101.0,
#  'relatum_X': 25.0,
#  'gammarus_NOUN': 105.5,
#  'monumcnta_NOUN': 8.0,
#  'remanent_ADJ': 27.5,
#  'westgate_ADJ': 147.0,
#  'circumscribed_NOUN': 35.0,
#  'sixpennyworth_NOUN': 52.0,
#  'aenea_NOUN': 28.0,
#  'kyrke_NOUN': 51.0,
#  'fiftene_NUM': 21.0,
#  'mercuric_NOUN': 578.5,
#  'phaed_NOUN': 23.0,
#  'climbe_VERB': 29.0,
#  'sarnen_NOUN': 40.0,
#  'quocunque_ADJ': 34.0,
#  'gight_NOUN': 59.5,
#  'shute_VERB': 18.0,
#  'pedicellate_VERB': 41.5,
#  'pochin_NOUN': 173.5,
#  'pyridine_NOUN': 326.0,
#  'centres_ADJ': 17.0,
#  'inventionem_NOUN': 8.0,
#  'praeclara_X': 27.0,
#  'dumbshow_NOUN': 10.0,
#  'ncwcastle_ADJ': 22.0,
#  'cooly_ADJ': 22.5,
#  'fala_NOUN': 13.0,
#  'gierusalemme_NOUN': 25.0,
#  'omissa_X': 17.0,
#  'emoirs_NOUN': 17.0,
#  'oificial_NOUN': 16.0,
#  'rarotongan_NOUN': 41.5,
#  'hada_DET': 11.0,
#  'solvendo_X': 17.0,
#  'malae_X': 10.0,
#  'ornate_X': 12.0,
#  'expenments_NOUN': 13.0,
#  'firat_ADV': 8.0,
#  'virgine_ADJ': 16.0,
#  'prophesie_NOUN': 36.5,
#  'bradney_NOUN': 41.0,
#  'nabonidus_NOUN': 174.0,
#  'tisa_NOUN': 7.5,
#  'pacified_ADJ': 13.0,
#  'galwa_NOUN': 8.0,
#  'iche_NOUN': 22.0,
#  'concessi_X': 54.0,
#  'bayth_NOUN': 32.5,
#  'waly_NOUN': 44.5,
#  'xx_ADP': 26.5,
#  'blaeu_NOUN': 57.0,
#  'apterya_NOUN': 16.5,
#  'squaee_NOUN': 12.0,
#  'concaved_VERB': 16.0,
#  'thirsty_PRON': 10.0,
#  'gravesend_ADJ': 22.5,
#  'solatium_ADJ': 44.0,
#  'victob_NOUN': 12.0,
#  'fuerunt_VERB': 18.0,
#  'ourselvos_NOUN': 7.0,
#  'bedder_NOUN': 125.0,
#  'factorum_X': 15.0,
#  'undersurface_NOUN': 53.5,
#  'hevy_ADJ': 31.0,
#  'broch_NOUN': 37.0,
#  'pisolitic_ADJ': 76.0,
#  'stickland_NOUN': 44.0,
#  'confarreatio_NOUN': 30.0,
#  'moonstone_NOUN': 42.0,
#  'papilionaceous_NOUN': 18.0,
#  'keillor_NOUN': 44.5,
#  'feilding_NOUN': 177.0,
#  'teversham_NOUN': 36.5,
#  'ronny_NOUN': 8.0,
#  'yielde_VERB': 14.0,
#  'rectorof_NOUN': 7.0,
#  'thoseof_DET': 6.0,
#  'ashwin_NOUN': 36.5,
#  'hydrographie_NOUN': 26.5,
#  'anstie_NOUN': 324.5,
#  'alverstoke_NOUN': 118.0,
#  'wyves_NOUN': 77.0,
#  'jointings_NOUN': 24.5,
#  'singeth_ADJ': 11.0,
#  'castaneus_NOUN': 49.5,
#  'draper_VERB': 15.5,
#  'execucion_NOUN': 76.0,
#  'longitudinis_X': 23.0,
#  'plag_NOUN': 8.5,
#  'adur_NOUN': 105.0,
#  'frediano_NOUN': 41.5,
#  'cospatric_NOUN': 27.5,
#  'olium_NOUN': 13.0,
#  'padma_NOUN': 68.0,
#  'appy_NOUN': 24.5,
#  'gladwell_NOUN': 26.5,
#  'omparative_ADJ': 5.0,
#  'kite_X': 10.5,
#  'motya_NOUN': 22.5,
#  'lingam_NOUN': 53.0,
#  'sehwan_NOUN': 41.0,
#  'protag_NOUN': 27.0,
#  'molliter_X': 15.5,
#  'kinsky_NOUN': 62.5,
#  'doctoris_X': 37.5,
#  'planco_NOUN': 16.0,
#  'latif_NOUN': 49.5,
#  'bose_ADJ': 13.0,
#  'gerardiana_NOUN': 18.5,
#  'chiefe_VERB': 36.5,
#  'rangiferina_NOUN': 30.0,
#  'bogey_NOUN': 101.0,
#  'frap_NOUN': 6.0,
#  'rollock_NOUN': 90.0,
#  'lucens_NOUN': 37.5,
#  'mailbag_NOUN': 19.0,
#  'meridionalis_NOUN': 47.5,
#  'hadar_NOUN': 17.5,
#  'taryed_VERB': 26.5,
#  'edgitha_NOUN': 13.5,
#  'dngald_NOUN': 8.0,
#  'andsocket_ADJ': 18.0,
#  'innocently_ADJ': 10.0,
#  'caoutchouc_VERB': 29.5,
#  'hypsiprymnus_NOUN': 33.0,
#  'jacqueminot_NOUN': 115.0,
#  'kearsey_NOUN': 32.5,
#  'traiteur_NOUN': 18.0,
#  'mixbury_NOUN': 22.5,
#  'controuled_VERB': 23.0,
#  'sensitiveness_ADJ': 20.0,
#  'chenpside_NOUN': 7.0,
#  'organum_X': 15.5,
#  'tegulae_NOUN': 198.5,
#  'locatelli_NOUN': 48.5,
#  'tunga_NOUN': 22.0,
#  'ravenshaw_NOUN': 93.5,
#  'dundases_NOUN': 18.5,
#  'theophila_NOUN': 57.5,
#  'jacere_NOUN': 12.0,
#  'rudkin_NOUN': 53.0,
#  'superare_NOUN': 12.0,
#  'disconnexion_NOUN': 52.0,
#  'boko_NOUN': 14.5,
#  'llanbadarn_NOUN': 77.0,
#  'elspet_NOUN': 42.0,
#  'wassell_NOUN': 30.0,
#  'lorsque_NOUN': 14.0,
#  'tubulated_VERB': 27.5,
#  'pecock_NOUN': 260.5,
#  'novorum_NOUN': 30.0,
#  'harcourts_NOUN': 50.0,
#  'compt_ADJ': 39.5,
#  'surveyorship_NOUN': 41.0,
#  'patrocinio_X': 14.0,
#  'moit_NOUN': 11.0,
#  'amusineg_VERB': 9.0,
#  'northesk_NOUN': 84.0,
#  'monastica_NOUN': 77.0,
#  'simone_X': 24.5,
#  'novatianism_NOUN': 18.5,
#  'arbnthnot_NOUN': 9.0,
#  'gutta_VERB': 15.0,
#  'kiog_NOUN': 7.0,
#  'septembris_X': 46.5,
#  'asad_NOUN': 51.0,
#  'ambrosiaster_NOUN': 26.0,
#  'kindlier_NOUN': 12.5,
#  'annuitie_NOUN': 26.0,
#  'evelegh_NOUN': 21.0,
#  'betwa_NOUN': 86.5,
#  'sectile_NOUN': 31.0,
#  'nycholas_NOUN': 64.5,
#  'allcard_NOUN': 34.5,
#  'centro_ADJ': 60.5,
#  'rathlin_NOUN': 121.5,
#  'intin_NOUN': 10.0,
#  'hereditary_VERB': 16.0,
#  'strret_NOUN': 9.5,
#  'bettering_ADJ': 9.5,
#  'latinise_VERB': 54.5,
#  'revien_NOUN': 18.5,
#  'verning_VERB': 15.0,
#  'desford_NOUN': 31.0,
#  'nour_X': 18.5,
#  'tausch_NOUN': 31.0,
#  'dilectione_X': 22.0,
#  'sennight_NOUN': 86.0,
#  'melanura_NOUN': 46.5,
#  'tinca_NOUN': 14.0,
#  'indumentum_X': 10.0,
#  'nonionina_NOUN': 41.0,
#  'docere_NOUN': 12.0,
#  'bradshawe_NOUN': 137.5,
#  'bestias_X': 18.5,
#  'rudyerd_NOUN': 72.5,
#  'ornamentists_NOUN': 15.0,
#  'deliciae_NOUN': 24.0,
#  'incorrodible_ADJ': 27.5,
#  'lxxiil_NOUN': 8.5,
#  'rowlinson_NOUN': 22.5,
#  'martyne_NOUN': 49.5,
#  'pbofessob_NOUN': 32.0,
#  'procuratores_NOUN': 23.0,
#  'devouport_NOUN': 11.0,
#  'jlj_NOUN': 16.0,
#  'tkl_NOUN': 27.5,
#  'sorbet_NOUN': 16.0,
#  'veritables_X': 11.0,
#  'westell_NOUN': 21.0,
#  'btems_NOUN': 17.0,
#  'stogursey_NOUN': 22.5,
#  'norice_NOUN': 16.5,
#  'waterfloods_NOUN': 18.0,
#  'alci_NOUN': 9.5,
#  'heire_VERB': 40.5,
#  'macular_NOUN': 98.5,
#  'rugs_VERB': 17.5,
#  'wauxhall_NOUN': 34.5,
#  'plainlie_NOUN': 29.0,
#  'quaeque_ADJ': 14.0,
#  'walgrave_NOUN': 100.5,
#  'nuper_CONJ': 10.0,
#  'elaeagnus_NOUN': 19.0,
#  'satisfaire_X': 16.5,
#  'obdeb_NOUN': 40.0,
#  'parlane_NOUN': 44.5,
#  'humea_NOUN': 25.0,
#  'blne_NOUN': 10.5,
#  'erskin_NOUN': 43.0,
#  'parri_NOUN': 9.0,
#  'threed_NOUN': 34.0,
#  'auximum_NOUN': 19.5,
#  'arthuri_NOUN': 15.0,
#  'yitruvius_NOUN': 7.0,
#  'itur_NOUN': 6.5,
#  'owne_ADV': 17.0,
#  'linemen_NOUN': 32.5,
#  'felpham_NOUN': 40.0,
#  'himselfe_ADV': 52.5,
#  'medio_VERB': 17.0,
#  'gallinae_NOUN': 44.5,
#  'chaunter_NOUN': 28.5,
#  'iest_VERB': 11.0,
#  'gingle_NOUN': 14.0,
#  'cleobury_NOUN': 129.0,
#  'esquyer_NOUN': 38.0,
#  'morinda_NOUN': 62.0,
#  'tuberosus_NOUN': 29.0,
#  'aequor_X': 15.0,
#  'abhorrer_NOUN': 22.0,
#  'perinaeal_ADJ': 68.5,
#  'beforementioned_ADJ': 13.0,
#  'scrofa_NOUN': 59.0,
#  'quingentesimo_X': 51.5,
#  'musikalische_NOUN': 23.0,
#  'behnes_NOUN': 84.0,
#  'coalminers_NOUN': 13.5,
#  'compeared_VERB': 84.0,
#  'pinnatus_NOUN': 18.0,
#  'laciniata_X': 15.0,
#  'enmore_NOUN': 52.0,
#  'avoi_X': 6.0,
#  'humilitate_X': 14.0,
#  'lntrod_NOUN': 11.5,
#  'voler_NOUN': 16.0,
#  'horum_NOUN': 32.0,
#  'brainsick_NOUN': 22.0,
#  'assimilis_VERB': 47.5,
#  'ouvert_NOUN': 15.5,
#  'tije_DET': 28.5,
#  'underlined_ADJ': 23.5,
#  'somme_DET': 73.0,
#  'macro_X': 11.0,
#  'tilsley_NOUN': 76.0,
#  'josling_NOUN': 22.0,
#  'uninterruptedly_ADJ': 9.0,
#  'succour_PRON': 37.5,
#  'enwn_NOUN': 5.0,
#  'appere_NOUN': 32.5,
#  'abercom_NOUN': 21.0,
#  'hayre_NOUN': 72.5,
#  'dutye_NOUN': 37.5,
#  'blumei_NOUN': 39.0,
#  'picturis_X': 11.5,
#  'prioratus_NOUN': 52.5,
#  'dodonaeus_NOUN': 13.5,
#  'fouler_NOUN': 26.0,
#  'advaunce_VERB': 25.0,
#  'lengthways_ADV': 40.5,
#  'computus_NOUN': 57.5,
#  'monogram_VERB': 21.5,
#  'cythere_NOUN': 139.0,
#  'holboen_NOUN': 8.5,
#  'ruman_NOUN': 10.0,
#  'fastigio_X': 11.5,
#  'foumart_NOUN': 31.5,
#  'wynnes_NOUN': 35.5,
#  'eastington_NOUN': 49.5,
#  'onby_ADP': 4.0,
#  'secunderabad_NOUN': 193.0,
#  'noncompletion_NOUN': 14.0,
#  'finshury_NOUN': 26.0,
#  'borna_NOUN': 18.0,
#  'robissos_NOUN': 8.0,
#  'beilage_NOUN': 30.5,
#  'castlecomer_NOUN': 79.5,
#  'porcian_NOUN': 9.0,
#  'besyde_ADP': 132.0,
#  'xxxvii_VERB': 15.5,
#  'stackyards_NOUN': 32.0,
#  'anguste_DET': 20.0,
#  'phillack_NOUN': 33.0,
#  'univcrsity_NOUN': 7.0,
#  'whereu_ADV': 13.0,
#  'accordthe_DET': 9.0,
#  'hauts_NOUN': 33.5,
#  'dipladenia_NOUN': 107.0,
#  'sempill_NOUN': 233.0,
#  'headforemost_ADV': 12.5,
#  'ultimatum_ADJ': 12.0,
#  'kidderpore_NOUN': 34.0,
#  'halloo_ADV': 9.0,
#  'unchronicled_VERB': 22.5,
#  'whewcll_NOUN': 9.0,
#  'fidelitate_X': 19.0,
#  'houbc_NOUN': 7.0,
#  'subjectis_VERB': 36.0,
#  'lossie_NOUN': 72.5,
#  'humboldtii_NOUN': 34.5,
#  'wonld_ADJ': 8.0,
#  'jouin_NOUN': 11.5,
#  'pnnciple_NOUN': 6.0,
#  'sumburgh_NOUN': 82.0,
#  'toth_ADJ': 18.5,
#  'meate_ADV': 11.0,
#  'geobgb_NOUN': 19.0,
#  'egi_NOUN': 6.5,
#  'tragiques_NOUN': 24.0,
#  'crich_NOUN': 93.0,
#  'oxfo_NOUN': 16.5,
#  'mendax_NOUN': 22.0,
#  'diflicultly_ADV': 19.5,
#  'wyt_VERB': 24.0,
#  'islington_ADP': 49.5,
#  'hunnis_NOUN': 21.5,
#  'thaines_NOUN': 8.0,
#  'rgument_NOUN': 10.5,
#  'materno_X': 10.5,
#  'illinc_X': 17.0,
#  'widville_NOUN': 25.0,
#  'confirmare_X': 17.5,
#  'parkhouse_NOUN': 45.5,
#  'arabat_NOUN': 20.0,
#  'oxydising_VERB': 16.0,
#  'radialis_X': 88.5,
#  'discrimina_X': 30.5,
#  'obeyeth_ADP': 16.5,
#  'lawtie_NOUN': 16.0,
#  'regtet_NOUN': 6.0,
#  'latinum_ADJ': 23.0,
#  'maittaire_NOUN': 85.5,
#  'keythorpe_NOUN': 24.5,
#  'cheu_NOUN': 12.0,
#  'disfavour_ADJ': 8.5,
#  'woodcut_ADJ': 44.5,
#  'wonford_NOUN': 35.5,
#  'translat_NOUN': 11.0,
#  'balistae_NOUN': 17.0,
#  'evaristus_NOUN': 22.5,
#  'kesident_NOUN': 16.0,
#  'comtek_NOUN': 8.0,
#  'merentur_X': 8.0,
#  'menstrie_NOUN': 55.5,
#  'vulgarise_VERB': 282.0,
#  'eightly_ADV': 23.0,
#  'wherry_VERB': 16.5,
#  'liliacea_NOUN': 24.0,
#  'troyon_NOUN': 190.0,
#  'willinge_NOUN': 71.0,
#  'refonnation_NOUN': 6.0,
#  'selfhumiliation_NOUN': 10.0,
#  'istoric_ADJ': 9.0,
#  'fronde_X': 47.5,
#  'rufis_NOUN': 23.5,
#  'worthe_VERB': 52.5,
#  'secretari_NOUN': 8.0,
#  'alcudia_NOUN': 34.5,
#  'mushroom_VERB': 18.0,
#  'pakefield_NOUN': 60.5,
#  'stevin_NOUN': 57.5,
#  'joyfullest_ADJ': 17.0,
#  'kyme_NOUN': 216.0,
#  'arpa_NOUN': 29.5,
#  'leventhorp_NOUN': 14.0,
#  'significationem_X': 18.0,
#  'lalng_NOUN': 10.0,
#  'cyprinidae_NOUN': 39.5,
#  'purchace_NOUN': 17.5,
#  'catteris_X': 24.0,
#  'bierlow_NOUN': 52.5,
#  'solleret_NOUN': 44.5,
#  'vhalley_NOUN': 23.0,
#  'wellwooded_VERB': 15.0,
#  'habitum_NOUN': 18.5,
#  'uudor_ADP': 9.0,
#  'subsalts_NOUN': 19.0,
#  'selfe_X': 43.5,
#  'hlmself_PRON': 9.0,
#  'aurinia_NOUN': 11.0,
#  'avillage_NOUN': 17.5,
#  'keepinge_NOUN': 45.5,
#  'peucedanum_NOUN': 28.5,
#  'feste_VERB': 36.5,
#  'busman_NOUN': 18.0,
#  'servabit_X': 11.5,
#  'conposition_NOUN': 7.0,
#  'ueher_NOUN': 8.0,
#  'weri_VERB': 9.0,
#  'insieme_ADJ': 17.0,
#  'falcatus_NOUN': 26.5,
#  'shehad_VERB': 8.0,
#  'peray_NOUN': 25.5,
#  'righte_VERB': 22.0,
#  'taly_ADV': 10.5,
#  'overtaketh_ADV': 9.0,
#  'galwny_NOUN': 9.5,
#  'nonus_NOUN': 12.0,
#  'iun_VERB': 7.5,
#  'emptie_VERB': 11.0,
#  'erical_ADJ': 8.0,
#  'patroness_ADJ': 14.0,
#  'hackwood_NOUN': 136.5,
#  'vessex_NOUN': 16.0,
#  'foreshowing_NOUN': 11.0,
#  'cadwaladr_NOUN': 57.0,
#  'comprehende_VERB': 12.0,
#  'vincing_NOUN': 8.0,
#  'oubril_NOUN': 24.0,
#  'deformity_ADJ': 14.5,
#  'gwyther_NOUN': 70.0,
#  'nodis_X': 22.0,
#  'etv_NOUN': 8.0,
#  'unstinting_ADJ': 30.5,
#  'unsportsmanlike_ADJ': 103.0,
#  'llary_NOUN': 5.0,
#  'anglcterre_NOUN': 8.0,
#  'carmunnock_NOUN': 17.5,
#  'apoda_NOUN': 40.0,
#  'gweedore_NOUN': 65.0,
#  'reflexion_VERB': 36.5,
#  'londoo_NOUN': 11.0,
#  'steill_NOUN': 33.5,
#  'unsifted_VERB': 13.0,
#  'oldman_NOUN': 55.5,
#  'vedantists_NOUN': 18.0,
#  'pughe_NOUN': 144.0,
#  'cusparia_NOUN': 25.5,
#  'birdcatchers_NOUN': 37.5,
#  'pretendit_NOUN': 45.5,
#  'tendit_X': 27.0,
#  'jurisprudents_NOUN': 10.0,
#  'settembre_NOUN': 25.5,
#  'prankt_NOUN': 13.0,
#  'harmonising_NOUN': 43.5,
#  'justled_VERB': 23.0,
#  'torthorwald_NOUN': 45.5,
#  'verschoyle_NOUN': 66.5,
#  'maroc_NOUN': 44.5,
#  'densiflorum_NOUN': 31.0,
#  'cornopean_NOUN': 26.5,
#  'apiocrinus_NOUN': 20.5,
#  'xvijth_NOUN': 16.0,
#  'weddington_NOUN': 11.5,
#  'britannice_NOUN': 14.5,
#  'fld_ADV': 78.0,
#  'lepido_NOUN': 15.0,
#  'suppressive_ADJ': 22.5,
#  'fagged_ADJ': 24.5,
#  'doppler_NOUN': 55.0,
#  'tricoupi_NOUN': 58.0,
#  'sorciers_NOUN': 13.0,
#  'divel_NOUN': 39.5,
#  'hypogea_NOUN': 11.0,
#  'tetty_NOUN': 25.0,
#  'antwerpiae_NOUN': 14.0,
#  'donderry_NOUN': 20.0,
#  'britayne_NOUN': 30.5,
#  'carriageroad_NOUN': 39.0,
#  'penlee_NOUN': 28.5,
#  'commers_NOUN': 30.0,
#  'tomkyns_NOUN': 61.5,
#  'estoppel_ADJ': 30.5,
#  'raisable_NOUN': 25.0,
#  'tabbe_NOUN': 14.5,
#  'attendaunce_NOUN': 41.0,
#  'dispels_NOUN': 21.0,
#  'jamar_NOUN': 14.0,
#  'dubing_NOUN': 10.0,
#  'finsbury_ADJ': 517.0,
#  'manockjee_NOUN': 19.0,
#  'womica_NOUN': 11.0,
#  'bignesse_NOUN': 47.0,
#  'dusart_NOUN': 38.0,
#  'everdingen_NOUN': 31.0,
#  'tuto_PRT': 5.5,
#  'underlyne_NOUN': 81.5,
#  'dedita_X': 11.0,
#  'disegno_NOUN': 17.0,
#  'madhu_NOUN': 51.0,
#  'tonning_NOUN': 38.0,
#  'loninox_NOUN': 11.0,
#  'tobermory_NOUN': 167.5,
#  'caligraphic_ADJ': 50.0,
#  'shillibeer_NOUN': 41.0,
#  'statoment_NOUN': 18.0,
#  'slabby_ADJ': 15.0,
#  'antennis_VERB': 175.5,
#  'ellerman_NOUN': 18.5,
#  'laneous_NOUN': 15.0,
#  'taedium_NOUN': 9.0,
#  'borodale_NOUN': 13.5,
#  'iough_ADP': 6.0,
#  'jousters_NOUN': 11.0,
#  'soumettre_X': 21.0,
#  'gunne_NOUN': 25.0,
#  'malcolms_NOUN': 20.0,
#  'letizia_NOUN': 20.0,
#  'schottus_NOUN': 22.0,
#  'sequent_X': 9.0,
#  'amne_X': 16.0,
#  'verygreat_NOUN': 10.0,
#  'northwold_NOUN': 56.5,
#  'benholme_NOUN': 97.5,
#  'asserunt_X': 15.0,
#  'concione_X': 12.0,
#  'donshire_NOUN': 6.0,
#  'cobts_NOUN': 28.0,
#  'ramsgill_NOUN': 9.0,
#  'combretum_NOUN': 27.0,
#  'rtion_VERB': 5.0,
#  'cernis_X': 13.5,
#  'uii_X': 9.5,
#  'baffaelle_NOUN': 15.0,
#  'altrincham_NOUN': 448.0,
#  'contulit_NOUN': 17.0,
#  'fosteriana_NOUN': 29.0,
#  'torksey_NOUN': 45.5,
#  'puerile_ADV': 15.5,
#  'gaetulians_NOUN': 16.0,
#  'muthill_NOUN': 51.5,
#  'yelept_ADP': 27.0,
#  'claydon_NOUN': 250.0,
#  'bashall_NOUN': 37.5,
#  'moones_NOUN': 18.5,
#  'inthey_NOUN': 14.0,
#  'ouvirandra_NOUN': 21.0,
#  'beatorum_X': 26.5,
#  'anythe_DET': 10.5,
#  'relinquit_NOUN': 13.0,
#  'flyeth_VERB': 19.0,
#  'catena_X': 24.0,
#  'palacky_NOUN': 81.5,
#  'dicti_VERB': 24.5,
#  'batailles_NOUN': 29.5,
#  'supercargo_VERB': 9.0,
#  'pallipes_NOUN': 52.5,
#  'thedirectors_NOUN': 11.5,
#  'voglio_X': 27.0,
#  'urraca_NOUN': 51.5,
#  'maills_NOUN': 100.0,
#  'commentarios_NOUN': 10.0,
#  'bearsted_NOUN': 14.5,
#  'emended_ADJ': 25.5,
#  'lion_X': 10.0,
#  'besurrection_NOUN': 28.5,
#  'oleifera_NOUN': 23.5,
#  'eumpe_NOUN': 5.0,
#  'hochheimer_NOUN': 13.5,
#  'unkindled_VERB': 9.0,
#  'principaliter_X': 29.0,
#  'doa_VERB': 11.0,
#  'runne_NOUN': 135.0,
#  'yew_NUM': 9.0,
#  'giardino_NOUN': 46.5,
#  'wattr_NOUN': 13.5,
#  'zua_NOUN': 17.5,
#  'pleins_X': 16.0,
#  'dispaire_NOUN': 47.5,
#  'forchammer_NOUN': 26.5,
#  'halfyear_ADJ': 87.5,
#  'opprest_ADP': 15.5,
#  'pearch_NOUN': 19.5,
#  'cantreds_NOUN': 45.5,
#  'cheynell_NOUN': 43.0,
#  'grosrenor_NOUN': 14.0,
#  'xij_X': 65.0,
#  'misdemean_VERB': 22.5,
#  'lautour_NOUN': 33.5,
#  'barwicke_NOUN': 56.0,
#  'aspdin_NOUN': 12.5,
#  'pridmore_NOUN': 24.5,
#  'edlin_NOUN': 81.5,
#  'reinet_NOUN': 114.0,
#  'biseiop_NOUN': 16.0,
#  'bellon_NOUN': 19.0,
#  'preit_NOUN': 12.0,
#  'ntent_NOUN': 10.0,
#  'keevil_NOUN': 44.0,
#  'chaunce_VERB': 59.5,
#  'tropicus_NOUN': 19.0,
#  'othes_VERB': 26.0,
#  'uet_VERB': 7.0,
#  'culliford_NOUN': 45.5,
#  'geffery_NOUN': 29.0,
#  'vetusta_NOUN': 38.0,
#  'ormston_NOUN': 34.0,
#  'selous_NOUN': 129.5,
#  'edgware_ADJ': 190.0,
#  'bagborough_NOUN': 21.5,
#  'llle_X': 13.5,
#  'nowthe_DET': 10.0,
#  'fordshire_NUM': 20.0,
#  'sirnamed_VERB': 17.0,
#  'bergue_NOUN': 86.0,
#  'apostolicam_NOUN': 18.0,
#  'fust_ADV': 14.5,
#  'ndently_ADV': 7.0,
#  'seil_X': 6.0,
#  'corngrowing_NOUN': 14.0,
#  'bcott_NOUN': 7.5,
#  'pondichery_NOUN': 53.5,
#  'dissimulating_NOUN': 12.0,
#  'concavo_X': 27.0,
#  'rustat_NOUN': 36.5,
#  'andwhite_ADJ': 37.5,
#  'graystock_NOUN': 24.0,
#  'englandand_NOUN': 12.0,
#  'mappe_NOUN': 16.0,
#  'bolinbroke_NOUN': 18.5,
#  'ipsissima_X': 19.0,
#  'girdlestone_NOUN': 446.0,
#  'creich_NOUN': 53.5,
#  'jnn_ADV': 40.0,
#  'haill_DET': 45.5,
#  'partc_ADJ': 16.0,
#  'unfortuuately_ADV': 5.0,
#  'anwoth_NOUN': 44.5,
#  'brahmanical_NOUN': 131.0,
#  'acquapendente_NOUN': 36.0,
#  'alfgar_NOUN': 39.0,
#  'falcate_VERB': 70.5,
#  'shamefull_ADJ': 40.0,
#  'inedita_X': 17.5,
#  'coy_VERB': 13.5,
#  'seealso_NOUN': 8.5,
#  'fae_ADV': 9.0,
#  'beccafumi_NOUN': 41.0,
#  'antiphonary_NOUN': 14.0,
#  'bewept_ADP': 17.0,
#  'burgum_NOUN': 35.5,
#  'vetus_ADJ': 13.0,
#  'volatilisation_NOUN': 400.5,
#  'mortmain_VERB': 37.0,
#  'suddaine_ADJ': 18.0,
#  'ecclesle_NOUN': 15.5,
#  'abershaw_NOUN': 26.5,
#  'understandest_ADP': 11.5,
#  'redacta_X': 17.0,
#  'mislikes_VERB': 23.5,
#  'fierie_NOUN': 36.5,
#  'soveraign_NOUN': 65.0,
#  'spectaculis_NOUN': 31.0,
#  'gosden_NOUN': 59.0,
#  'cesarewitch_NOUN': 277.0,
#  'europam_NOUN': 12.0,
#  'adulterio_X': 16.5,
#  'rupibus_X': 40.0,
#  'lectus_NOUN': 23.5,
#  'vasis_X': 23.5,
#  'ovalau_NOUN': 69.0,
#  'edica_NOUN': 9.0,
#  'testes_VERB': 26.0,
#  'convolvulaceae_NOUN': 30.0,
#  'consignation_NOUN': 195.0,
#  'bueton_NOUN': 9.0,
#  'reoognised_VERB': 17.0,
#  'waile_VERB': 37.5,
#  'gisters_NOUN': 12.0,
#  'courtmartial_ADJ': 20.0,
#  'aemilian_NOUN': 24.0,
#  'clamour_ADJ': 21.5,
#  'lyinge_NOUN': 81.5,
#  ...}

# %%
BRIT_1851_1900_STEP1
# Out:
# {'angelic_ADJ': {'sum_usage': 157686,
#   'median_usage': 3164.0,
#   'mean_usage': 3153.72,
#   'max_usage': 4073,
#   'min_usage': 2035,
#   'frequency': 2.786038625269845e-06},
#  'baker_NOUN': {'sum_usage': 311357,
#   'median_usage': 6086.5,
#   'mean_usage': 6227.14,
#   'max_usage': 9180,
#   'min_usage': 4607,
#   'frequency': 5.501139151529896e-06},
#  'after_ADP': {'sum_usage': 53679702,
#   'median_usage': 1074339.0,
#   'mean_usage': 1073594.04,
#   'max_usage': 1368491,
#   'min_usage': 881247,
#   'frequency': 0.0009484274010690548},
#  'auersperg_NOUN': {'sum_usage': 3201,
#   'median_usage': 56.0,
#   'mean_usage': 64.02,
#   'max_usage': 196,
#   'min_usage': 4,
#   'frequency': 5.6556128251644245e-08},
#  'alfeed_NOUN': {'sum_usage': 1614,
#   'median_usage': 28.0,
#   'mean_usage': 32.28,
#   'max_usage': 59,
#   'min_usage': 7,
#   'frequency': 2.851658575387498e-08},
#  'animae_NOUN': {'sum_usage': 1255,
#   'median_usage': 22.0,
#   'mean_usage': 25.1,
#   'max_usage': 80,
#   'min_usage': 4,
#   'frequency': 2.2173677274543433e-08},
#  'ban_NOUN': {'sum_usage': 155540,
#   'median_usage': 3055.0,
#   'mean_usage': 3110.8,
#   'max_usage': 3941,
#   'min_usage': 2528,
#   'frequency': 2.7481225205438133e-06},
#  'bolena_NOUN': {'sum_usage': 2145,
#   'median_usage': 26.0,
#   'mean_usage': 42.9,
#   'max_usage': 499,
#   'min_usage': 4,
#   'frequency': 3.789843645728738e-08},
#  'adelpbi_NOUN': {'sum_usage': 716,
#   'median_usage': 14.0,
#   'mean_usage': 14.32,
#   'max_usage': 28,
#   'min_usage': 2,
#   'frequency': 1.2650480421173784e-08},
#  'apemantus_NOUN': {'sum_usage': 7832,
#   'median_usage': 150.5,
#   'mean_usage': 156.64,
#   'max_usage': 337,
#   'min_usage': 12,
#   'frequency': 1.3837788080814673e-07},
#  'aperture_NOUN': {'sum_usage': 1020840,
#   'median_usage': 19936.5,
#   'mean_usage': 20416.8,
#   'max_usage': 26179,
#   'min_usage': 14605,
#   'frequency': 1.8036475465294755e-05},
#  'aaron_NOUN': {'sum_usage': 317245,
#   'median_usage': 5987.0,
#   'mean_usage': 6344.9,
#   'max_usage': 14725,
#   'min_usage': 4035,
#   'frequency': 5.605169917898431e-06},
#  'bamian_NOUN': {'sum_usage': 6640,
#   'median_usage': 121.5,
#   'mean_usage': 132.8,
#   'max_usage': 733,
#   'min_usage': 7,
#   'frequency': 1.1731730446451665e-07},
#  'bertrand_NOUN': {'sum_usage': 115780,
#   'median_usage': 1911.0,
#   'mean_usage': 2315.6,
#   'max_usage': 9125,
#   'min_usage': 1147,
#   'frequency': 2.0456321552562857e-06},
#  'anchylosis_NOUN': {'sum_usage': 26193,
#   'median_usage': 526.5,
#   'mean_usage': 523.86,
#   'max_usage': 1297,
#   'min_usage': 103,
#   'frequency': 4.627849632287778e-07},
#  'almes_NOUN': {'sum_usage': 10091,
#   'median_usage': 181.5,
#   'mean_usage': 201.82,
#   'max_usage': 516,
#   'min_usage': 110,
#   'frequency': 1.7829049990232493e-07},
#  'antioche_NOUN': {'sum_usage': 1720,
#   'median_usage': 30.0,
#   'mean_usage': 34.4,
#   'max_usage': 113,
#   'min_usage': 5,
#   'frequency': 3.038942224080853e-08},
#  'anastomosis_NOUN': {'sum_usage': 33408,
#   'median_usage': 633.5,
#   'mean_usage': 668.16,
#   'max_usage': 1340,
#   'min_usage': 188,
#   'frequency': 5.902615222214718e-07},
#  'carrot_NOUN': {'sum_usage': 114110,
#   'median_usage': 2146.0,
#   'mean_usage': 2282.2,
#   'max_usage': 3918,
#   'min_usage': 1263,
#   'frequency': 2.01612614645271e-06},
#  'ali_ADJ': {'sum_usage': 6660,
#   'median_usage': 130.5,
#   'mean_usage': 133.2,
#   'max_usage': 200,
#   'min_usage': 96,
#   'frequency': 1.1767066983940977e-07},
#  'baldernock_NOUN': {'sum_usage': 1008,
#   'median_usage': 16.5,
#   'mean_usage': 20.16,
#   'max_usage': 73,
#   'min_usage': 2,
#   'frequency': 1.780961489461337e-08},
#  'bowyer_NOUN': {'sum_usage': 2021,
#   'median_usage': 38.0,
#   'mean_usage': 40.42,
#   'max_usage': 90,
#   'min_usage': 14,
#   'frequency': 3.5707571132950023e-08},
#  'arimanes_NOUN': {'sum_usage': 1657,
#   'median_usage': 28.0,
#   'mean_usage': 33.14,
#   'max_usage': 96,
#   'min_usage': 6,
#   'frequency': 2.9276321309895193e-08},
#  'adanson_NOUN': {'sum_usage': 6899,
#   'median_usage': 112.5,
#   'mean_usage': 137.98,
#   'max_usage': 399,
#   'min_usage': 39,
#   'frequency': 1.2189338606938258e-07},
#  'ballou_NOUN': {'sum_usage': 2427,
#   'median_usage': 37.5,
#   'mean_usage': 48.54,
#   'max_usage': 207,
#   'min_usage': 2,
#   'frequency': 4.2880888243280405e-08},
#  'ardson_NOUN': {'sum_usage': 1525,
#   'median_usage': 25.0,
#   'mean_usage': 30.5,
#   'max_usage': 70,
#   'min_usage': 6,
#   'frequency': 2.6944109835600585e-08},
#  'assess_VERB': {'sum_usage': 622082,
#   'median_usage': 11642.5,
#   'mean_usage': 12441.64,
#   'max_usage': 20389,
#   'min_usage': 8333,
#   'frequency': 1.0991111957213169e-05},
#  'authenticate_VERB': {'sum_usage': 201555,
#   'median_usage': 4110.0,
#   'mean_usage': 4031.1,
#   'max_usage': 4893,
#   'min_usage': 3127,
#   'frequency': 3.5611279068291647e-06},
#  'bella_X': {'sum_usage': 11621,
#   'median_usage': 224.0,
#   'mean_usage': 232.42,
#   'max_usage': 376,
#   'min_usage': 126,
#   'frequency': 2.053229510816488e-07},
#  'braddon_NOUN': {'sum_usage': 38352,
#   'median_usage': 791.0,
#   'mean_usage': 767.04,
#   'max_usage': 1549,
#   'min_usage': 25,
#   'frequency': 6.776134428950516e-07},
#  'abstraction_NOUN': {'sum_usage': 360912,
#   'median_usage': 7077.5,
#   'mean_usage': 7218.24,
#   'max_usage': 9283,
#   'min_usage': 4671,
#   'frequency': 6.37669020917133e-06},
#  'ambition_NOUN': {'sum_usage': 1419962,
#   'median_usage': 27680.0,
#   'mean_usage': 28399.24,
#   'max_usage': 45147,
#   'min_usage': 21542,
#   'frequency': 2.5088270223199395e-05},
#  'ayrton_NOUN': {'sum_usage': 171072,
#   'median_usage': 3216.5,
#   'mean_usage': 3421.44,
#   'max_usage': 8067,
#   'min_usage': 246,
#   'frequency': 3.022546070685812e-06},
#  'bucher_NOUN': {'sum_usage': 8485,
#   'median_usage': 68.0,
#   'mean_usage': 169.7,
#   'max_usage': 4296,
#   'min_usage': 15,
#   'frequency': 1.4991526029840719e-07},
#  'am_NOUN': {'sum_usage': 135790,
#   'median_usage': 2704.5,
#   'mean_usage': 2715.8,
#   'max_usage': 4010,
#   'min_usage': 2137,
#   'frequency': 2.399174212836855e-06},
#  'atrium_NOUN': {'sum_usage': 45241,
#   'median_usage': 753.5,
#   'mean_usage': 904.82,
#   'max_usage': 2293,
#   'min_usage': 318,
#   'frequency': 7.993301462769876e-07},
#  'ascertain_VERB': {'sum_usage': 4543639,
#   'median_usage': 92423.5,
#   'mean_usage': 90872.78,
#   'max_usage': 114199,
#   'min_usage': 72824,
#   'frequency': 8.027823493070059e-05},
#  'braunschweig_NOUN': {'sum_usage': 9631,
#   'median_usage': 197.5,
#   'mean_usage': 192.62,
#   'max_usage': 429,
#   'min_usage': 40,
#   'frequency': 1.701630962797831e-07},
#  'buenaventura_NOUN': {'sum_usage': 3880,
#   'median_usage': 63.0,
#   'mean_usage': 77.6,
#   'max_usage': 237,
#   'min_usage': 20,
#   'frequency': 6.855288272926575e-08},
#  'amenophis_NOUN': {'sum_usage': 23453,
#   'median_usage': 377.0,
#   'mean_usage': 469.06,
#   'max_usage': 1592,
#   'min_usage': 98,
#   'frequency': 4.1437390686842e-07},
#  'apparition_NOUN': {'sum_usage': 264995,
#   'median_usage': 5057.5,
#   'mean_usage': 5299.9,
#   'max_usage': 8328,
#   'min_usage': 3745,
#   'frequency': 4.682002875990149e-06},
#  'amount_VERB': {'sum_usage': 3986799,
#   'median_usage': 76661.5,
#   'mean_usage': 79735.98,
#   'max_usage': 114653,
#   'min_usage': 66075,
#   'frequency': 7.043983616292629e-05},
#  'barclayana_NOUN': {'sum_usage': 743,
#   'median_usage': 13.0,
#   'mean_usage': 14.86,
#   'max_usage': 58,
#   'min_usage': 2,
#   'frequency': 1.3127523677279498e-08},
#  'antioeh_NOUN': {'sum_usage': 1024,
#   'median_usage': 17.5,
#   'mean_usage': 20.48,
#   'max_usage': 66,
#   'min_usage': 3,
#   'frequency': 1.809230719452787e-08},
#  'blistered_NOUN': {'sum_usage': 674,
#   'median_usage': 11.0,
#   'mean_usage': 13.48,
#   'max_usage': 41,
#   'min_usage': 3,
#   'frequency': 1.1908413133898226e-08},
#  'bearer_NOUN': {'sum_usage': 774205,
#   'median_usage': 15198.5,
#   'mean_usage': 15484.1,
#   'max_usage': 20957,
#   'min_usage': 11651,
#   'frequency': 1.3678862003456492e-05},
#  'argosy_NOUN': {'sum_usage': 10300,
#   'median_usage': 208.5,
#   'mean_usage': 206,
#   'max_usage': 333,
#   'min_usage': 112,
#   'frequency': 1.8198316806995806e-07},
#  'ath_NOUN': {'sum_usage': 18386,
#   'median_usage': 360.0,
#   'mean_usage': 367.72,
#   'max_usage': 462,
#   'min_usage': 261,
#   'frequency': 3.2484878913924745e-07},
#  'brody_NOUN': {'sum_usage': 3877,
#   'median_usage': 61.0,
#   'mean_usage': 77.54,
#   'max_usage': 365,
#   'min_usage': 18,
#   'frequency': 6.849987792303179e-08},
#  'adios_X': {'sum_usage': 1396,
#   'median_usage': 24.5,
#   'mean_usage': 27.92,
#   'max_usage': 93,
#   'min_usage': 3,
#   'frequency': 2.4664903167539946e-08},
#  'blucher_NOUN': {'sum_usage': 1180,
#   'median_usage': 22.0,
#   'mean_usage': 23.6,
#   'max_usage': 50,
#   'min_usage': 5,
#   'frequency': 2.0848557118694225e-08},
#  'bodkin_NOUN': {'sum_usage': 24214,
#   'median_usage': 486.5,
#   'mean_usage': 484.28,
#   'max_usage': 636,
#   'min_usage': 312,
#   'frequency': 4.2781945938310334e-07},
#  'belf_NOUN': {'sum_usage': 4395,
#   'median_usage': 86.5,
#   'mean_usage': 87.9,
#   'max_usage': 131,
#   'min_usage': 48,
#   'frequency': 7.765204113276366e-08},
#  'alrica_NOUN': {'sum_usage': 667,
#   'median_usage': 10.0,
#   'mean_usage': 13.34,
#   'max_usage': 46,
#   'min_usage': 2,
#   'frequency': 1.1784735252685634e-08},
#  'bold_ADJ': {'sum_usage': 2124354,
#   'median_usage': 41948.5,
#   'mean_usage': 42487.08,
#   'max_usage': 54300,
#   'min_usage': 34374,
#   'frequency': 3.753365738078521e-05},
#  'acorn_NOUN': {'sum_usage': 108939,
#   'median_usage': 2151.5,
#   'mean_usage': 2178.78,
#   'max_usage': 2904,
#   'min_usage': 1625,
#   'frequency': 1.9247635287740933e-06},
#  'abutment_NOUN': {'sum_usage': 109785,
#   'median_usage': 2089.5,
#   'mean_usage': 2195.7,
#   'max_usage': 3358,
#   'min_usage': 1271,
#   'frequency': 1.9397108841320723e-06},
#  'belmont_NOUN': {'sum_usage': 55355,
#   'median_usage': 986.0,
#   'mean_usage': 1107.1,
#   'max_usage': 3316,
#   'min_usage': 536,
#   'frequency': 9.780270163604396e-07},
#  'anahuac_NOUN': {'sum_usage': 8479,
#   'median_usage': 148.5,
#   'mean_usage': 169.58,
#   'max_usage': 579,
#   'min_usage': 37,
#   'frequency': 1.4980925068593927e-07},
#  'cavendish_NOUN': {'sum_usage': 1903,
#   'median_usage': 31.5,
#   'mean_usage': 38.06,
#   'max_usage': 213,
#   'min_usage': 2,
#   'frequency': 3.36227154210806e-08},
#  'bilsdale_NOUN': {'sum_usage': 2367,
#   'median_usage': 33.0,
#   'mean_usage': 47.34,
#   'max_usage': 193,
#   'min_usage': 7,
#   'frequency': 4.182079211860104e-08},
#  'association_NOUN': {'sum_usage': 2382267,
#   'median_usage': 46627.5,
#   'mean_usage': 47645.34,
#   'max_usage': 82587,
#   'min_usage': 33337,
#   'frequency': 4.209053357752571e-05},
#  'basinghall_NOUN': {'sum_usage': 26271,
#   'median_usage': 394.0,
#   'mean_usage': 525.42,
#   'max_usage': 1937,
#   'min_usage': 218,
#   'frequency': 4.6416308819086095e-07},
#  'beckon_NOUN': {'sum_usage': 792,
#   'median_usage': 16.0,
#   'mean_usage': 15.84,
#   'max_usage': 38,
#   'min_usage': 3,
#   'frequency': 1.3993268845767648e-08},
#  'alsh_NOUN': {'sum_usage': 2290,
#   'median_usage': 44.5,
#   'mean_usage': 45.8,
#   'max_usage': 116,
#   'min_usage': 12,
#   'frequency': 4.046033542526252e-08},
#  'asperula_NOUN': {'sum_usage': 3534,
#   'median_usage': 64.5,
#   'mean_usage': 70.68,
#   'max_usage': 189,
#   'min_usage': 30,
#   'frequency': 6.243966174361473e-08},
#  'brington_NOUN': {'sum_usage': 4566,
#   'median_usage': 72.0,
#   'mean_usage': 91.32,
#   'max_usage': 560,
#   'min_usage': 17,
#   'frequency': 8.067331508809985e-08},
#  'agency_NOUN': {'sum_usage': 1340247,
#   'median_usage': 26997.0,
#   'mean_usage': 26804.94,
#   'max_usage': 31214,
#   'min_usage': 21316,
#   'frequency': 2.3679844180219135e-05},
#  'active_NOUN': {'sum_usage': 9540,
#   'median_usage': 186.0,
#   'mean_usage': 190.8,
#   'max_usage': 294,
#   'min_usage': 116,
#   'frequency': 1.685552838240194e-07},
#  'bromhead_NOUN': {'sum_usage': 7515,
#   'median_usage': 116.0,
#   'mean_usage': 150.3,
#   'max_usage': 880,
#   'min_usage': 28,
#   'frequency': 1.3277703961609075e-07},
#  'braunfels_NOUN': {'sum_usage': 1760,
#   'median_usage': 24.0,
#   'mean_usage': 35.2,
#   'max_usage': 158,
#   'min_usage': 9,
#   'frequency': 3.109615299059477e-08},
#  'blindness_NOUN': {'sum_usage': 254661,
#   'median_usage': 5079.5,
#   'mean_usage': 5093.22,
#   'max_usage': 6386,
#   'min_usage': 4043,
#   'frequency': 4.4994189867828724e-06},
#  'apothe_NOUN': {'sum_usage': 941,
#   'median_usage': 16.5,
#   'mean_usage': 18.82,
#   'max_usage': 60,
#   'min_usage': 3,
#   'frequency': 1.6625840888721412e-08},
#  'adult_ADJ': {'sum_usage': 95614,
#   'median_usage': 1905.0,
#   'mean_usage': 1912.28,
#   'max_usage': 2903,
#   'min_usage': 1109,
#   'frequency': 1.6893338477515504e-06},
#  'bey_NOUN': {'sum_usage': 25718,
#   'median_usage': 470.5,
#   'mean_usage': 514.36,
#   'max_usage': 1706,
#   'min_usage': 286,
#   'frequency': 4.5439253557506614e-07},
#  'camillo_NOUN': {'sum_usage': 31178,
#   'median_usage': 564.0,
#   'mean_usage': 623.56,
#   'max_usage': 1230,
#   'min_usage': 231,
#   'frequency': 5.508612829208885e-07},
#  'arabesque_NOUN': {'sum_usage': 50261,
#   'median_usage': 951.0,
#   'mean_usage': 1005.22,
#   'max_usage': 1836,
#   'min_usage': 665,
#   'frequency': 8.880248553751613e-07},
#  'appendix_NOUN': {'sum_usage': 398468,
#   'median_usage': 7145.0,
#   'mean_usage': 7969.36,
#   'max_usage': 16921,
#   'min_usage': 3922,
#   'frequency': 7.040239710145636e-06},
#  'bentley_NOUN': {'sum_usage': 348630,
#   'median_usage': 6629.5,
#   'mean_usage': 6972.6,
#   'max_usage': 12737,
#   'min_usage': 4643,
#   'frequency': 6.159688532449464e-06},
#  'argun_NOUN': {'sum_usage': 2925,
#   'median_usage': 46.0,
#   'mean_usage': 58.5,
#   'max_usage': 232,
#   'min_usage': 7,
#   'frequency': 5.167968607811916e-08},
#  'affinis_NOUN': {'sum_usage': 4973,
#   'median_usage': 97.5,
#   'mean_usage': 99.46,
#   'max_usage': 184,
#   'min_usage': 45,
#   'frequency': 8.78643004671749e-08},
#  'aim_VERB': {'sum_usage': 1314855,
#   'median_usage': 26733.0,
#   'mean_usage': 26297.1,
#   'max_usage': 37203,
#   'min_usage': 19580,
#   'frequency': 2.3231211500254825e-05},
#  'boeotians_NOUN': {'sum_usage': 25492,
#   'median_usage': 403.5,
#   'mean_usage': 509.84,
#   'max_usage': 1708,
#   'min_usage': 118,
#   'frequency': 4.5039950683877386e-07},
#  'ataroth_NOUN': {'sum_usage': 2201,
#   'median_usage': 35.0,
#   'mean_usage': 44.02,
#   'max_usage': 156,
#   'min_usage': 6,
#   'frequency': 3.8887859506988125e-08},
#  'akt_NOUN': {'sum_usage': 4753,
#   'median_usage': 77.5,
#   'mean_usage': 95.06,
#   'max_usage': 812,
#   'min_usage': 40,
#   'frequency': 8.397728134335055e-08},
#  'blide_NOUN': {'sum_usage': 1284,
#   'median_usage': 27.0,
#   'mean_usage': 25.68,
#   'max_usage': 57,
#   'min_usage': 2,
#   'frequency': 2.268605706813846e-08},
#  'amateur_NOUN': {'sum_usage': 495156,
#   'median_usage': 10271.5,
#   'mean_usage': 9903.12,
#   'max_usage': 15300,
#   'min_usage': 4910,
#   'frequency': 8.748549278528946e-06},
#  'argentiferous_NOUN': {'sum_usage': 1743,
#   'median_usage': 25.0,
#   'mean_usage': 34.86,
#   'max_usage': 177,
#   'min_usage': 3,
#   'frequency': 3.079579242193562e-08},
#  'baruch_NOUN': {'sum_usage': 34115,
#   'median_usage': 631.0,
#   'mean_usage': 682.3,
#   'max_usage': 1912,
#   'min_usage': 290,
#   'frequency': 6.027529882239436e-07},
#  'abscess_ADJ': {'sum_usage': 4731,
#   'median_usage': 85.0,
#   'mean_usage': 94.62,
#   'max_usage': 247,
#   'min_usage': 23,
#   'frequency': 8.358857943096812e-08},
#  'articulata_NOUN': {'sum_usage': 6361,
#   'median_usage': 111.5,
#   'mean_usage': 127.22,
#   'max_usage': 380,
#   'min_usage': 63,
#   'frequency': 1.1238785748475759e-07},
#  'annuity_NOUN': {'sum_usage': 988069,
#   'median_usage': 18857.5,
#   'mean_usage': 19761.38,
#   'max_usage': 35381,
#   'min_usage': 12403,
#   'frequency': 1.745746863026363e-05},
#  'akhbar_NOUN': {'sum_usage': 2922,
#   'median_usage': 50.5,
#   'mean_usage': 58.44,
#   'max_usage': 244,
#   'min_usage': 20,
#   'frequency': 5.1626681271885185e-08},
#  'banda_NOUN': {'sum_usage': 1503,
#   'median_usage': 26.5,
#   'mean_usage': 30.06,
#   'max_usage': 94,
#   'min_usage': 8,
#   'frequency': 2.655540792321815e-08},
#  'brahmin_NOUN': {'sum_usage': 6481,
#   'median_usage': 70.0,
#   'mean_usage': 129.62,
#   'max_usage': 745,
#   'min_usage': 4,
#   'frequency': 1.1450804973411632e-07},
#  'bagnio_NOUN': {'sum_usage': 5452,
#   'median_usage': 106.0,
#   'mean_usage': 109.04,
#   'max_usage': 247,
#   'min_usage': 48,
#   'frequency': 9.632740119586517e-08},
#  'abyss_NOUN': {'sum_usage': 254830,
#   'median_usage': 4959.0,
#   'mean_usage': 5096.6,
#   'max_usage': 7340,
#   'min_usage': 4092,
#   'frequency': 4.50240492420072e-06},
#  'binney_NOUN': {'sum_usage': 48001,
#   'median_usage': 893.5,
#   'mean_usage': 960.02,
#   'max_usage': 2088,
#   'min_usage': 355,
#   'frequency': 8.480945680122385e-07},
#  'blagg_NOUN': {'sum_usage': 5962,
#   'median_usage': 68.5,
#   'mean_usage': 119.24,
#   'max_usage': 1665,
#   'min_usage': 21,
#   'frequency': 1.053382182556398e-07},
#  'angouleme_NOUN': {'sum_usage': 27556,
#   'median_usage': 476.5,
#   'mean_usage': 551.12,
#   'max_usage': 1310,
#   'min_usage': 277,
#   'frequency': 4.868668135277441e-07},
#  'byzantine_NOUN': {'sum_usage': 225122,
#   'median_usage': 4005.5,
#   'mean_usage': 4502.44,
#   'max_usage': 19312,
#   'min_usage': 2020,
#   'frequency': 3.977515996334475e-06},
#  'abed_NOUN': {'sum_usage': 1871,
#   'median_usage': 37.5,
#   'mean_usage': 37.42,
#   'max_usage': 75,
#   'min_usage': 13,
#   'frequency': 3.30573308212516e-08},
#  'amazona_NOUN': {'sum_usage': 7079,
#   'median_usage': 105.5,
#   'mean_usage': 141.58,
#   'max_usage': 833,
#   'min_usage': 10,
#   'frequency': 1.250736744434207e-07},
#  'bridlington_NOUN': {'sum_usage': 52600,
#   'median_usage': 1047.0,
#   'mean_usage': 1052,
#   'max_usage': 2099,
#   'min_usage': 393,
#   'frequency': 9.29350935968912e-07},
#  'another_DET': {'sum_usage': 28002952,
#   'median_usage': 564760.0,
#   'mean_usage': 560059.04,
#   'max_usage': 707279,
#   'min_usage': 455552,
#   'frequency': 0.0004947636815797056},
#  'bondholder_NOUN': {'sum_usage': 108978,
#   'median_usage': 2204.5,
#   'mean_usage': 2179.56,
#   'max_usage': 4968,
#   'min_usage': 307,
#   'frequency': 1.925452591255135e-06},
#  'betts_NOUN': {'sum_usage': 42452,
#   'median_usage': 735.5,
#   'mean_usage': 849.04,
#   'max_usage': 2075,
#   'min_usage': 486,
#   'frequency': 7.500533447481417e-07},
#  'apelles_NOUN': {'sum_usage': 32752,
#   'median_usage': 610.5,
#   'mean_usage': 655.04,
#   'max_usage': 1493,
#   'min_usage': 342,
#   'frequency': 5.786711379249773e-07},
#  'beckmann_NOUN': {'sum_usage': 14761,
#   'median_usage': 226.0,
#   'mean_usage': 295.22,
#   'max_usage': 742,
#   'min_usage': 114,
#   'frequency': 2.6080131493986904e-07},
#  'artaria_NOUN': {'sum_usage': 2000,
#   'median_usage': 31.0,
#   'mean_usage': 40,
#   'max_usage': 189,
#   'min_usage': 3,
#   'frequency': 3.533653748931224e-08},
#  'btone_NOUN': {'sum_usage': 6494,
#   'median_usage': 120.0,
#   'mean_usage': 129.88,
#   'max_usage': 271,
#   'min_usage': 49,
#   'frequency': 1.1473773722779685e-07},
#  'both_DET': {'sum_usage': 29163822,
#   'median_usage': 580099.5,
#   'mean_usage': 583276.44,
#   'max_usage': 732831,
#   'min_usage': 473734,
#   'frequency': 0.0005152742447173146},
#  'cast_VERB': {'sum_usage': 3811260,
#   'median_usage': 75867.5,
#   'mean_usage': 76225.2,
#   'max_usage': 95611,
#   'min_usage': 58153,
#   'frequency': 6.733836593575809e-05},
#  'alpen_NOUN': {'sum_usage': 5428,
#   'median_usage': 109.5,
#   'mean_usage': 108.56,
#   'max_usage': 318,
#   'min_usage': 21,
#   'frequency': 9.590336274599343e-08},
#  'bohu_NOUN': {'sum_usage': 1451,
#   'median_usage': 26.5,
#   'mean_usage': 29.02,
#   'max_usage': 98,
#   'min_usage': 10,
#   'frequency': 2.5636657948496033e-08},
#  'aha_NOUN': {'sum_usage': 2931,
#   'median_usage': 60.0,
#   'mean_usage': 58.62,
#   'max_usage': 95,
#   'min_usage': 30,
#   'frequency': 5.178569569058709e-08},
#  'almaviva_NOUN': {'sum_usage': 4376,
#   'median_usage': 77.0,
#   'mean_usage': 87.52,
#   'max_usage': 257,
#   'min_usage': 10,
#   'frequency': 7.731634402661518e-08},
#  'abdal_NOUN': {'sum_usage': 4462,
#   'median_usage': 44.5,
#   'mean_usage': 89.24,
#   'max_usage': 858,
#   'min_usage': 4,
#   'frequency': 7.883581513865561e-08},
#  'acquit_NOUN': {'sum_usage': 2791,
#   'median_usage': 51.0,
#   'mean_usage': 55.82,
#   'max_usage': 207,
#   'min_usage': 15,
#   'frequency': 4.9312138066335236e-08},
#  'basilica_NOUN': {'sum_usage': 94765,
#   'median_usage': 1761.5,
#   'mean_usage': 1895.3,
#   'max_usage': 4071,
#   'min_usage': 562,
#   'frequency': 1.6743334875873373e-06},
#  'carson_NOUN': {'sum_usage': 52836,
#   'median_usage': 812.5,
#   'mean_usage': 1056.72,
#   'max_usage': 3165,
#   'min_usage': 520,
#   'frequency': 9.335206473926509e-07},
#  'bunting_NOUN': {'sum_usage': 31578,
#   'median_usage': 595.0,
#   'mean_usage': 631.56,
#   'max_usage': 1309,
#   'min_usage': 360,
#   'frequency': 5.57928590418751e-07},
#  'chaumont_NOUN': {'sum_usage': 27165,
#   'median_usage': 497.5,
#   'mean_usage': 543.3,
#   'max_usage': 1124,
#   'min_usage': 177,
#   'frequency': 4.799585204485835e-07},
#  'benth_NOUN': {'sum_usage': 35443,
#   'median_usage': 585.0,
#   'mean_usage': 708.86,
#   'max_usage': 2322,
#   'min_usage': 103,
#   'frequency': 6.262164491168469e-07},
#  'bexley_NOUN': {'sum_usage': 29479,
#   'median_usage': 585.0,
#   'mean_usage': 589.58,
#   'max_usage': 1234,
#   'min_usage': 185,
#   'frequency': 5.208428943237178e-07},
#  'albumazar_NOUN': {'sum_usage': 3320,
#   'median_usage': 48.0,
#   'mean_usage': 66.4,
#   'max_usage': 649,
#   'min_usage': 16,
#   'frequency': 5.8658652232258324e-08},
#  'ache_NOUN': {'sum_usage': 81548,
#   'median_usage': 1620.0,
#   'mean_usage': 1630.96,
#   'max_usage': 2128,
#   'min_usage': 1086,
#   'frequency': 1.4408119795892175e-06},
#  'absolom_NOUN': {'sum_usage': 4099,
#   'median_usage': 77.5,
#   'mean_usage': 81.98,
#   'max_usage': 316,
#   'min_usage': 32,
#   'frequency': 7.242223358434545e-08},
#  'boston_NOUN': {'sum_usage': 1029799,
#   'median_usage': 20082.0,
#   'mean_usage': 20595.98,
#   'max_usage': 31331,
#   'min_usage': 13124,
#   'frequency': 1.819476548497813e-05},
#  'adwertisements_NOUN': {'sum_usage': 3762,
#   'median_usage': 78.0,
#   'mean_usage': 75.24,
#   'max_usage': 210,
#   'min_usage': 12,
#   'frequency': 6.646802701739632e-08},
#  'broadcloth_NOUN': {'sum_usage': 28554,
#   'median_usage': 558.5,
#   'mean_usage': 571.08,
#   'max_usage': 906,
#   'min_usage': 354,
#   'frequency': 5.044997457349109e-07},
#  'baumes_NOUN': {'sum_usage': 931,
#   'median_usage': 13.0,
#   'mean_usage': 18.62,
#   'max_usage': 94,
#   'min_usage': 2,
#   'frequency': 1.644915820127485e-08},
#  'arsenical_NOUN': {'sum_usage': 53214,
#   'median_usage': 987.5,
#   'mean_usage': 1064.28,
#   'max_usage': 1855,
#   'min_usage': 487,
#   'frequency': 9.401992529781308e-07},
#  'afflict_VERB': {'sum_usage': 576063,
#   'median_usage': 11364.0,
#   'mean_usage': 11521.26,
#   'max_usage': 18832,
#   'min_usage': 8487,
#   'frequency': 1.017803589785284e-05},
#  'abbas_NOUN': {'sum_usage': 3738,
#   'median_usage': 60.0,
#   'mean_usage': 74.76,
#   'max_usage': 203,
#   'min_usage': 16,
#   'frequency': 6.604398856752458e-08},
#  'babell_NOUN': {'sum_usage': 1143,
#   'median_usage': 20.0,
#   'mean_usage': 22.86,
#   'max_usage': 57,
#   'min_usage': 4,
#   'frequency': 2.0194831175141948e-08},
#  'blissett_NOUN': {'sum_usage': 3995,
#   'median_usage': 48.5,
#   'mean_usage': 79.9,
#   'max_usage': 1163,
#   'min_usage': 7,
#   'frequency': 7.058473363490121e-08},
#  'acquaint_VERB': {'sum_usage': 3161161,
#   'median_usage': 61066.0,
#   'mean_usage': 63223.22,
#   'max_usage': 96341,
#   'min_usage': 49241,
#   'frequency': 5.585224209312589e-05},
#  'brick_NOUN': {'sum_usage': 1817537,
#   'median_usage': 35713.5,
#   'mean_usage': 36350.74,
#   'max_usage': 49569,
#   'min_usage': 26739,
#   'frequency': 3.2112732169356055e-05},
#  'bunbury_NOUN': {'sum_usage': 52370,
#   'median_usage': 1008.0,
#   'mean_usage': 1047.4,
#   'max_usage': 1718,
#   'min_usage': 564,
#   'frequency': 9.252872341576411e-07},
#  'buckle_VERB': {'sum_usage': 79401,
#   'median_usage': 1543.5,
#   'mean_usage': 1588.02,
#   'max_usage': 2570,
#   'min_usage': 1160,
#   'frequency': 1.4028782065944408e-06},
#  'assist_VERB': {'sum_usage': 3712982,
#   'median_usage': 74023.5,
#   'mean_usage': 74259.64,
#   'max_usage': 91782,
#   'min_usage': 60209,
#   'frequency': 6.560196382007078e-05},
#  'biblioteca_NOUN': {'sum_usage': 11311,
#   'median_usage': 211.0,
#   'mean_usage': 226.22,
#   'max_usage': 610,
#   'min_usage': 83,
#   'frequency': 1.998457877708054e-07},
#  'cambrian_NOUN': {'sum_usage': 134578,
#   'median_usage': 2719.0,
#   'mean_usage': 2691.56,
#   'max_usage': 4270,
#   'min_usage': 1199,
#   'frequency': 2.3777602711183317e-06},
#  'bevue_NOUN': {'sum_usage': 1836,
#   'median_usage': 31.0,
#   'mean_usage': 36.72,
#   'max_usage': 97,
#   'min_usage': 2,
#   'frequency': 3.243894141518864e-08},
#  'algardi_NOUN': {'sum_usage': 1755,
#   'median_usage': 32.5,
#   'mean_usage': 35.1,
#   'max_usage': 94,
#   'min_usage': 7,
#   'frequency': 3.1007811646871496e-08},
#  'arron_NOUN': {'sum_usage': 461,
#   'median_usage': 8.0,
#   'mean_usage': 9.22,
#   'max_usage': 21,
#   'min_usage': 3,
#   'frequency': 8.145071891286472e-09},
#  'articulus_NOUN': {'sum_usage': 1965,
#   'median_usage': 25.5,
#   'mean_usage': 39.3,
#   'max_usage': 244,
#   'min_usage': 4,
#   'frequency': 3.471814808324928e-08},
#  'adverting_NOUN': {'sum_usage': 42668,
#   'median_usage': 664.5,
#   'mean_usage': 853.36,
#   'max_usage': 3813,
#   'min_usage': 200,
#   'frequency': 7.538696907969874e-07},
#  'alen_NOUN': {'sum_usage': 11490,
#   'median_usage': 181.0,
#   'mean_usage': 229.8,
#   'max_usage': 1149,
#   'min_usage': 52,
#   'frequency': 2.0300840787609884e-07},
#  'animate_VERB': {'sum_usage': 811957,
#   'median_usage': 15424.5,
#   'mean_usage': 16239.14,
#   'max_usage': 27256,
#   'min_usage': 11959,
#   'frequency': 1.434587448510475e-05},
#  'baan_NOUN': {'sum_usage': 897,
#   'median_usage': 12.5,
#   'mean_usage': 17.94,
#   'max_usage': 81,
#   'min_usage': 2,
#   'frequency': 1.584843706395654e-08},
#  'bousquet_NOUN': {'sum_usage': 2561,
#   'median_usage': 49.5,
#   'mean_usage': 51.22,
#   'max_usage': 136,
#   'min_usage': 5,
#   'frequency': 4.524843625506433e-08},
#  'bournemouth_NOUN': {'sum_usage': 107094,
#   'median_usage': 1445.0,
#   'mean_usage': 2141.88,
#   'max_usage': 7286,
#   'min_usage': 99,
#   'frequency': 1.8921655729402027e-06},
#  'barbican_NOUN': {'sum_usage': 11981,
#   'median_usage': 226.5,
#   'mean_usage': 239.62,
#   'max_usage': 439,
#   'min_usage': 139,
#   'frequency': 2.11683527829725e-07},
#  'champ_NOUN': {'sum_usage': 9376,
#   'median_usage': 186.5,
#   'mean_usage': 187.52,
#   'max_usage': 262,
#   'min_usage': 112,
#   'frequency': 1.656576877498958e-07},
#  'axe_NOUN': {'sum_usage': 431468,
#   'median_usage': 8603.0,
#   'mean_usage': 8629.36,
#   'max_usage': 10288,
#   'min_usage': 6923,
#   'frequency': 7.623292578719287e-06},
#  'aska_NOUN': {'sum_usage': 564,
#   'median_usage': 10.5,
#   'mean_usage': 11.28,
#   'max_usage': 39,
#   'min_usage': 2,
#   'frequency': 9.964903571986052e-09},
#  'alfort_NOUN': {'sum_usage': 4964,
#   'median_usage': 92.0,
#   'mean_usage': 99.28,
#   'max_usage': 199,
#   'min_usage': 29,
#   'frequency': 8.770528604847299e-08},
#  'arrowsmith_NOUN': {'sum_usage': 34856,
#   'median_usage': 723.0,
#   'mean_usage': 697.12,
#   'max_usage': 1161,
#   'min_usage': 317,
#   'frequency': 6.158451753637338e-07},
#  'area_NOUN': {'sum_usage': 4692622,
#   'median_usage': 91435.0,
#   'mean_usage': 93852.44,
#   'max_usage': 223445,
#   'min_usage': 31903,
#   'frequency': 8.29105066130857e-05},
#  'begg_NOUN': {'sum_usage': 1021,
#   'median_usage': 18.0,
#   'mean_usage': 20.42,
#   'max_usage': 68,
#   'min_usage': 4,
#   'frequency': 1.80393023882939e-08},
#  'blight_VERB': {'sum_usage': 103819,
#   'median_usage': 2067.5,
#   'mean_usage': 2076.38,
#   'max_usage': 2906,
#   'min_usage': 1573,
#   'frequency': 1.8343019928014539e-06},
#  'adoro_NOUN': {'sum_usage': 683,
#   'median_usage': 12.0,
#   'mean_usage': 13.66,
#   'max_usage': 48,
#   'min_usage': 2,
#   'frequency': 1.2067427552600131e-08},
#  'basks_NOUN': {'sum_usage': 1969,
#   'median_usage': 39.5,
#   'mean_usage': 39.38,
#   'max_usage': 65,
#   'min_usage': 21,
#   'frequency': 3.4788821158227906e-08},
#  'beket_NOUN': {'sum_usage': 3005,
#   'median_usage': 40.0,
#   'mean_usage': 60.1,
#   'max_usage': 352,
#   'min_usage': 2,
#   'frequency': 5.3093147577691645e-08},
#  'brave_NOUN': {'sum_usage': 45719,
#   'median_usage': 893.5,
#   'mean_usage': 914.38,
#   'max_usage': 1432,
#   'min_usage': 526,
#   'frequency': 8.077755787369332e-07},
#  'bcenes_NOUN': {'sum_usage': 760,
#   'median_usage': 16.0,
#   'mean_usage': 15.2,
#   'max_usage': 28,
#   'min_usage': 6,
#   'frequency': 1.3427884245938652e-08},
#  'broussais_NOUN': {'sum_usage': 6788,
#   'median_usage': 117.5,
#   'mean_usage': 135.76,
#   'max_usage': 525,
#   'min_usage': 26,
#   'frequency': 1.1993220823872576e-07},
#  'atmospheric_ADJ': {'sum_usage': 694493,
#   'median_usage': 14047.5,
#   'mean_usage': 13889.86,
#   'max_usage': 16879,
#   'min_usage': 11277,
#   'frequency': 1.2270488965282464e-05},
#  'adjudged_NOUN': {'sum_usage': 3774,
#   'median_usage': 68.0,
#   'mean_usage': 75.48,
#   'max_usage': 243,
#   'min_usage': 7,
#   'frequency': 6.66800462423322e-08},
#  'ashby_NOUN': {'sum_usage': 77552,
#   'median_usage': 1510.5,
#   'mean_usage': 1551.04,
#   'max_usage': 2643,
#   'min_usage': 923,
#   'frequency': 1.3702095776855715e-06},
#  'boman_NOUN': {'sum_usage': 46660,
#   'median_usage': 950.5,
#   'mean_usage': 933.2,
#   'max_usage': 1531,
#   'min_usage': 533,
#   'frequency': 8.244014196256546e-07},
#  'arbigland_NOUN': {'sum_usage': 1259,
#   'median_usage': 19.0,
#   'mean_usage': 25.18,
#   'max_usage': 192,
#   'min_usage': 2,
#   'frequency': 2.2244350349522057e-08},
#  'breach_VERB': {'sum_usage': 41062,
#   'median_usage': 747.0,
#   'mean_usage': 821.24,
#   'max_usage': 1695,
#   'min_usage': 492,
#   'frequency': 7.254944511930697e-07},
#  'alick_NOUN': {'sum_usage': 38098,
#   'median_usage': 618.0,
#   'mean_usage': 761.96,
#   'max_usage': 3571,
#   'min_usage': 122,
#   'frequency': 6.731257026339089e-07},
#  'beatson_NOUN': {'sum_usage': 29092,
#   'median_usage': 462.5,
#   'mean_usage': 581.84,
#   'max_usage': 3080,
#   'min_usage': 239,
#   'frequency': 5.140052743195359e-07},
#  'anns_NOUN': {'sum_usage': 2683,
#   'median_usage': 53.5,
#   'mean_usage': 53.66,
#   'max_usage': 77,
#   'min_usage': 31,
#   'frequency': 4.740396504191237e-08},
#  'arouse_VERB': {'sum_usage': 690589,
#   'median_usage': 13027.0,
#   'mean_usage': 13811.78,
#   'max_usage': 25020,
#   'min_usage': 9376,
#   'frequency': 1.2201512044103326e-05},
#  'blackst_NOUN': {'sum_usage': 2447,
#   'median_usage': 36.0,
#   'mean_usage': 48.94,
#   'max_usage': 315,
#   'min_usage': 2,
#   'frequency': 4.323425361817353e-08},
#  'baz_NOUN': {'sum_usage': 2167,
#   'median_usage': 38.0,
#   'mean_usage': 43.34,
#   'max_usage': 132,
#   'min_usage': 17,
#   'frequency': 3.8287138369669817e-08},
#  'abound_VERB': {'sum_usage': 1222252,
#   'median_usage': 24425.0,
#   'mean_usage': 24445.04,
#   'max_usage': 34938,
#   'min_usage': 17724,
#   'frequency': 2.1595076809693435e-05},
#  'awfully_ADV': {'sum_usage': 133532,
#   'median_usage': 2559.0,
#   'mean_usage': 2670.64,
#   'max_usage': 4912,
#   'min_usage': 1560,
#   'frequency': 2.3592792620114213e-06},
#  'bonus_NOUN': {'sum_usage': 270445,
#   'median_usage': 4857.0,
#   'mean_usage': 5408.9,
#   'max_usage': 11519,
#   'min_usage': 2537,
#   'frequency': 4.778294940648525e-06},
#  'aram_ADJ': {'sum_usage': 1348,
#   'median_usage': 24.0,
#   'mean_usage': 26.96,
#   'max_usage': 90,
#   'min_usage': 5,
#   'frequency': 2.3816826267796453e-08},
#  'bruguiere_NOUN': {'sum_usage': 1909,
#   'median_usage': 29.5,
#   'mean_usage': 38.18,
#   'max_usage': 110,
#   'min_usage': 2,
#   'frequency': 3.372872503354854e-08},
#  'balkan_NOUN': {'sum_usage': 95382,
#   'median_usage': 1548.0,
#   'mean_usage': 1907.64,
#   'max_usage': 9362,
#   'min_usage': 252,
#   'frequency': 1.6852348094027901e-06},
#  'analytic_NOUN': {'sum_usage': 6626,
#   'median_usage': 136.5,
#   'mean_usage': 132.52,
#   'max_usage': 204,
#   'min_usage': 56,
#   'frequency': 1.1706994870209146e-07},
#  'alter_VERB': {'sum_usage': 3986547,
#   'median_usage': 79249.5,
#   'mean_usage': 79730.94,
#   'max_usage': 102763,
#   'min_usage': 66151,
#   'frequency': 7.043538375920262e-05},
#  'apportion_NOUN': {'sum_usage': 3307,
#   'median_usage': 64.0,
#   'mean_usage': 66.14,
#   'max_usage': 108,
#   'min_usage': 32,
#   'frequency': 5.842896473857779e-08},
#  'avienus_NOUN': {'sum_usage': 4689,
#   'median_usage': 73.0,
#   'mean_usage': 93.78,
#   'max_usage': 234,
#   'min_usage': 29,
#   'frequency': 8.284651214369255e-08},
#  'banish_NOUN': {'sum_usage': 7909,
#   'median_usage': 146.0,
#   'mean_usage': 158.18,
#   'max_usage': 281,
#   'min_usage': 78,
#   'frequency': 1.3973833750148526e-07},
#  'boucicault_NOUN': {'sum_usage': 27657,
#   'median_usage': 520.5,
#   'mean_usage': 553.14,
#   'max_usage': 1655,
#   'min_usage': 12,
#   'frequency': 4.886513086709543e-07},
#  'blotting_NOUN': {'sum_usage': 11113,
#   'median_usage': 208.0,
#   'mean_usage': 222.26,
#   'max_usage': 477,
#   'min_usage': 99,
#   'frequency': 1.9634747055936347e-07},
#  'buddha_NOUN': {'sum_usage': 312320,
#   'median_usage': 5962.5,
#   'mean_usage': 6246.4,
#   'max_usage': 16467,
#   'min_usage': 838,
#   'frequency': 5.518153694331e-06},
#  'bahar_NOUN': {'sum_usage': 17283,
#   'median_usage': 277.5,
#   'mean_usage': 345.66,
#   'max_usage': 1326,
#   'min_usage': 86,
#   'frequency': 3.0536068871389174e-07},
#  'andely_NOUN': {'sum_usage': 1991,
#   'median_usage': 34.5,
#   'mean_usage': 39.82,
#   'max_usage': 214,
#   'min_usage': 4,
#   'frequency': 3.5177523070610337e-08},
#  'brahminical_NOUN': {'sum_usage': 4683,
#   'median_usage': 87.0,
#   'mean_usage': 93.66,
#   'max_usage': 214,
#   'min_usage': 18,
#   'frequency': 8.274050253122462e-08},
#  'boileau_NOUN': {'sum_usage': 71356,
#   'median_usage': 1343.0,
#   'mean_usage': 1427.12,
#   'max_usage': 2639,
#   'min_usage': 649,
#   'frequency': 1.2607369845436822e-06},
#  'alveolina_NOUN': {'sum_usage': 2386,
#   'median_usage': 24.5,
#   'mean_usage': 47.72,
#   'max_usage': 341,
#   'min_usage': 4,
#   'frequency': 4.215648922474951e-08},
#  'bardie_NOUN': {'sum_usage': 512,
#   'median_usage': 10.0,
#   'mean_usage': 10.24,
#   'max_usage': 26,
#   'min_usage': 3,
#   'frequency': 9.046153597263934e-09},
#  'buildino_NOUN': {'sum_usage': 1062,
#   'median_usage': 20.0,
#   'mean_usage': 21.24,
#   'max_usage': 59,
#   'min_usage': 2,
#   'frequency': 1.8763701406824802e-08},
#  'brushford_NOUN': {'sum_usage': 1266,
#   'median_usage': 17.0,
#   'mean_usage': 25.32,
#   'max_usage': 91,
#   'min_usage': 2,
#   'frequency': 2.236802823073465e-08},
#  'boothe_NOUN': {'sum_usage': 4269,
#   'median_usage': 63.5,
#   'mean_usage': 85.38,
#   'max_usage': 811,
#   'min_usage': 7,
#   'frequency': 7.542583927093699e-08},
#  'aram_NOUN': {'sum_usage': 4688,
#   'median_usage': 81.5,
#   'mean_usage': 93.76,
#   'max_usage': 249,
#   'min_usage': 35,
#   'frequency': 8.28288438749479e-08},
#  'anatomic_X': {'sum_usage': 1735,
#   'median_usage': 30.5,
#   'mean_usage': 34.7,
#   'max_usage': 89,
#   'min_usage': 5,
#   'frequency': 3.065444627197837e-08},
#  'cersted_NOUN': {'sum_usage': 1747,
#   'median_usage': 31.0,
#   'mean_usage': 34.94,
#   'max_usage': 133,
#   'min_usage': 6,
#   'frequency': 3.086646549691425e-08},
#  'bachelor_NOUN': {'sum_usage': 275245,
#   'median_usage': 5261.0,
#   'mean_usage': 5504.9,
#   'max_usage': 7915,
#   'min_usage': 4332,
#   'frequency': 4.863102630622875e-06},
#  'bewdley_NOUN': {'sum_usage': 26331,
#   'median_usage': 473.5,
#   'mean_usage': 526.62,
#   'max_usage': 1721,
#   'min_usage': 237,
#   'frequency': 4.6522318431554036e-07},
#  'boyne_NOUN': {'sum_usage': 74567,
#   'median_usage': 1445.5,
#   'mean_usage': 1491.34,
#   'max_usage': 2947,
#   'min_usage': 906,
#   'frequency': 1.317469795482773e-06},
#  'burst_VERB': {'sum_usage': 1474366,
#   'median_usage': 29101.0,
#   'mean_usage': 29487.32,
#   'max_usage': 37908,
#   'min_usage': 25778,
#   'frequency': 2.6049494715983668e-05},
#  'brll_NOUN': {'sum_usage': 1218,
#   'median_usage': 16.0,
#   'mean_usage': 24.36,
#   'max_usage': 103,
#   'min_usage': 3,
#   'frequency': 2.1519951330991155e-08},
#  'ai_NOUN': {'sum_usage': 35719,
#   'median_usage': 726.5,
#   'mean_usage': 714.38,
#   'max_usage': 1831,
#   'min_usage': 418,
#   'frequency': 6.31092891290372e-07},
#  'bleu_X': {'sum_usage': 13557,
#   'median_usage': 238.5,
#   'mean_usage': 271.14,
#   'max_usage': 735,
#   'min_usage': 104,
#   'frequency': 2.39528719371303e-07},
#  'antrim_NOUN': {'sum_usage': 147064,
#   'median_usage': 2742.5,
#   'mean_usage': 2941.28,
#   'max_usage': 5661,
#   'min_usage': 1412,
#   'frequency': 2.598366274664108e-06},
#  'benedicite_NOUN': {'sum_usage': 1606,
#   'median_usage': 29.0,
#   'mean_usage': 32.12,
#   'max_usage': 96,
#   'min_usage': 8,
#   'frequency': 2.837523960391773e-08},
#  'botiller_NOUN': {'sum_usage': 6744,
#   'median_usage': 90.0,
#   'mean_usage': 134.88,
#   'max_usage': 617,
#   'min_usage': 7,
#   'frequency': 1.1915480441396088e-07},
#  'assissi_NOUN': {'sum_usage': 1287,
#   'median_usage': 22.0,
#   'mean_usage': 25.74,
#   'max_usage': 86,
#   'min_usage': 5,
#   'frequency': 2.273906187437243e-08},
#  'alphabetical_NOUN': {'sum_usage': 1093,
#   'median_usage': 19.0,
#   'mean_usage': 21.86,
#   'max_usage': 99,
#   'min_usage': 5,
#   'frequency': 1.931141773790914e-08},
#  'alian_NOUN': {'sum_usage': 755,
#   'median_usage': 15.0,
#   'mean_usage': 15.1,
#   'max_usage': 28,
#   'min_usage': 4,
#   'frequency': 1.3339542902215372e-08},
#  'anticipate_VERB': {'sum_usage': 1751454,
#   'median_usage': 34753.0,
#   'mean_usage': 35029.08,
#   'max_usage': 45471,
#   'min_usage': 29612,
#   'frequency': 3.094515996590294e-05},
#  'asmoneans_NOUN': {'sum_usage': 2093,
#   'median_usage': 29.5,
#   'mean_usage': 41.86,
#   'max_usage': 221,
#   'min_usage': 6,
#   'frequency': 3.697968648256526e-08},
#  'bar_VERB': {'sum_usage': 666059,
#   'median_usage': 12369.5,
#   'mean_usage': 13321.18,
#   'max_usage': 21264,
#   'min_usage': 8780,
#   'frequency': 1.1768109411796912e-05},
#  'bidet_NOUN': {'sum_usage': 1510,
#   'median_usage': 21.5,
#   'mean_usage': 30.2,
#   'max_usage': 108,
#   'min_usage': 4,
#   'frequency': 2.6679085804430744e-08},
#  'beno_NOUN': {'sum_usage': 2382,
#   'median_usage': 15.0,
#   'mean_usage': 47.64,
#   'max_usage': 563,
#   'min_usage': 3,
#   'frequency': 4.208581614977088e-08},
#  'assorted_ADJ': {'sum_usage': 40368,
#   'median_usage': 815.0,
#   'mean_usage': 807.36,
#   'max_usage': 1139,
#   'min_usage': 578,
#   'frequency': 7.132326726842784e-07},
#  'boiler_NOUN': {'sum_usage': 2473064,
#   'median_usage': 44832.0,
#   'mean_usage': 49461.28,
#   'max_usage': 96298,
#   'min_usage': 24833,
#   'frequency': 4.369475937473425e-05},
#  'although_ADP': {'sum_usage': 12130436,
#   'median_usage': 238957.0,
#   'mean_usage': 242608.72,
#   'max_usage': 293510,
#   'min_usage': 208739,
#   'frequency': 0.00021432380323785144},
#  'apryll_NOUN': {'sum_usage': 2462,
#   'median_usage': 46.0,
#   'mean_usage': 49.24,
#   'max_usage': 103,
#   'min_usage': 7,
#   'frequency': 4.349927764934337e-08},
#  'auxiliary_ADJ': {'sum_usage': 298842,
#   'median_usage': 5761.5,
#   'mean_usage': 5976.84,
#   'max_usage': 11303,
#   'min_usage': 3894,
#   'frequency': 5.280020768190525e-06},
#  'aphis_NOUN': {'sum_usage': 48870,
#   'median_usage': 1035.0,
#   'mean_usage': 977.4,
#   'max_usage': 1935,
#   'min_usage': 334,
#   'frequency': 8.634482935513447e-07},
#  'brag_NOUN': {'sum_usage': 25465,
#   'median_usage': 506.5,
#   'mean_usage': 509.3,
#   'max_usage': 813,
#   'min_usage': 272,
#   'frequency': 4.499224635826681e-07},
#  'baiting_NOUN': {'sum_usage': 34804,
#   'median_usage': 703.5,
#   'mean_usage': 696.08,
#   'max_usage': 1192,
#   'min_usage': 349,
#   'frequency': 6.149264253890117e-07},
#  'boulay_NOUN': {'sum_usage': 10042,
#   'median_usage': 170.0,
#   'mean_usage': 200.84,
#   'max_usage': 714,
#   'min_usage': 44,
#   'frequency': 1.7742475473383678e-07},
#  'beazeley_NOUN': {'sum_usage': 3415,
#   'median_usage': 53.5,
#   'mean_usage': 68.3,
#   'max_usage': 279,
#   'min_usage': 2,
#   'frequency': 6.033713776300066e-08},
#  'bononiae_NOUN': {'sum_usage': 1317,
#   'median_usage': 18.0,
#   'mean_usage': 26.34,
#   'max_usage': 187,
#   'min_usage': 2,
#   'frequency': 2.3269109936712114e-08},
#  'alveolar_NOUN': {'sum_usage': 43417,
#   'median_usage': 825.0,
#   'mean_usage': 868.34,
#   'max_usage': 2093,
#   'min_usage': 238,
#   'frequency': 7.671032240867349e-07},
#  'agathos_NOUN': {'sum_usage': 1432,
#   'median_usage': 25.5,
#   'mean_usage': 28.64,
#   'max_usage': 104,
#   'min_usage': 3,
#   'frequency': 2.5300960842347568e-08},
#  'archaiology_NOUN': {'sum_usage': 3270,
#   'median_usage': 49.0,
#   'mean_usage': 65.4,
#   'max_usage': 234,
#   'min_usage': 22,
#   'frequency': 5.777523879502552e-08},
#  'bechstein_NOUN': {'sum_usage': 11842,
#   'median_usage': 213.0,
#   'mean_usage': 236.84,
#   'max_usage': 548,
#   'min_usage': 61,
#   'frequency': 2.0922763847421778e-07},
#  'abduction_NOUN': {'sum_usage': 54264,
#   'median_usage': 1011.5,
#   'mean_usage': 1085.28,
#   'max_usage': 1937,
#   'min_usage': 724,
#   'frequency': 9.587509351600198e-07},
#  'bellhouse_NOUN': {'sum_usage': 4554,
#   'median_usage': 80.0,
#   'mean_usage': 91.08,
#   'max_usage': 315,
#   'min_usage': 16,
#   'frequency': 8.046129586316398e-08},
#  'birchwood_NOUN': {'sum_usage': 1696,
#   'median_usage': 31.0,
#   'mean_usage': 33.92,
#   'max_usage': 79,
#   'min_usage': 7,
#   'frequency': 2.9965383790936784e-08},
#  'bias_NOUN': {'sum_usage': 275921,
#   'median_usage': 5421.0,
#   'mean_usage': 5518.42,
#   'max_usage': 6883,
#   'min_usage': 4597,
#   'frequency': 4.875046380294262e-06},
#  'bathe_NOUN': {'sum_usage': 24742,
#   'median_usage': 488.0,
#   'mean_usage': 494.84,
#   'max_usage': 756,
#   'min_usage': 260,
#   'frequency': 4.371483052802818e-07},
#  'burges_NOUN': {'sum_usage': 14109,
#   'median_usage': 175.5,
#   'mean_usage': 282.18,
#   'max_usage': 1041,
#   'min_usage': 22,
#   'frequency': 2.4928160371835325e-07},
#  'berve_NOUN': {'sum_usage': 1571,
#   'median_usage': 30.0,
#   'mean_usage': 31.42,
#   'max_usage': 53,
#   'min_usage': 13,
#   'frequency': 2.7756850197854767e-08},
#  'britford_NOUN': {'sum_usage': 2295,
#   'median_usage': 36.0,
#   'mean_usage': 45.9,
#   'max_usage': 223,
#   'min_usage': 3,
#   'frequency': 4.05486767689858e-08},
#  'adhesive_NOUN': {'sum_usage': 22670,
#   'median_usage': 436.5,
#   'mean_usage': 453.4,
#   'max_usage': 719,
#   'min_usage': 304,
#   'frequency': 4.0053965244135427e-07},
#  'behove_VERB': {'sum_usage': 193273,
#   'median_usage': 3851.5,
#   'mean_usage': 3865.46,
#   'max_usage': 4793,
#   'min_usage': 2938,
#   'frequency': 3.414799305085923e-06},
#  'balston_NOUN': {'sum_usage': 4308,
#   'median_usage': 74.5,
#   'mean_usage': 86.16,
#   'max_usage': 434,
#   'min_usage': 11,
#   'frequency': 7.611490175197857e-08},
#  'assistantship_NOUN': {'sum_usage': 1851,
#   'median_usage': 32.0,
#   'mean_usage': 37.02,
#   'max_usage': 130,
#   'min_usage': 7,
#   'frequency': 3.270396544635848e-08},
#  'adjective_NOUN': {'sum_usage': 335351,
#   'median_usage': 6764.0,
#   'mean_usage': 6707.02,
#   'max_usage': 10759,
#   'min_usage': 4109,
#   'frequency': 5.925071591789175e-06},
#  'admetus_NOUN': {'sum_usage': 17125,
#   'median_usage': 276.0,
#   'mean_usage': 342.5,
#   'max_usage': 1102,
#   'min_usage': 82,
#   'frequency': 3.025691022522361e-07},
#  'basaltic_NOUN': {'sum_usage': 11501,
#   'median_usage': 230.5,
#   'mean_usage': 230.02,
#   'max_usage': 379,
#   'min_usage': 94,
#   'frequency': 2.0320275883229007e-07},
#  'are_NOUN': {'sum_usage': 15212,
#   'median_usage': 302.0,
#   'mean_usage': 304.24,
#   'max_usage': 479,
#   'min_usage': 205,
#   'frequency': 2.687697041437089e-07},
#  'alien_NOUN': {'sum_usage': 235533,
#   'median_usage': 4305.0,
#   'mean_usage': 4710.66,
#   'max_usage': 8745,
#   'min_usage': 3093,
#   'frequency': 4.16146034223509e-06},
#  'burden_VERB': {'sum_usage': 193490,
#   'median_usage': 3938.0,
#   'mean_usage': 3869.8,
#   'max_usage': 5080,
#   'min_usage': 2802,
#   'frequency': 3.418633319403513e-06},
#  'bengo_NOUN': {'sum_usage': 2067,
#   'median_usage': 27.0,
#   'mean_usage': 41.34,
#   'max_usage': 147,
#   'min_usage': 9,
#   'frequency': 3.65203114952042e-08},
#  'boat_VERB': {'sum_usage': 13830,
#   'median_usage': 286.5,
#   'mean_usage': 276.6,
#   'max_usage': 451,
#   'min_usage': 111,
#   'frequency': 2.443521567385942e-07},
#  'antiquaires_NOUN': {'sum_usage': 1218,
#   'median_usage': 23.0,
#   'mean_usage': 24.36,
#   'max_usage': 54,
#   'min_usage': 6,
#   'frequency': 2.1519951330991155e-08},
#  'anthedon_NOUN': {'sum_usage': 2374,
#   'median_usage': 36.5,
#   'mean_usage': 47.48,
#   'max_usage': 266,
#   'min_usage': 8,
#   'frequency': 4.194446999981363e-08},
#  'apnea_NOUN': {'sum_usage': 733,
#   'median_usage': 12.0,
#   'mean_usage': 14.66,
#   'max_usage': 53,
#   'min_usage': 2,
#   'frequency': 1.2950840989832938e-08},
#  'beaumanor_NOUN': {'sum_usage': 1943,
#   'median_usage': 24.0,
#   'mean_usage': 38.86,
#   'max_usage': 432,
#   'min_usage': 3,
#   'frequency': 3.432944617086685e-08},
#  'bearhaven_NOUN': {'sum_usage': 1671,
#   'median_usage': 20.0,
#   'mean_usage': 33.42,
#   'max_usage': 205,
#   'min_usage': 5,
#   'frequency': 2.952367707232038e-08},
#  'banfi_NOUN': {'sum_usage': 2469,
#   'median_usage': 32.0,
#   'mean_usage': 49.38,
#   'max_usage': 826,
#   'min_usage': 9,
#   'frequency': 4.362295553055596e-08},
#  'burke_NOUN': {'sum_usage': 3759,
#   'median_usage': 67.0,
#   'mean_usage': 75.18,
#   'max_usage': 218,
#   'min_usage': 21,
#   'frequency': 6.641502221116237e-08},
#  'braikenridge_NOUN': {'sum_usage': 1997,
#   'median_usage': 33.5,
#   'mean_usage': 39.94,
#   'max_usage': 151,
#   'min_usage': 7,
#   'frequency': 3.5283532683078275e-08},
#  'advice_NOUN': {'sum_usage': 3082583,
#   'median_usage': 61205.0,
#   'mean_usage': 61651.66,
#   'max_usage': 82966,
#   'min_usage': 48740,
#   'frequency': 5.44639048717083e-05},
#  'bodin_NOUN': {'sum_usage': 1814,
#   'median_usage': 18.0,
#   'mean_usage': 36.28,
#   'max_usage': 301,
#   'min_usage': 2,
#   'frequency': 3.205023950280621e-08},
#  'bosmere_NOUN': {'sum_usage': 2549,
#   'median_usage': 36.5,
#   'mean_usage': 50.98,
#   'max_usage': 152,
#   'min_usage': 9,
#   'frequency': 4.5036417030128457e-08},
#  'asset_NOUN': {'sum_usage': 667743,
#   'median_usage': 11809.5,
#   'mean_usage': 13354.86,
#   'max_usage': 32328,
#   'min_usage': 5213,
#   'frequency': 1.1797862776362912e-05},
#  'beelzebub_NOUN': {'sum_usage': 33393,
#   'median_usage': 673.5,
#   'mean_usage': 667.86,
#   'max_usage': 1143,
#   'min_usage': 524,
#   'frequency': 5.899964981903019e-07},
#  'bmm_NOUN': {'sum_usage': 350,
#   'median_usage': 6.0,
#   'mean_usage': 7,
#   'max_usage': 24,
#   'min_usage': 2,
#   'frequency': 6.1838940606296426e-09},
#  'budworth_NOUN': {'sum_usage': 7240,
#   'median_usage': 109.0,
#   'mean_usage': 144.8,
#   'max_usage': 424,
#   'min_usage': 31,
#   'frequency': 1.2791826571131032e-07},
#  'aie_NOUN': {'sum_usage': 9618,
#   'median_usage': 186.0,
#   'mean_usage': 192.36,
#   'max_usage': 294,
#   'min_usage': 109,
#   'frequency': 1.6993340878610257e-07},
#  'bookseller_NOUN': {'sum_usage': 448017,
#   'median_usage': 8758.5,
#   'mean_usage': 8960.34,
#   'max_usage': 14131,
#   'min_usage': 6266,
#   'frequency': 7.915684758174603e-06},
#  'calf_NOUN': {'sum_usage': 983206,
#   'median_usage': 18453.0,
#   'mean_usage': 19664.12,
#   'max_usage': 37023,
#   'min_usage': 11935,
#   'frequency': 1.7371547839358368e-05},
#  'bindon_NOUN': {'sum_usage': 14127,
#   'median_usage': 231.5,
#   'mean_usage': 282.54,
#   'max_usage': 815,
#   'min_usage': 95,
#   'frequency': 2.4959963255575706e-07},
#  'arnoldo_NOUN': {'sum_usage': 2406,
#   'median_usage': 29.0,
#   'mean_usage': 48.12,
#   'max_usage': 365,
#   'min_usage': 3,
#   'frequency': 4.250985459964263e-08},
#  'aldous_NOUN': {'sum_usage': 7168,
#   'median_usage': 82.5,
#   'mean_usage': 143.36,
#   'max_usage': 1523,
#   'min_usage': 5,
#   'frequency': 1.2664615036169508e-07},
#  'bisse_NOUN': {'sum_usage': 5110,
#   'median_usage': 81.5,
#   'mean_usage': 102.2,
#   'max_usage': 611,
#   'min_usage': 13,
#   'frequency': 9.028485328519278e-08},
#  'argument_NOUN': {'sum_usage': 6121284,
#   'median_usage': 121474.5,
#   'mean_usage': 122425.68,
#   'max_usage': 151637,
#   'min_usage': 103405,
#   'frequency': 0.0001081524907743636},
#  'allhallow_NOUN': {'sum_usage': 1625,
#   'median_usage': 31.0,
#   'mean_usage': 32.5,
#   'max_usage': 73,
#   'min_usage': 11,
#   'frequency': 2.87109367100662e-08},
#  'bilt_NOUN': {'sum_usage': 658,
#   'median_usage': 10.0,
#   'mean_usage': 13.16,
#   'max_usage': 60,
#   'min_usage': 2,
#   'frequency': 1.1625720833983727e-08},
#  'antipholus_NOUN': {'sum_usage': 9436,
#   'median_usage': 138.0,
#   'mean_usage': 188.72,
#   'max_usage': 602,
#   'min_usage': 10,
#   'frequency': 1.6671778387457515e-07},
#  'allegretto_NOUN': {'sum_usage': 2476,
#   'median_usage': 46.5,
#   'mean_usage': 49.52,
#   'max_usage': 120,
#   'min_usage': 7,
#   'frequency': 4.374663341176856e-08},
#  'allis_NOUN': {'sum_usage': 1627,
#   'median_usage': 26.5,
#   'mean_usage': 32.54,
#   'max_usage': 146,
#   'min_usage': 13,
#   'frequency': 2.874627324755551e-08},
#  'almagro_NOUN': {'sum_usage': 17140,
#   'median_usage': 151.0,
#   'mean_usage': 342.8,
#   'max_usage': 2568,
#   'min_usage': 37,
#   'frequency': 3.0283412628340595e-07},
#  'alcuin_NOUN': {'sum_usage': 44399,
#   'median_usage': 718.0,
#   'mean_usage': 887.98,
#   'max_usage': 3340,
#   'min_usage': 356,
# ...
#  'aluminum_NOUN': {'sum_usage': 29461,
#   'median_usage': 533.5,
#   'mean_usage': 589.22,
#   'max_usage': 3168,
#   'min_usage': 173,
#   'frequency': 5.20524865486314e-07},
#  'blackhead_NOUN': {'sum_usage': 756,
#   'median_usage': 10.0,
#   'mean_usage': 15.12,
#   'max_usage': 113,
#   'min_usage': 2,
#   'frequency': 1.3357211170960028e-08},
#  'brandish_VERB': {'sum_usage': 80622,
#   'median_usage': 1594.0,
#   'mean_usage': 1612.44,
#   'max_usage': 2488,
#   'min_usage': 1265,
#   'frequency': 1.424451162731666e-06},
#  'bend_NOUN': {'sum_usage': 474811,
#   'median_usage': 9427.5,
#   'mean_usage': 9496.22,
#   'max_usage': 14008,
#   'min_usage': 5984,
#   'frequency': 8.389088350918917e-06},
#  'aristotle_NOUN': {'sum_usage': 843422,
#   'median_usage': 16190.0,
#   'mean_usage': 16868.44,
#   'max_usage': 37054,
#   'min_usage': 10802,
#   'frequency': 1.4901806561155355e-05},
#  'armstrong_NOUN': {'sum_usage': 467272,
#   'median_usage': 9076.0,
#   'mean_usage': 9345.44,
#   'max_usage': 17126,
#   'min_usage': 3485,
#   'frequency': 8.255887272852956e-06},
#  'asplenium_NOUN': {'sum_usage': 29206,
#   'median_usage': 552.5,
#   'mean_usage': 584.12,
#   'max_usage': 1077,
#   'min_usage': 246,
#   'frequency': 5.160194569564267e-07},
#  'battas_NOUN': {'sum_usage': 2618,
#   'median_usage': 42.0,
#   'mean_usage': 52.36,
#   'max_usage': 184,
#   'min_usage': 10,
#   'frequency': 4.625552757350973e-08},
#  'byers_NOUN': {'sum_usage': 10106,
#   'median_usage': 172.5,
#   'mean_usage': 202.12,
#   'max_usage': 901,
#   'min_usage': 69,
#   'frequency': 1.7855552393349478e-07},
#  'alternation_NOUN': {'sum_usage': 219180,
#   'median_usage': 4087.0,
#   'mean_usage': 4383.6,
#   'max_usage': 6682,
#   'min_usage': 3209,
#   'frequency': 3.872531143453729e-06},
#  'astronomer_NOUN': {'sum_usage': 390777,
#   'median_usage': 7517.5,
#   'mean_usage': 7815.54,
#   'max_usage': 13817,
#   'min_usage': 5424,
#   'frequency': 6.904353055230485e-06},
#  'arctic_NOUN': {'sum_usage': 103256,
#   'median_usage': 1986.5,
#   'mean_usage': 2065.12,
#   'max_usage': 3867,
#   'min_usage': 1307,
#   'frequency': 1.8243547574982124e-06},
#  'africa_NOUN': {'sum_usage': 3204712,
#   'median_usage': 50661.5,
#   'mean_usage': 64094.24,
#   'max_usage': 235342,
#   'min_usage': 35446,
#   'frequency': 5.662171286522441e-05},
#  'athenarum_NOUN': {'sum_usage': 4281,
#   'median_usage': 83.0,
#   'mean_usage': 85.62,
#   'max_usage': 156,
#   'min_usage': 42,
#   'frequency': 7.563785849587285e-08},
#  'alconbury_NOUN': {'sum_usage': 2067,
#   'median_usage': 29.5,
#   'mean_usage': 41.34,
#   'max_usage': 156,
#   'min_usage': 8,
#   'frequency': 3.65203114952042e-08},
#  'bef_NOUN': {'sum_usage': 1482,
#   'median_usage': 25.5,
#   'mean_usage': 29.64,
#   'max_usage': 109,
#   'min_usage': 11,
#   'frequency': 2.618437427958037e-08},
#  'bevs_NOUN': {'sum_usage': 715,
#   'median_usage': 11.0,
#   'mean_usage': 14.3,
#   'max_usage': 47,
#   'min_usage': 2,
#   'frequency': 1.2632812152429127e-08},
#  'broughton_NOUN': {'sum_usage': 180519,
#   'median_usage': 3404.5,
#   'mean_usage': 3610.38,
#   'max_usage': 5980,
#   'min_usage': 1962,
#   'frequency': 3.1894582055165783e-06},
#  'bramweu_NOUN': {'sum_usage': 786,
#   'median_usage': 13.0,
#   'mean_usage': 15.72,
#   'max_usage': 29,
#   'min_usage': 5,
#   'frequency': 1.3887259233299711e-08},
#  'blazon_NOUN': {'sum_usage': 23473,
#   'median_usage': 459.0,
#   'mean_usage': 469.46,
#   'max_usage': 758,
#   'min_usage': 244,
#   'frequency': 4.1472727224331314e-07},
#  'brooking_NOUN': {'sum_usage': 695,
#   'median_usage': 12.5,
#   'mean_usage': 13.9,
#   'max_usage': 35,
#   'min_usage': 2,
#   'frequency': 1.2279446777536005e-08},
#  'act_NOUN': {'sum_usage': 10766028,
#   'median_usage': 215649.0,
#   'mean_usage': 215320.56,
#   'max_usage': 288280,
#   'min_usage': 162945,
#   'frequency': 0.00019021707601649265},
#  'air_NOUN': {'sum_usage': 13583245,
#   'median_usage': 269403.5,
#   'mean_usage': 271664.9,
#   'max_usage': 336840,
#   'min_usage': 211226,
#   'frequency': 0.00023999242308450655},
#  'boling_NOUN': {'sum_usage': 17762,
#   'median_usage': 279.0,
#   'mean_usage': 355.24,
#   'max_usage': 1023,
#   'min_usage': 48,
#   'frequency': 3.1382378944258204e-07},
#  'bosanquet_NOUN': {'sum_usage': 55029,
#   'median_usage': 914.5,
#   'mean_usage': 1100.58,
#   'max_usage': 2506,
#   'min_usage': 367,
#   'frequency': 9.722671607496816e-07},
#  'bauman_NOUN': {'sum_usage': 2321,
#   'median_usage': 30.5,
#   'mean_usage': 46.42,
#   'max_usage': 288,
#   'min_usage': 5,
#   'frequency': 4.100805175634686e-08},
#  'bhoot_NOUN': {'sum_usage': 1083,
#   'median_usage': 12.5,
#   'mean_usage': 21.66,
#   'max_usage': 318,
#   'min_usage': 3,
#   'frequency': 1.913473505046258e-08},
#  'antiochus_NOUN': {'sum_usage': 164440,
#   'median_usage': 2980.0,
#   'mean_usage': 3288.8,
#   'max_usage': 7752,
#   'min_usage': 1464,
#   'frequency': 2.9053701123712526e-06},
#  'beuben_NOUN': {'sum_usage': 898,
#   'median_usage': 16.0,
#   'mean_usage': 17.96,
#   'max_usage': 106,
#   'min_usage': 5,
#   'frequency': 1.5866105332701196e-08},
#  'atto_NOUN': {'sum_usage': 2074,
#   'median_usage': 33.0,
#   'mean_usage': 41.48,
#   'max_usage': 231,
#   'min_usage': 17,
#   'frequency': 3.6643989376416797e-08},
#  'bazley_NOUN': {'sum_usage': 19406,
#   'median_usage': 277.5,
#   'mean_usage': 388.12,
#   'max_usage': 1334,
#   'min_usage': 38,
#   'frequency': 3.428704232587967e-07},
#  'angelina_NOUN': {'sum_usage': 29337,
#   'median_usage': 512.5,
#   'mean_usage': 586.74,
#   'max_usage': 2519,
#   'min_usage': 241,
#   'frequency': 5.183340001619767e-07},
#  'arius_NOUN': {'sum_usage': 1401,
#   'median_usage': 27.0,
#   'mean_usage': 28.02,
#   'max_usage': 61,
#   'min_usage': 9,
#   'frequency': 2.4753244511263226e-08},
#  'anglicanae_NOUN': {'sum_usage': 6580,
#   'median_usage': 126.5,
#   'mean_usage': 131.6,
#   'max_usage': 302,
#   'min_usage': 42,
#   'frequency': 1.1625720833983727e-07},
#  'bingo_NOUN': {'sum_usage': 10428,
#   'median_usage': 99.0,
#   'mean_usage': 208.56,
#   'max_usage': 1026,
#   'min_usage': 4,
#   'frequency': 1.8424470646927403e-07},
#  'antiphonary_NOUN': {'sum_usage': 1099,
#   'median_usage': 14.0,
#   'mean_usage': 21.98,
#   'max_usage': 125,
#   'min_usage': 2,
#   'frequency': 1.941742735037708e-08},
#  'boatman_NOUN': {'sum_usage': 193383,
#   'median_usage': 3833.0,
#   'mean_usage': 3867.66,
#   'max_usage': 5208,
#   'min_usage': 2935,
#   'frequency': 3.416742814647835e-06},
#  'bayliss_NOUN': {'sum_usage': 23003,
#   'median_usage': 244.0,
#   'mean_usage': 460.06,
#   'max_usage': 2553,
#   'min_usage': 18,
#   'frequency': 4.0642318593332477e-07},
#  'aegae_NOUN': {'sum_usage': 2362,
#   'median_usage': 34.0,
#   'mean_usage': 47.24,
#   'max_usage': 259,
#   'min_usage': 6,
#   'frequency': 4.173245077487776e-08},
#  'berthold_NOUN': {'sum_usage': 29539,
#   'median_usage': 562.0,
#   'mean_usage': 590.78,
#   'max_usage': 1397,
#   'min_usage': 182,
#   'frequency': 5.219029904483972e-07},
#  'aurelius_NOUN': {'sum_usage': 139436,
#   'median_usage': 2806.5,
#   'mean_usage': 2788.72,
#   'max_usage': 4543,
#   'min_usage': 1435,
#   'frequency': 2.463592720679871e-06},
#  'alcove_NOUN': {'sum_usage': 38442,
#   'median_usage': 745.5,
#   'mean_usage': 768.84,
#   'max_usage': 1201,
#   'min_usage': 480,
#   'frequency': 6.792035870820706e-07},
#  'bussian_NOUN': {'sum_usage': 16478,
#   'median_usage': 303.0,
#   'mean_usage': 329.56,
#   'max_usage': 752,
#   'min_usage': 49,
#   'frequency': 2.911377323744436e-07},
#  'allan_NOUN': {'sum_usage': 1190,
#   'median_usage': 22.0,
#   'mean_usage': 23.8,
#   'max_usage': 59,
#   'min_usage': 4,
#   'frequency': 2.1025239806140785e-08},
#  'aliud_NOUN': {'sum_usage': 5551,
#   'median_usage': 101.0,
#   'mean_usage': 111.02,
#   'max_usage': 238,
#   'min_usage': 70,
#   'frequency': 9.807655980158614e-08},
#  'blackbeard_NOUN': {'sum_usage': 2460,
#   'median_usage': 37.5,
#   'mean_usage': 49.2,
#   'max_usage': 236,
#   'min_usage': 5,
#   'frequency': 4.346394111185406e-08},
#  'boswell_NOUN': {'sum_usage': 351066,
#   'median_usage': 6078.0,
#   'mean_usage': 7021.32,
#   'max_usage': 25548,
#   'min_usage': 3227,
#   'frequency': 6.202728435111446e-06},
#  'bertha_NOUN': {'sum_usage': 147813,
#   'median_usage': 2782.0,
#   'mean_usage': 2956.26,
#   'max_usage': 5225,
#   'min_usage': 1540,
#   'frequency': 2.611599807953855e-06},
#  'behold_ADP': {'sum_usage': 17752,
#   'median_usage': 341.5,
#   'mean_usage': 355.04,
#   'max_usage': 561,
#   'min_usage': 211,
#   'frequency': 3.136471067551355e-07},
#  'angostura_NOUN': {'sum_usage': 8437,
#   'median_usage': 119.0,
#   'mean_usage': 168.74,
#   'max_usage': 753,
#   'min_usage': 16,
#   'frequency': 1.490671833986637e-07},
#  'busch_NOUN': {'sum_usage': 20277,
#   'median_usage': 318.0,
#   'mean_usage': 405.54,
#   'max_usage': 1845,
#   'min_usage': 99,
#   'frequency': 3.582594853353922e-07},
#  'alraschid_NOUN': {'sum_usage': 8148,
#   'median_usage': 135.0,
#   'mean_usage': 162.96,
#   'max_usage': 1027,
#   'min_usage': 74,
#   'frequency': 1.439610537314581e-07},
#  'bibliophile_NOUN': {'sum_usage': 13257,
#   'median_usage': 141.5,
#   'mean_usage': 265.14,
#   'max_usage': 938,
#   'min_usage': 13,
#   'frequency': 2.342282387479062e-07},
#  'aob_NOUN': {'sum_usage': 5251,
#   'median_usage': 98.0,
#   'mean_usage': 105.02,
#   'max_usage': 290,
#   'min_usage': 26,
#   'frequency': 9.27760791781893e-08},
#  'almshouses_NOUN': {'sum_usage': 64994,
#   'median_usage': 1055.5,
#   'mean_usage': 1299.88,
#   'max_usage': 7452,
#   'min_usage': 612,
#   'frequency': 1.14833145879018e-06},
#  'adult_NOUN': {'sum_usage': 974328,
#   'median_usage': 18897.5,
#   'mean_usage': 19486.56,
#   'max_usage': 33267,
#   'min_usage': 12484,
#   'frequency': 1.721468894944331e-05},
#  'aughrim_NOUN': {'sum_usage': 6374,
#   'median_usage': 109.0,
#   'mean_usage': 127.48,
#   'max_usage': 284,
#   'min_usage': 32,
#   'frequency': 1.1261754497843811e-07},
#  'barbarossa_NOUN': {'sum_usage': 51578,
#   'median_usage': 949.0,
#   'mean_usage': 1031.56,
#   'max_usage': 1546,
#   'min_usage': 743,
#   'frequency': 9.112939653118735e-07},
#  'annelides_NOUN': {'sum_usage': 8219,
#   'median_usage': 146.5,
#   'mean_usage': 164.38,
#   'max_usage': 495,
#   'min_usage': 10,
#   'frequency': 1.4521550081232866e-07},
#  'black_ADJ': {'sum_usage': 8043762,
#   'median_usage': 153156.0,
#   'mean_usage': 160875.24,
#   'max_usage': 228880,
#   'min_usage': 123122,
#   'frequency': 0.0001421193487340526},
#  'anty_NOUN': {'sum_usage': 611,
#   'median_usage': 9.0,
#   'mean_usage': 12.22,
#   'max_usage': 74,
#   'min_usage': 4,
#   'frequency': 1.079531220298489e-08},
#  'adapt_VERB': {'sum_usage': 2590568,
#   'median_usage': 51391.5,
#   'mean_usage': 51811.36,
#   'max_usage': 61126,
#   'min_usage': 41155,
#   'frequency': 4.577085162530632e-05},
#  'burfield_NOUN': {'sum_usage': 2356,
#   'median_usage': 41.0,
#   'mean_usage': 47.12,
#   'max_usage': 170,
#   'min_usage': 7,
#   'frequency': 4.162644116240982e-08},
#  'barebones_NOUN': {'sum_usage': 7703,
#   'median_usage': 132.0,
#   'mean_usage': 154.06,
#   'max_usage': 710,
#   'min_usage': 57,
#   'frequency': 1.360986741400861e-07},
#  'bereans_NOUN': {'sum_usage': 3249,
#   'median_usage': 58.5,
#   'mean_usage': 64.98,
#   'max_usage': 188,
#   'min_usage': 14,
#   'frequency': 5.740420515138774e-08},
#  'bruising_NOUN': {'sum_usage': 3952,
#   'median_usage': 75.5,
#   'mean_usage': 79.04,
#   'max_usage': 213,
#   'min_usage': 27,
#   'frequency': 6.9824998078881e-08},
#  'anonymus_NOUN': {'sum_usage': 4215,
#   'median_usage': 57.0,
#   'mean_usage': 84.3,
#   'max_usage': 381,
#   'min_usage': 13,
#   'frequency': 7.447175275872555e-08},
#  'abiathar_NOUN': {'sum_usage': 14402,
#   'median_usage': 252.0,
#   'mean_usage': 288.04,
#   'max_usage': 582,
#   'min_usage': 98,
#   'frequency': 2.544584064605375e-07},
#  'brandenburg_NOUN': {'sum_usage': 117003,
#   'median_usage': 2171.0,
#   'mean_usage': 2340.06,
#   'max_usage': 4797,
#   'min_usage': 1322,
#   'frequency': 2.0672404479310003e-06},
#  'baggage_NOUN': {'sum_usage': 403082,
#   'median_usage': 7865.5,
#   'mean_usage': 8061.64,
#   'max_usage': 12807,
#   'min_usage': 5711,
#   'frequency': 7.121761102133479e-06},
#  'celtic_NOUN': {'sum_usage': 570344,
#   'median_usage': 12001.0,
#   'mean_usage': 11406.88,
#   'max_usage': 17562,
#   'min_usage': 5646,
#   'frequency': 1.0076991068902152e-05},
#  'abbey_NOUN': {'sum_usage': 574727,
#   'median_usage': 11345.0,
#   'mean_usage': 11494.54,
#   'max_usage': 16137,
#   'min_usage': 7947,
#   'frequency': 1.0154431090809979e-05},
#  'arith_NOUN': {'sum_usage': 1335,
#   'median_usage': 22.0,
#   'mean_usage': 26.7,
#   'max_usage': 78,
#   'min_usage': 8,
#   'frequency': 2.3587138774115923e-08},
#  'array_NOUN': {'sum_usage': 492459,
#   'median_usage': 9913.0,
#   'mean_usage': 9849.18,
#   'max_usage': 13230,
#   'min_usage': 8032,
#   'frequency': 8.700897957724609e-06},
#  'bibroci_NOUN': {'sum_usage': 1043,
#   'median_usage': 17.0,
#   'mean_usage': 20.86,
#   'max_usage': 66,
#   'min_usage': 2,
#   'frequency': 1.8428004300676334e-08},
#  'beam_VERB': {'sum_usage': 220633,
#   'median_usage': 4428.0,
#   'mean_usage': 4412.66,
#   'max_usage': 5956,
#   'min_usage': 3471,
#   'frequency': 3.8982031379397145e-06},
#  'ayres_NOUN': {'sum_usage': 1754,
#   'median_usage': 27.5,
#   'mean_usage': 35.08,
#   'max_usage': 132,
#   'min_usage': 3,
#   'frequency': 3.099014337812684e-08},
#  'ache_VERB': {'sum_usage': 268927,
#   'median_usage': 5389.0,
#   'mean_usage': 5378.54,
#   'max_usage': 7604,
#   'min_usage': 3685,
#   'frequency': 4.751474508694137e-06},
#  'cami_NOUN': {'sum_usage': 5415,
#   'median_usage': 98.5,
#   'mean_usage': 108.3,
#   'max_usage': 234,
#   'min_usage': 52,
#   'frequency': 9.56736752523129e-08},
#  'annibale_NOUN': {'sum_usage': 15849,
#   'median_usage': 288.5,
#   'mean_usage': 316.98,
#   'max_usage': 777,
#   'min_usage': 83,
#   'frequency': 2.800243913340549e-07},
#  'braganza_NOUN': {'sum_usage': 27835,
#   'median_usage': 546.0,
#   'mean_usage': 556.7,
#   'max_usage': 1185,
#   'min_usage': 349,
#   'frequency': 4.917962605075032e-07},
#  'bidding_ADJ': {'sum_usage': 7970,
#   'median_usage': 153.5,
#   'mean_usage': 159.4,
#   'max_usage': 283,
#   'min_usage': 106,
#   'frequency': 1.408161018949093e-07},
#  'burthen_NOUN': {'sum_usage': 233507,
#   'median_usage': 4424.0,
#   'mean_usage': 4670.14,
#   'max_usage': 9222,
#   'min_usage': 2867,
#   'frequency': 4.125664429758417e-06},
#  'behead_VERB': {'sum_usage': 219771,
#   'median_usage': 4226.5,
#   'mean_usage': 4395.42,
#   'max_usage': 6847,
#   'min_usage': 3203,
#   'frequency': 3.882973090281821e-06},
#  'bolland_NOUN': {'sum_usage': 19737,
#   'median_usage': 370.0,
#   'mean_usage': 394.74,
#   'max_usage': 1014,
#   'min_usage': 141,
#   'frequency': 3.4871862021327785e-07},
#  'appleton_NOUN': {'sum_usage': 69353,
#   'median_usage': 1404.0,
#   'mean_usage': 1387.06,
#   'max_usage': 2592,
#   'min_usage': 463,
#   'frequency': 1.225347442248136e-06},
#  'antediluvian_NOUN': {'sum_usage': 6425,
#   'median_usage': 118.5,
#   'mean_usage': 128.5,
#   'max_usage': 289,
#   'min_usage': 40,
#   'frequency': 1.1351862668441558e-07},
#  'atherton_NOUN': {'sum_usage': 73148,
#   'median_usage': 1267.5,
#   'mean_usage': 1462.96,
#   'max_usage': 4088,
#   'min_usage': 602,
#   'frequency': 1.292398522134106e-06},
#  'beechey_NOUN': {'sum_usage': 39779,
#   'median_usage': 570.0,
#   'mean_usage': 795.58,
#   'max_usage': 2586,
#   'min_usage': 293,
#   'frequency': 7.028260623936759e-07},
#  'arabicus_NOUN': {'sum_usage': 1018,
#   'median_usage': 17.0,
#   'mean_usage': 20.36,
#   'max_usage': 71,
#   'min_usage': 2,
#   'frequency': 1.7986297582059933e-08},
#  'bampton_NOUN': {'sum_usage': 81064,
#   'median_usage': 1589.0,
#   'mean_usage': 1621.28,
#   'max_usage': 2765,
#   'min_usage': 577,
#   'frequency': 1.432260537516804e-06},
#  'cam_NOUN': {'sum_usage': 288110,
#   'median_usage': 4996.5,
#   'mean_usage': 5762.2,
#   'max_usage': 11461,
#   'min_usage': 2451,
#   'frequency': 5.090404908022875e-06},
#  'baffaelle_NOUN': {'sum_usage': 852,
#   'median_usage': 15.0,
#   'mean_usage': 17.04,
#   'max_usage': 52,
#   'min_usage': 2,
#   'frequency': 1.5053364970447017e-08},
#  'avere_VERB': {'sum_usage': 819,
#   'median_usage': 15.0,
#   'mean_usage': 16.38,
#   'max_usage': 29,
#   'min_usage': 4,
#   'frequency': 1.4470312101873364e-08},
#  'antiburgher_NOUN': {'sum_usage': 1887,
#   'median_usage': 25.0,
#   'mean_usage': 37.74,
#   'max_usage': 441,
#   'min_usage': 4,
#   'frequency': 3.33400231211661e-08},
#  'annoyed_ADJ': {'sum_usage': 34101,
#   'median_usage': 663.5,
#   'mean_usage': 682.02,
#   'max_usage': 964,
#   'min_usage': 490,
#   'frequency': 6.025056324615184e-07},
#  ...}

# %%
top_max_usage = top_counts(ngrams,'max_usage')
