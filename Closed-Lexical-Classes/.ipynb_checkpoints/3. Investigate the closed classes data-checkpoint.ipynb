# %% [markdown]
# # Goal:
# The number of lexemes output by the Closed Classes Analysis notebook was far too great to manually investigate efficiently. Thus, we will make a few hypotheses which may assist in programmatically reducing the qualitative search space.
# 1. There is a higher likelihood of finding true instances of birth/death in the highest frequency words
# 2. We will be able to group instances of birth and death by their relative numbers of years (number of birth years - number of death years = 1 for a birthed word, 0 for a dead word.
# 3. Words that have only one birth or death year are more likely to be true instances than those with >1 of each.
#
# \*Note: These hypotheses do not affect our linguistic framework nor allow us to conclude that the other data does not have bona fide instances of birth and death i.e. not due to OCR mistakes, spelling diversity (when the spelling refers to the same spoken word), etc. They simply limit how much data we have to look at.

# %%
import json
from collections import OrderedDict
data_directory = '../Ngrams/unigram_data/'

# %%
def open_json(directory,file_path):
    with open(directory+file_path,'r') as f:
        ngrams = json.load(f)
        f.close()
    return ngrams

# %%
def save_json(dictionary,directory,file_path):
    output = file_path+'.json'
    if len(dictionary)>0:
        with open(directory+output, 'w') as f_out:
            json.dump(dictionary, f_out)
        print('SAVED: ',output,len(dictionary))
    else:
        print('unigram dict empty',output,dictionary)

# %%
#This allows for easy filtering of the part of speech (POS) in Excel
def save_csv(dictionary,directory,title):
    output = title+'.csv'
    with open(output,'w') as f:
        f.write('lexeme,part_of_speech,max_usage,median_all,median_in_use,mean_all,mean_in_use\n')
        for lexeme, entries in dictionary.items():
            f.write(lexeme+','
                    +entries['POS']+','
                    +str(int(entries['max_usage']))+','
                    +str(int(entries['median_all']))+','
                    +str(int(entries['median_in_use']))+','
                    +str(int(entries['mean_all']))+','
                    +str(int(entries['mean_in_use']))+'\n')
        f.close()
        print('SAVED: ',output,len(dictionary))

# %%
ngrams = open_json(data_directory,'CLOSED_CLASSES_SORTABLE.json')

# %%
print('Number of lexemes in closed lexical classes with birth and death: ',len(ngrams.keys()))
# Out:
# Number of lexemes in closed lexical classes with birth and death:  440403

# %% [markdown]
# ### Hypothesis #1: There is a higher likelihood of finding true instances of birth/death in highest frequency words
# Will get top counts for all metrics, then combine them into a non-overlapping dictionary. Then will save as .json and .csv files

# %%
def top_counts(dictionary,count_type,num_hits=500,head = True):
    return OrderedDict(sorted(dictionary.items(), key=lambda x: x[1][count_type], reverse=head)[:num_hits])

# %%
top_max_usage = top_counts(ngrams,'max_usage')

# %%
top_median_all = top_counts(ngrams,'median_all')

# %%
top_median_in_use = top_counts(ngrams,'median_in_use')

# %%
top_mean_all = top_counts(ngrams,'mean_all')

# %%
top_mean_in_use = top_counts(ngrams,'mean_in_use')

# %%
top_all = {**top_max_usage,**top_median_all,**top_median_in_use,**top_mean_all,**top_mean_in_use}

# %%
len(top_all)
# Out:
# 1185

# %%
list((k,v) for k,v in top_all.items())[:50]
# Out:
# [('bbe',
#   {'POS': 'ADP',
#    'max_usage': 133568.4,
#    'median_all': 4.8,
#    'median_in_use': 5.6,
#    'mean_all': 1470.3064814814813,
#    'mean_in_use': 1595.910552763819,
#    'birth_years': [1814, 1820, 1846],
#    'death_years': [1818, 1841]}),
#  ('nhe',
#   {'POS': 'ADP',
#    'max_usage': 75803.4,
#    'median_all': 4.4,
#    'median_in_use': 5.300000000000001,
#    'mean_all': 971.6851851851851,
#    'mean_in_use': 1093.1458333333333,
#    'birth_years': [1803, 1814, 1833, 1840, 1851],
#    'death_years': [1807, 1818, 1837, 1849]}),
#  ('proton',
#   {'POS': 'ADP',
#    'max_usage': 32690.0,
#    'median_all': 25.3,
#    'median_in_use': 54.2,
#    'mean_all': 6065.498148148148,
#    'mean_in_use': 7006.136898395722,
#    'birth_years': [1823, 1833, 1844],
#    'death_years': [1828, 1839]}),
#  ('transgender',
#   {'POS': 'DET',
#    'max_usage': 22530.8,
#    'median_all': 0.0,
#    'median_in_use': 31.200000000000003,
#    'mean_all': 796.3740740740741,
#    'mean_in_use': 2774.4645161290323,
#    'birth_years': [1947, 1958, 1971],
#    'death_years': [1951, 1967]}),
#  ('thruout',
#   {'POS': 'ADP',
#    'max_usage': 21064.8,
#    'median_all': 164.60000000000002,
#    'median_in_use': 320.9,
#    'mean_all': 1899.4074074074074,
#    'mean_in_use': 2182.2978723404253,
#    'birth_years': [1823, 1836, 1863],
#    'death_years': [1834, 1856]}),
#  ('bypass',
#   {'POS': 'ADP',
#    'max_usage': 21029.6,
#    'median_all': 42.900000000000006,
#    'median_in_use': 186.1,
#    'mean_all': 2935.186111111111,
#    'mean_in_use': 4012.659493670886,
#    'birth_years': [1830, 1863, 1883],
#    'death_years': [1834, 1880]}),
#  ('thethethethe',
#   {'POS': 'DET',
#    'max_usage': 18730.8,
#    'median_all': 0.0,
#    'median_in_use': 3.4,
#    'mean_all': 425.5925925925926,
#    'mean_in_use': 2484.5405405405404,
#    'birth_years': [1981],
#    'death_years': []}),
#  ('kjb',
#   {'POS': 'ADP',
#    'max_usage': 18063.6,
#    'median_all': 0.0,
#    'median_in_use': 1.0,
#    'mean_all': 195.2046296296296,
#    'mean_in_use': 2219.1684210526314,
#    'birth_years': [1975, 2004],
#    'death_years': [1979]}),
#  ('gonna',
#   {'POS': 'PRT',
#    'max_usage': 17807.0,
#    'median_all': 1.8,
#    'median_in_use': 248.2,
#    'mean_all': 1330.2324074074074,
#    'mean_in_use': 2435.001694915254,
#    'birth_years': [1830, 1886, 1910],
#    'death_years': [1834, 1890]}),
#  ('tomato',
#   {'POS': 'PRT',
#    'max_usage': 17370.8,
#    'median_all': 986.8000000000001,
#    'median_in_use': 1413.6,
#    'mean_all': 2848.7574074074073,
#    'mean_in_use': 2944.1703349282297,
#    'birth_years': [1803, 1810, 1817, 1827],
#    'death_years': [1807, 1814, 1824]}),
#  ('knockout',
#   {'POS': 'ADP',
#    'max_usage': 13710.0,
#    'median_all': 65.7,
#    'median_in_use': 105.8,
#    'mean_all': 1223.1453703703703,
#    'mean_in_use': 1620.8552147239263,
#    'birth_years': [1830, 1841, 1864, 1881],
#    'death_years': [1834, 1845, 1879]}),
#  ('ligand',
#   {'POS': 'CONJ',
#    'max_usage': 13554.6,
#    'median_all': 5.300000000000001,
#    'median_in_use': 7.2,
#    'mean_all': 1635.125,
#    'mean_in_use': 1940.5879120879122,
#    'birth_years': [1807, 1824, 1843, 1849, 1865, 1927],
#    'death_years': [1811, 1828, 1847, 1863, 1925]}),
#  ('sesame',
#   {'POS': 'DET',
#    'max_usage': 13423.2,
#    'median_all': 494.8,
#    'median_in_use': 584.5,
#    'mean_all': 1735.0435185185186,
#    'mean_in_use': 1837.1049019607842,
#    'birth_years': [1810, 1822, 1828],
#    'death_years': [1818, 1826]}),
#  ('alfalfa',
#   {'POS': 'DET',
#    'max_usage': 13002.2,
#    'median_all': 2880.7,
#    'median_in_use': 4390.4,
#    'mean_all': 3654.6546296296297,
#    'mean_in_use': 4133.012565445026,
#    'birth_years': [1814, 1825, 1839, 1850],
#    'death_years': [1818, 1837, 1843]}),
#  ('ofofofof',
#   {'POS': 'ADP',
#    'max_usage': 12266.2,
#    'median_all': 0.0,
#    'median_in_use': 2.0,
#    'mean_all': 280.67685185185184,
#    'mean_in_use': 1347.2488888888888,
#    'birth_years': [1954, 1960, 1979, 1988],
#    'death_years': [1958, 1964, 1983]}),
#  ('ylt',
#   {'POS': 'PRON',
#    'max_usage': 11158.2,
#    'median_all': 0.9,
#    'median_in_use': 2.3,
#    'mean_all': 117.1574074074074,
#    'mean_in_use': 191.71212121212122,
#    'birth_years': [1878, 1891, 1908, 1920, 1944],
#    'death_years': [1889, 1905, 1915, 1942]}),
#  ('sunflower',
#   {'POS': 'DET',
#    'max_usage': 11114.6,
#    'median_all': 916.8,
#    'median_in_use': 1103.4,
#    'mean_all': 2508.0814814814817,
#    'mean_in_use': 2579.7409523809524,
#    'birth_years': [1805, 1817, 1828],
#    'death_years': [1815, 1825]}),
#  ('website',
#   {'POS': 'PRON',
#    'max_usage': 10875.8,
#    'median_all': 0.0,
#    'median_in_use': 8.5,
#    'mean_all': 709.275,
#    'mean_in_use': 1740.9477272727272,
#    'birth_years': [1898, 1922, 1934, 1947, 1957],
#    'death_years': [1902, 1926, 1943, 1953]}),
#  ('phonon',
#   {'POS': 'ADP',
#    'max_usage': 9353.0,
#    'median_all': 1.5,
#    'median_in_use': 85.8,
#    'mean_all': 1712.512037037037,
#    'mean_in_use': 2845.404615384615,
#    'birth_years': [1824, 1851, 1867, 1875, 1904, 1916],
#    'death_years': [1828, 1855, 1871, 1879, 1911]}),
#  ('thuringiensis',
#   {'POS': 'ADP',
#    'max_usage': 9323.8,
#    'median_all': 2.8,
#    'median_in_use': 181.2,
#    'mean_all': 1313.0648148148148,
#    'mean_in_use': 2181.7076923076925,
#    'birth_years': [1829, 1867, 1892, 1898, 1904, 1913],
#    'death_years': [1833, 1871, 1896, 1902, 1908]}),
#  ('afp',
#   {'POS': 'ADP',
#    'max_usage': 9319.0,
#    'median_all': 0.0,
#    'median_in_use': 2.8,
#    'mean_all': 640.5175925925926,
#    'mean_in_use': 1471.827659574468,
#    'birth_years': [1899, 1908, 1924, 1949],
#    'death_years': [1906, 1914, 1933]}),
#  ('outta',
#   {'POS': 'ADP',
#    'max_usage': 9289.0,
#    'median_all': 10.4,
#    'median_in_use': 25.4,
#    'mean_all': 676.9694444444444,
#    'mean_in_use': 781.9540106951872,
#    'birth_years': [1814, 1831, 1842, 1848, 1855],
#    'death_years': [1818, 1839, 1846, 1852]}),
#  ('annja',
#   {'POS': 'DET',
#    'max_usage': 8853.0,
#    'median_all': 0.0,
#    'median_in_use': 833.8000000000001,
#    'mean_all': 255.88425925925927,
#    'mean_in_use': 2302.9583333333335,
#    'birth_years': [1994],
#    'death_years': []}),
#  ('andandandand',
#   {'POS': 'CONJ',
#    'max_usage': 8795.8,
#    'median_all': 0.0,
#    'median_in_use': 1.9,
#    'mean_all': 199.5185185185185,
#    'mean_in_use': 979.4545454545454,
#    'birth_years': [1973, 1979],
#    'death_years': [1977]}),
#  ('anand',
#   {'POS': 'CONJ',
#    'max_usage': 8461.8,
#    'median_all': 73.80000000000001,
#    'median_in_use': 76.5,
#    'mean_all': 1434.974074074074,
#    'mean_in_use': 1448.385046728972,
#    'birth_years': [1809],
#    'death_years': [1806]}),
#  ('tendon',
#   {'POS': 'ADP',
#    'max_usage': 8344.4,
#    'median_all': 121.8,
#    'median_in_use': 131.5,
#    'mean_all': 890.4092592592592,
#    'mean_in_use': 915.8495238095238,
#    'birth_years': [1816, 1824],
#    'death_years': [1812, 1820]}),
#  ('isbn',
#   {'POS': 'ADP',
#    'max_usage': 8320.6,
#    'median_all': 0.4,
#    'median_in_use': 33.0,
#    'mean_all': 822.3935185185185,
#    'mean_in_use': 1572.0088495575221,
#    'birth_years': [1836, 1850, 1888, 1904, 1910, 1922, 1933, 1945],
#    'death_years': [1840, 1854, 1892, 1908, 1914, 1931, 1937]}),
#  ('andand',
#   {'POS': 'CONJ',
#    'max_usage': 8266.8,
#    'median_all': 12.6,
#    'median_in_use': 13.0,
#    'mean_all': 317.7916666666667,
#    'mean_in_use': 326.87142857142857,
#    'birth_years': [1808],
#    'death_years': []}),
#  ('meself',
#   {'POS': 'PRON',
#    'max_usage': 8122.0,
#    'median_all': 585.8,
#    'median_in_use': 590.0,
#    'mean_all': 910.325,
#    'mean_in_use': 923.1464788732394,
#    'birth_years': [1805],
#    'death_years': []}),
#  ('pyr',
#   {'POS': 'ADP',
#    'max_usage': 7774.2,
#    'median_all': 9.8,
#    'median_in_use': 9.8,
#    'mean_all': 124.72592592592592,
#    'mean_in_use': 127.68151658767772,
#    'birth_years': [1807],
#    'death_years': []}),
#  ('ref',
#   {'POS': 'PRT',
#    'max_usage': 7624.6,
#    'median_all': 89.9,
#    'median_in_use': 647.0,
#    'mean_all': 1509.499074074074,
#    'mean_in_use': 1762.442162162162,
#    'birth_years': [1824, 1833, 1843],
#    'death_years': [1828, 1837]}),
#  ('yerself',
#   {'POS': 'PRON',
#    'max_usage': 7420.4,
#    'median_all': 336.79999999999995,
#    'median_in_use': 351.79999999999995,
#    'mean_all': 749.3518518518518,
#    'mean_in_use': 785.7281553398059,
#    'birth_years': [1814],
#    'death_years': [1803]}),
#  ('thethethethethe',
#   {'POS': 'DET',
#    'max_usage': 7263.4,
#    'median_all': 0.0,
#    'median_in_use': 62.2,
#    'mean_all': 171.68703703703704,
#    'mean_in_use': 1612.3652173913044,
#    'birth_years': [1995],
#    'death_years': []}),
#  ('allograft',
#   {'POS': 'DET',
#    'max_usage': 7140.6,
#    'median_all': 0.0,
#    'median_in_use': 217.2,
#    'mean_all': 852.1333333333333,
#    'mean_in_use': 1752.96,
#    'birth_years': [1867, 1875, 1901, 1912, 1931, 1945],
#    'death_years': [1871, 1881, 1905, 1917, 1939]}),
#  ('thaliana',
#   {'POS': 'DET',
#    'max_usage': 6309.4,
#    'median_all': 3.7,
#    'median_in_use': 8.7,
#    'mean_all': 652.687962962963,
#    'mean_in_use': 903.7217948717948,
#    'birth_years': [1803, 1832, 1858, 1867, 1874, 1881, 1898],
#    'death_years': [1807, 1836, 1862, 1871, 1878, 1891]}),
#  ('actinomycin',
#   {'POS': 'ADP',
#    'max_usage': 6300.0,
#    'median_all': 3.6,
#    'median_in_use': 151.8,
#    'mean_all': 819.6296296296297,
#    'mean_in_use': 1394.015748031496,
#    'birth_years': [1867, 1875, 1901, 1912, 1921],
#    'death_years': [1871, 1885, 1908, 1917]}),
#  ('thymus',
#   {'POS': 'ADP',
#    'max_usage': 5859.8,
#    'median_all': 108.1,
#    'median_in_use': 131.6,
#    'mean_all': 798.9472222222222,
#    'mean_in_use': 903.5214659685864,
#    'birth_years': [1804, 1832],
#    'death_years': [1808]}),
#  ('outbound',
#   {'POS': 'ADP',
#    'max_usage': 5808.8,
#    'median_all': 342.2,
#    'median_in_use': 979.4000000000001,
#    'mean_all': 1014.312962962963,
#    'mean_in_use': 1386.6556962025315,
#    'birth_years': [1830, 1845, 1857, 1878],
#    'death_years': [1834, 1852, 1861]}),
#  ('inhalation',
#   {'POS': 'ADP',
#    'max_usage': 5603.0,
#    'median_all': 132.8,
#    'median_in_use': 183.4,
#    'mean_all': 1122.9231481481481,
#    'mean_in_use': 1243.8533333333332,
#    'birth_years': [1805, 1828],
#    'death_years': [1809]}),
#  ('php',
#   {'POS': 'ADP',
#    'max_usage': 5458.6,
#    'median_all': 0.4,
#    'median_in_use': 4.0,
#    'mean_all': 264.1212962962963,
#    'mean_in_use': 442.2496124031008,
#    'birth_years': [1825, 1853, 1897, 1919, 1928, 1935],
#    'death_years': [1830, 1861, 1917, 1923, 1932]}),
#  ('inininin',
#   {'POS': 'ADP',
#    'max_usage': 5451.8,
#    'median_all': 0.0,
#    'median_in_use': 3.2,
#    'mean_all': 124.13148148148149,
#    'mean_in_use': 766.0685714285714,
#    'birth_years': [1982, 1994],
#    'death_years': [1992]}),
#  ('aerosol',
#   {'POS': 'DET',
#    'max_usage': 5382.4,
#    'median_all': 2.9,
#    'median_in_use': 182.3,
#    'mean_all': 1026.3944444444444,
#    'mean_in_use': 1518.5013698630137,
#    'birth_years': [1830, 1867, 1875, 1881, 1901, 1916],
#    'death_years': [1834, 1871, 1879, 1897, 1912]}),
#  ('lsbn',
#   {'POS': 'ADP',
#    'max_usage': 5166.4,
#    'median_all': 0.0,
#    'median_in_use': 1374.4,
#    'mean_all': 476.11574074074076,
#    'mean_in_use': 1685.9180327868853,
#    'birth_years': [1957],
#    'death_years': []}),
#  ('wurde',
#   {'POS': 'ADP',
#    'max_usage': 5163.6,
#    'median_all': 141.0,
#    'median_in_use': 142.9,
#    'mean_all': 422.06666666666666,
#    'mean_in_use': 426.011214953271,
#    'birth_years': [1813],
#    'death_years': [1810]}),
#  ('offeror',
#   {'POS': 'ADP',
#    'max_usage': 5142.8,
#    'median_all': 9.3,
#    'median_in_use': 32.4,
#    'mean_all': 735.6268518518518,
#    'mean_in_use': 877.8751381215469,
#    'birth_years': [1823, 1849],
#    'death_years': [1834]}),
#  ('mainland',
#   {'POS': 'CONJ',
#    'max_usage': 4839.0,
#    'median_all': 62.900000000000006,
#    'median_in_use': 76.0,
#    'mean_all': 836.4814814814815,
#    'mean_in_use': 941.0416666666666,
#    'birth_years': [1821, 1840],
#    'death_years': [1834]}),
#  ('foer',
#   {'POS': 'ADP',
#    'max_usage': 4612.4,
#    'median_all': 4.699999999999999,
#    'median_in_use': 5.4,
#    'mean_all': 324.51759259259256,
#    'mean_in_use': 352.24020100502514,
#    'birth_years': [1812, 1823, 1831, 1842, 1853],
#    'death_years': [1805, 1816, 1827, 1840, 1851]}),
#  ('boldface',
#   {'POS': 'DET',
#    'max_usage': 4567.4,
#    'median_all': 89.8,
#    'median_in_use': 388.4,
#    'mean_all': 906.8175925925926,
#    'mean_in_use': 1231.903144654088,
#    'birth_years': [1830, 1866],
#    'death_years': [1803, 1834]}),
#  ('epub',
#   {'POS': 'PRON',
#    'max_usage': 4562.6,
#    'median_all': 0.0,
#    'median_in_use': 11.4,
#    'mean_all': 109.26759259259259,
#    'mean_in_use': 561.947619047619,
#    'birth_years': [1976],
#    'death_years': []}),
#  ('andandandandand',
#   {'POS': 'CONJ',
#    'max_usage': 4474.2,
#    'median_all': 0.0,
#    'median_in_use': 58.4,
#    'mean_all': 107.76296296296296,
#    'mean_in_use': 1012.0347826086957,
#    'birth_years': [1995],
#    'death_years': []})]

# %%
save_json(top_all,'','ALL CLOSED CLASSES TOP 500s')
save_csv(top_all,'','ALL CLOSED CLASSES TOP 500s')
# Out:
# SAVED:  ALL CLOSED CLASSES TOP 500s.json 1185
# SAVED:  ALL CLOSED CLASSES TOP 500s.csv 1185

# %% [markdown]
# ### Hypothesis #2: Group Instances of birth and death

# %%
death_lexemes, birth_lexemes = dict(), dict()

for lexeme, entries in ngrams.items():
    
    bit = len(entries['birth_years'])-len(entries['death_years'])
    
    if bit ==1:
        birth_lexemes[lexeme]=entries
    elif bit==0 or bit==-1: #was already in existence at lower time bound
        death_lexemes[lexeme]=entries
    else:
        print(bit)#,lexeme,entries)
        print()

# %% [markdown]
# Top Birth & Save

# %%
top_birth_max_usage = top_counts(birth_lexemes,'max_usage')
top_birth_median_all = top_counts(birth_lexemes,'median_all')
top_birth_median_in_use = top_counts(birth_lexemes,'median_in_use')
top_birth_mean_all = top_counts(birth_lexemes,'mean_all')
top_birth_mean_in_use = top_counts(birth_lexemes,'mean_in_use')
top_birth_all = {**top_birth_max_usage,**top_birth_median_all,**top_birth_median_in_use,**top_birth_mean_all,**top_birth_mean_in_use}
len(top_birth_all)
# Out:
# 1189

# %%
list((k,v) for k,v in top_birth_all.items())[:50]
# Out:
# [('bbe',
#   {'POS': 'ADP',
#    'max_usage': 133568.4,
#    'median_all': 4.8,
#    'median_in_use': 5.6,
#    'mean_all': 1470.3064814814813,
#    'mean_in_use': 1595.910552763819,
#    'birth_years': [1814, 1820, 1846],
#    'death_years': [1818, 1841]}),
#  ('nhe',
#   {'POS': 'ADP',
#    'max_usage': 75803.4,
#    'median_all': 4.4,
#    'median_in_use': 5.300000000000001,
#    'mean_all': 971.6851851851851,
#    'mean_in_use': 1093.1458333333333,
#    'birth_years': [1803, 1814, 1833, 1840, 1851],
#    'death_years': [1807, 1818, 1837, 1849]}),
#  ('proton',
#   {'POS': 'ADP',
#    'max_usage': 32690.0,
#    'median_all': 25.3,
#    'median_in_use': 54.2,
#    'mean_all': 6065.498148148148,
#    'mean_in_use': 7006.136898395722,
#    'birth_years': [1823, 1833, 1844],
#    'death_years': [1828, 1839]}),
#  ('transgender',
#   {'POS': 'DET',
#    'max_usage': 22530.8,
#    'median_all': 0.0,
#    'median_in_use': 31.200000000000003,
#    'mean_all': 796.3740740740741,
#    'mean_in_use': 2774.4645161290323,
#    'birth_years': [1947, 1958, 1971],
#    'death_years': [1951, 1967]}),
#  ('thruout',
#   {'POS': 'ADP',
#    'max_usage': 21064.8,
#    'median_all': 164.60000000000002,
#    'median_in_use': 320.9,
#    'mean_all': 1899.4074074074074,
#    'mean_in_use': 2182.2978723404253,
#    'birth_years': [1823, 1836, 1863],
#    'death_years': [1834, 1856]}),
#  ('bypass',
#   {'POS': 'ADP',
#    'max_usage': 21029.6,
#    'median_all': 42.900000000000006,
#    'median_in_use': 186.1,
#    'mean_all': 2935.186111111111,
#    'mean_in_use': 4012.659493670886,
#    'birth_years': [1830, 1863, 1883],
#    'death_years': [1834, 1880]}),
#  ('thethethethe',
#   {'POS': 'DET',
#    'max_usage': 18730.8,
#    'median_all': 0.0,
#    'median_in_use': 3.4,
#    'mean_all': 425.5925925925926,
#    'mean_in_use': 2484.5405405405404,
#    'birth_years': [1981],
#    'death_years': []}),
#  ('kjb',
#   {'POS': 'ADP',
#    'max_usage': 18063.6,
#    'median_all': 0.0,
#    'median_in_use': 1.0,
#    'mean_all': 195.2046296296296,
#    'mean_in_use': 2219.1684210526314,
#    'birth_years': [1975, 2004],
#    'death_years': [1979]}),
#  ('gonna',
#   {'POS': 'PRT',
#    'max_usage': 17807.0,
#    'median_all': 1.8,
#    'median_in_use': 248.2,
#    'mean_all': 1330.2324074074074,
#    'mean_in_use': 2435.001694915254,
#    'birth_years': [1830, 1886, 1910],
#    'death_years': [1834, 1890]}),
#  ('tomato',
#   {'POS': 'PRT',
#    'max_usage': 17370.8,
#    'median_all': 986.8000000000001,
#    'median_in_use': 1413.6,
#    'mean_all': 2848.7574074074073,
#    'mean_in_use': 2944.1703349282297,
#    'birth_years': [1803, 1810, 1817, 1827],
#    'death_years': [1807, 1814, 1824]}),
#  ('knockout',
#   {'POS': 'ADP',
#    'max_usage': 13710.0,
#    'median_all': 65.7,
#    'median_in_use': 105.8,
#    'mean_all': 1223.1453703703703,
#    'mean_in_use': 1620.8552147239263,
#    'birth_years': [1830, 1841, 1864, 1881],
#    'death_years': [1834, 1845, 1879]}),
#  ('ligand',
#   {'POS': 'CONJ',
#    'max_usage': 13554.6,
#    'median_all': 5.300000000000001,
#    'median_in_use': 7.2,
#    'mean_all': 1635.125,
#    'mean_in_use': 1940.5879120879122,
#    'birth_years': [1807, 1824, 1843, 1849, 1865, 1927],
#    'death_years': [1811, 1828, 1847, 1863, 1925]}),
#  ('sesame',
#   {'POS': 'DET',
#    'max_usage': 13423.2,
#    'median_all': 494.8,
#    'median_in_use': 584.5,
#    'mean_all': 1735.0435185185186,
#    'mean_in_use': 1837.1049019607842,
#    'birth_years': [1810, 1822, 1828],
#    'death_years': [1818, 1826]}),
#  ('alfalfa',
#   {'POS': 'DET',
#    'max_usage': 13002.2,
#    'median_all': 2880.7,
#    'median_in_use': 4390.4,
#    'mean_all': 3654.6546296296297,
#    'mean_in_use': 4133.012565445026,
#    'birth_years': [1814, 1825, 1839, 1850],
#    'death_years': [1818, 1837, 1843]}),
#  ('ofofofof',
#   {'POS': 'ADP',
#    'max_usage': 12266.2,
#    'median_all': 0.0,
#    'median_in_use': 2.0,
#    'mean_all': 280.67685185185184,
#    'mean_in_use': 1347.2488888888888,
#    'birth_years': [1954, 1960, 1979, 1988],
#    'death_years': [1958, 1964, 1983]}),
#  ('ylt',
#   {'POS': 'PRON',
#    'max_usage': 11158.2,
#    'median_all': 0.9,
#    'median_in_use': 2.3,
#    'mean_all': 117.1574074074074,
#    'mean_in_use': 191.71212121212122,
#    'birth_years': [1878, 1891, 1908, 1920, 1944],
#    'death_years': [1889, 1905, 1915, 1942]}),
#  ('sunflower',
#   {'POS': 'DET',
#    'max_usage': 11114.6,
#    'median_all': 916.8,
#    'median_in_use': 1103.4,
#    'mean_all': 2508.0814814814817,
#    'mean_in_use': 2579.7409523809524,
#    'birth_years': [1805, 1817, 1828],
#    'death_years': [1815, 1825]}),
#  ('website',
#   {'POS': 'PRON',
#    'max_usage': 10875.8,
#    'median_all': 0.0,
#    'median_in_use': 8.5,
#    'mean_all': 709.275,
#    'mean_in_use': 1740.9477272727272,
#    'birth_years': [1898, 1922, 1934, 1947, 1957],
#    'death_years': [1902, 1926, 1943, 1953]}),
#  ('phonon',
#   {'POS': 'ADP',
#    'max_usage': 9353.0,
#    'median_all': 1.5,
#    'median_in_use': 85.8,
#    'mean_all': 1712.512037037037,
#    'mean_in_use': 2845.404615384615,
#    'birth_years': [1824, 1851, 1867, 1875, 1904, 1916],
#    'death_years': [1828, 1855, 1871, 1879, 1911]}),
#  ('thuringiensis',
#   {'POS': 'ADP',
#    'max_usage': 9323.8,
#    'median_all': 2.8,
#    'median_in_use': 181.2,
#    'mean_all': 1313.0648148148148,
#    'mean_in_use': 2181.7076923076925,
#    'birth_years': [1829, 1867, 1892, 1898, 1904, 1913],
#    'death_years': [1833, 1871, 1896, 1902, 1908]}),
#  ('afp',
#   {'POS': 'ADP',
#    'max_usage': 9319.0,
#    'median_all': 0.0,
#    'median_in_use': 2.8,
#    'mean_all': 640.5175925925926,
#    'mean_in_use': 1471.827659574468,
#    'birth_years': [1899, 1908, 1924, 1949],
#    'death_years': [1906, 1914, 1933]}),
#  ('outta',
#   {'POS': 'ADP',
#    'max_usage': 9289.0,
#    'median_all': 10.4,
#    'median_in_use': 25.4,
#    'mean_all': 676.9694444444444,
#    'mean_in_use': 781.9540106951872,
#    'birth_years': [1814, 1831, 1842, 1848, 1855],
#    'death_years': [1818, 1839, 1846, 1852]}),
#  ('annja',
#   {'POS': 'DET',
#    'max_usage': 8853.0,
#    'median_all': 0.0,
#    'median_in_use': 833.8000000000001,
#    'mean_all': 255.88425925925927,
#    'mean_in_use': 2302.9583333333335,
#    'birth_years': [1994],
#    'death_years': []}),
#  ('andandandand',
#   {'POS': 'CONJ',
#    'max_usage': 8795.8,
#    'median_all': 0.0,
#    'median_in_use': 1.9,
#    'mean_all': 199.5185185185185,
#    'mean_in_use': 979.4545454545454,
#    'birth_years': [1973, 1979],
#    'death_years': [1977]}),
#  ('isbn',
#   {'POS': 'ADP',
#    'max_usage': 8320.6,
#    'median_all': 0.4,
#    'median_in_use': 33.0,
#    'mean_all': 822.3935185185185,
#    'mean_in_use': 1572.0088495575221,
#    'birth_years': [1836, 1850, 1888, 1904, 1910, 1922, 1933, 1945],
#    'death_years': [1840, 1854, 1892, 1908, 1914, 1931, 1937]}),
#  ('andand',
#   {'POS': 'CONJ',
#    'max_usage': 8266.8,
#    'median_all': 12.6,
#    'median_in_use': 13.0,
#    'mean_all': 317.7916666666667,
#    'mean_in_use': 326.87142857142857,
#    'birth_years': [1808],
#    'death_years': []}),
#  ('meself',
#   {'POS': 'PRON',
#    'max_usage': 8122.0,
#    'median_all': 585.8,
#    'median_in_use': 590.0,
#    'mean_all': 910.325,
#    'mean_in_use': 923.1464788732394,
#    'birth_years': [1805],
#    'death_years': []}),
#  ('pyr',
#   {'POS': 'ADP',
#    'max_usage': 7774.2,
#    'median_all': 9.8,
#    'median_in_use': 9.8,
#    'mean_all': 124.72592592592592,
#    'mean_in_use': 127.68151658767772,
#    'birth_years': [1807],
#    'death_years': []}),
#  ('ref',
#   {'POS': 'PRT',
#    'max_usage': 7624.6,
#    'median_all': 89.9,
#    'median_in_use': 647.0,
#    'mean_all': 1509.499074074074,
#    'mean_in_use': 1762.442162162162,
#    'birth_years': [1824, 1833, 1843],
#    'death_years': [1828, 1837]}),
#  ('thethethethethe',
#   {'POS': 'DET',
#    'max_usage': 7263.4,
#    'median_all': 0.0,
#    'median_in_use': 62.2,
#    'mean_all': 171.68703703703704,
#    'mean_in_use': 1612.3652173913044,
#    'birth_years': [1995],
#    'death_years': []}),
#  ('allograft',
#   {'POS': 'DET',
#    'max_usage': 7140.6,
#    'median_all': 0.0,
#    'median_in_use': 217.2,
#    'mean_all': 852.1333333333333,
#    'mean_in_use': 1752.96,
#    'birth_years': [1867, 1875, 1901, 1912, 1931, 1945],
#    'death_years': [1871, 1881, 1905, 1917, 1939]}),
#  ('thaliana',
#   {'POS': 'DET',
#    'max_usage': 6309.4,
#    'median_all': 3.7,
#    'median_in_use': 8.7,
#    'mean_all': 652.687962962963,
#    'mean_in_use': 903.7217948717948,
#    'birth_years': [1803, 1832, 1858, 1867, 1874, 1881, 1898],
#    'death_years': [1807, 1836, 1862, 1871, 1878, 1891]}),
#  ('actinomycin',
#   {'POS': 'ADP',
#    'max_usage': 6300.0,
#    'median_all': 3.6,
#    'median_in_use': 151.8,
#    'mean_all': 819.6296296296297,
#    'mean_in_use': 1394.015748031496,
#    'birth_years': [1867, 1875, 1901, 1912, 1921],
#    'death_years': [1871, 1885, 1908, 1917]}),
#  ('thymus',
#   {'POS': 'ADP',
#    'max_usage': 5859.8,
#    'median_all': 108.1,
#    'median_in_use': 131.6,
#    'mean_all': 798.9472222222222,
#    'mean_in_use': 903.5214659685864,
#    'birth_years': [1804, 1832],
#    'death_years': [1808]}),
#  ('outbound',
#   {'POS': 'ADP',
#    'max_usage': 5808.8,
#    'median_all': 342.2,
#    'median_in_use': 979.4000000000001,
#    'mean_all': 1014.312962962963,
#    'mean_in_use': 1386.6556962025315,
#    'birth_years': [1830, 1845, 1857, 1878],
#    'death_years': [1834, 1852, 1861]}),
#  ('inhalation',
#   {'POS': 'ADP',
#    'max_usage': 5603.0,
#    'median_all': 132.8,
#    'median_in_use': 183.4,
#    'mean_all': 1122.9231481481481,
#    'mean_in_use': 1243.8533333333332,
#    'birth_years': [1805, 1828],
#    'death_years': [1809]}),
#  ('php',
#   {'POS': 'ADP',
#    'max_usage': 5458.6,
#    'median_all': 0.4,
#    'median_in_use': 4.0,
#    'mean_all': 264.1212962962963,
#    'mean_in_use': 442.2496124031008,
#    'birth_years': [1825, 1853, 1897, 1919, 1928, 1935],
#    'death_years': [1830, 1861, 1917, 1923, 1932]}),
#  ('inininin',
#   {'POS': 'ADP',
#    'max_usage': 5451.8,
#    'median_all': 0.0,
#    'median_in_use': 3.2,
#    'mean_all': 124.13148148148149,
#    'mean_in_use': 766.0685714285714,
#    'birth_years': [1982, 1994],
#    'death_years': [1992]}),
#  ('aerosol',
#   {'POS': 'DET',
#    'max_usage': 5382.4,
#    'median_all': 2.9,
#    'median_in_use': 182.3,
#    'mean_all': 1026.3944444444444,
#    'mean_in_use': 1518.5013698630137,
#    'birth_years': [1830, 1867, 1875, 1881, 1901, 1916],
#    'death_years': [1834, 1871, 1879, 1897, 1912]}),
#  ('lsbn',
#   {'POS': 'ADP',
#    'max_usage': 5166.4,
#    'median_all': 0.0,
#    'median_in_use': 1374.4,
#    'mean_all': 476.11574074074076,
#    'mean_in_use': 1685.9180327868853,
#    'birth_years': [1957],
#    'death_years': []}),
#  ('offeror',
#   {'POS': 'ADP',
#    'max_usage': 5142.8,
#    'median_all': 9.3,
#    'median_in_use': 32.4,
#    'mean_all': 735.6268518518518,
#    'mean_in_use': 877.8751381215469,
#    'birth_years': [1823, 1849],
#    'death_years': [1834]}),
#  ('mainland',
#   {'POS': 'CONJ',
#    'max_usage': 4839.0,
#    'median_all': 62.900000000000006,
#    'median_in_use': 76.0,
#    'mean_all': 836.4814814814815,
#    'mean_in_use': 941.0416666666666,
#    'birth_years': [1821, 1840],
#    'death_years': [1834]}),
#  ('epub',
#   {'POS': 'PRON',
#    'max_usage': 4562.6,
#    'median_all': 0.0,
#    'median_in_use': 11.4,
#    'mean_all': 109.26759259259259,
#    'mean_in_use': 561.947619047619,
#    'birth_years': [1976],
#    'death_years': []}),
#  ('andandandandand',
#   {'POS': 'CONJ',
#    'max_usage': 4474.2,
#    'median_all': 0.0,
#    'median_in_use': 58.4,
#    'mean_all': 107.76296296296296,
#    'mean_in_use': 1012.0347826086957,
#    'birth_years': [1995],
#    'death_years': []}),
#  ('totototo',
#   {'POS': 'PRT',
#    'max_usage': 4428.0,
#    'median_all': 0.0,
#    'median_in_use': 0.8,
#    'mean_all': 100.35648148148148,
#    'mean_in_use': 277.9102564102564,
#    'birth_years': [1853, 1864, 1889, 1902, 1936, 1951, 1966, 1975, 1988],
#    'death_years': [1857, 1868, 1893, 1906, 1940, 1958, 1970, 1984]}),
#  ('lifestyle',
#   {'POS': 'ADP',
#    'max_usage': 4381.4,
#    'median_all': 0.0,
#    'median_in_use': 81.8,
#    'mean_all': 405.04814814814813,
#    'mean_in_use': 983.038202247191,
#    'birth_years': [1898, 1923, 1938, 1947],
#    'death_years': [1902, 1927, 1945]}),
#  ('ofofofofof',
#   {'POS': 'ADP',
#    'max_usage': 4371.8,
#    'median_all': 0.0,
#    'median_in_use': 68.8,
#    'mean_all': 106.45833333333333,
#    'mean_in_use': 792.9310344827586,
#    'birth_years': [1989],
#    'death_years': []}),
#  ('lnc',
#   {'POS': 'ADP',
#    'max_usage': 4347.2,
#    'median_all': 8.5,
#    'median_in_use': 30.6,
#    'mean_all': 382.0527777777778,
#    'mean_in_use': 539.3686274509804,
#    'birth_years': [1846, 1853, 1875, 1884],
#    'death_years': [1850, 1861, 1879]}),
#  ('magneto',
#   {'POS': 'DET',
#    'max_usage': 4156.0,
#    'median_all': 520.1,
#    'median_in_use': 643.9,
#    'mean_all': 639.7416666666667,
#    'mean_in_use': 759.2538461538461,
#    'birth_years': [1830, 1841],
#    'death_years': [1834]}),
#  ('byby',
#   {'POS': 'ADP',
#    'max_usage': 4046.6,
#    'median_all': 3.6,
#    'median_in_use': 4.4,
#    'mean_all': 77.7537037037037,
#    'mean_in_use': 98.79294117647059,
#    'birth_years': [1838, 1851, 1868],
#    'death_years': [1843, 1864]})]

# %%
save_json(top_birth_all,'','Birth Lexemes')
save_csv(top_birth_all,'','Birth Lexemes')
# Out:
# SAVED:  Birth Lexemes.json 1189
# SAVED:  Birth Lexemes.csv 1189

# %% [markdown]
# Top Death & Save

# %%
top_death_max_usage = top_counts(death_lexemes,'max_usage')
top_death_median_all = top_counts(death_lexemes,'median_all')
top_death_median_in_use = top_counts(death_lexemes,'median_in_use')
top_death_mean_all = top_counts(death_lexemes,'mean_all')
top_death_mean_in_use = top_counts(death_lexemes,'mean_in_use')
top_death_all = {**top_death_max_usage,**top_death_median_all,**top_death_median_in_use,**top_death_mean_all,**top_death_mean_in_use}
len(top_death_all)
# Out:
# 1104

# %%
list((k,v) for k,v in top_death_all.items())[:50]
# Out:
# [('anand',
#   {'POS': 'CONJ',
#    'max_usage': 8461.8,
#    'median_all': 73.80000000000001,
#    'median_in_use': 76.5,
#    'mean_all': 1434.974074074074,
#    'mean_in_use': 1448.385046728972,
#    'birth_years': [1809],
#    'death_years': [1806]}),
#  ('tendon',
#   {'POS': 'ADP',
#    'max_usage': 8344.4,
#    'median_all': 121.8,
#    'median_in_use': 131.5,
#    'mean_all': 890.4092592592592,
#    'mean_in_use': 915.8495238095238,
#    'birth_years': [1816, 1824],
#    'death_years': [1812, 1820]}),
#  ('yerself',
#   {'POS': 'PRON',
#    'max_usage': 7420.4,
#    'median_all': 336.79999999999995,
#    'median_in_use': 351.79999999999995,
#    'mean_all': 749.3518518518518,
#    'mean_in_use': 785.7281553398059,
#    'birth_years': [1814],
#    'death_years': [1803]}),
#  ('wurde',
#   {'POS': 'ADP',
#    'max_usage': 5163.6,
#    'median_all': 141.0,
#    'median_in_use': 142.9,
#    'mean_all': 422.06666666666666,
#    'mean_in_use': 426.011214953271,
#    'birth_years': [1813],
#    'death_years': [1810]}),
#  ('foer',
#   {'POS': 'ADP',
#    'max_usage': 4612.4,
#    'median_all': 4.699999999999999,
#    'median_in_use': 5.4,
#    'mean_all': 324.51759259259256,
#    'mean_in_use': 352.24020100502514,
#    'birth_years': [1812, 1823, 1831, 1842, 1853],
#    'death_years': [1805, 1816, 1827, 1840, 1851]}),
#  ('boldface',
#   {'POS': 'DET',
#    'max_usage': 4567.4,
#    'median_all': 89.8,
#    'median_in_use': 388.4,
#    'mean_all': 906.8175925925926,
#    'mean_in_use': 1231.903144654088,
#    'birth_years': [1830, 1866],
#    'death_years': [1803, 1834]}),
#  ('assignor',
#   {'POS': 'ADP',
#    'max_usage': 4165.2,
#    'median_all': 947.4,
#    'median_in_use': 957.8,
#    'mean_all': 1173.9898148148147,
#    'mean_in_use': 1190.5248826291079,
#    'birth_years': [1808],
#    'death_years': [1804]}),
#  ('alfa',
#   {'POS': 'DET',
#    'max_usage': 3350.6,
#    'median_all': 64.69999999999999,
#    'median_in_use': 64.8,
#    'mean_all': 346.44537037037037,
#    'mean_in_use': 348.0567441860465,
#    'birth_years': [1827],
#    'death_years': [1825]}),
#  ('thereunder',
#   {'POS': 'PRON',
#    'max_usage': 2998.6,
#    'median_all': 1047.7,
#    'median_in_use': 1162.3000000000002,
#    'mean_all': 1079.6824074074075,
#    'mean_in_use': 1110.5304761904763,
#    'birth_years': [1806, 1815],
#    'death_years': [1803, 1810]}),
#  ('listener',
#   {'POS': 'ADP',
#    'max_usage': 2714.2,
#    'median_all': 115.6,
#    'median_in_use': 115.6,
#    'mean_all': 400.89074074074074,
#    'mean_in_use': 402.7553488372093,
#    'birth_years': [1807],
#    'death_years': [1805]}),
#  ('wideband',
#   {'POS': 'ADP',
#    'max_usage': 2707.6,
#    'median_all': 3.3,
#    'median_in_use': 4.0,
#    'mean_all': 464.52129629629627,
#    'mean_in_use': 514.5466666666666,
#    'birth_years': [1807, 1818, 1843, 1857],
#    'death_years': [1805, 1811, 1831, 1853]}),
#  ('variance',
#   {'POS': 'ADP',
#    'max_usage': 2689.6,
#    'median_all': 9.9,
#    'median_in_use': 10.8,
#    'mean_all': 397.22407407407405,
#    'mean_in_use': 418.5385365853659,
#    'birth_years': [1817, 1832, 1848, 1862],
#    'death_years': [1812, 1830, 1845, 1857]}),
#  ('fofr',
#   {'POS': 'ADP',
#    'max_usage': 2557.8,
#    'median_all': 4.1,
#    'median_in_use': 4.2,
#    'mean_all': 67.49074074074075,
#    'mean_in_use': 67.8046511627907,
#    'birth_years': [1842],
#    'death_years': [1840]}),
#  ('atound',
#   {'POS': 'ADP',
#    'max_usage': 2406.4,
#    'median_all': 4.2,
#    'median_in_use': 4.4,
#    'mean_all': 84.07222222222222,
#    'mean_in_use': 88.58341463414634,
#    'birth_years': [1806, 1827],
#    'death_years': [1803, 1817]}),
#  ('kangaroo',
#   {'POS': 'DET',
#    'max_usage': 2286.2,
#    'median_all': 321.4,
#    'median_in_use': 323.2,
#    'mean_all': 585.8388888888888,
#    'mean_in_use': 588.5637209302325,
#    'birth_years': [1806],
#    'death_years': [1804]}),
#  ('xix',
#   {'POS': 'CONJ',
#    'max_usage': 2222.6,
#    'median_all': 169.5,
#    'median_in_use': 174.8,
#    'mean_all': 405.40092592592595,
#    'mean_in_use': 407.286511627907,
#    'birth_years': [1807],
#    'death_years': [1805]}),
#  ('nonemployer',
#   {'POS': 'CONJ',
#    'max_usage': 1999.2,
#    'median_all': 0.0,
#    'median_in_use': 4.6,
#    'mean_all': 50.61574074074074,
#    'mean_in_use': 352.6774193548387,
#    'birth_years': [1975],
#    'death_years': [2005]}),
#  ('lcaho',
#   {'POS': 'ADP',
#    'max_usage': 1927.0,
#    'median_all': 0.0,
#    'median_in_use': 11.6,
#    'mean_all': 105.47685185185185,
#    'mean_in_use': 386.1525423728813,
#    'birth_years': [1952, 1958],
#    'death_years': [1956, 2011]}),
#  ('insrt',
#   {'POS': 'ADP',
#    'max_usage': 1888.2,
#    'median_all': 0.0,
#    'median_in_use': 479.6,
#    'mean_all': 73.77777777777777,
#    'mean_in_use': 590.2222222222222,
#    'birth_years': [1983, 1996],
#    'death_years': [1994, 2010]}),
#  ('lllus',
#   {'POS': 'ADP',
#    'max_usage': 1759.2,
#    'median_all': 5.4,
#    'median_in_use': 10.1,
#    'mean_all': 72.81944444444444,
#    'mean_in_use': 98.30625,
#    'birth_years': [1847, 1853, 1862],
#    'death_years': [1851, 1857, 2011]}),
#  ('becouse',
#   {'POS': 'ADP',
#    'max_usage': 1749.2,
#    'median_all': 28.5,
#    'median_in_use': 29.2,
#    'mean_all': 250.3740740740741,
#    'mean_in_use': 251.53860465116279,
#    'birth_years': [1810],
#    'death_years': [1808]}),
#  ('dgn',
#   {'POS': 'ADP',
#    'max_usage': 1741.6,
#    'median_all': 0.4,
#    'median_in_use': 2.0,
#    'mean_all': 45.90925925925926,
#    'mean_in_use': 74.00298507462686,
#    'birth_years': [1850, 1862, 1885, 1902, 1927, 1942, 1950],
#    'death_years': [1804, 1854, 1866, 1896, 1925, 1938, 1946]}),
#  ('instill',
#   {'POS': 'ADP',
#    'max_usage': 1680.0,
#    'median_all': 82.8,
#    'median_in_use': 83.2,
#    'mean_all': 279.1111111111111,
#    'mean_in_use': 283.0422535211268,
#    'birth_years': [1830],
#    'death_years': [1826]}),
#  ('lraq',
#   {'POS': 'ADP',
#    'max_usage': 1439.2,
#    'median_all': 0.0,
#    'median_in_use': 53.0,
#    'mean_all': 71.41666666666667,
#    'mean_in_use': 214.25,
#    'birth_years': [1945],
#    'death_years': [2016]}),
#  ('moot',
#   {'POS': 'PRON',
#    'max_usage': 1433.0,
#    'median_all': 33.4,
#    'median_in_use': 34.8,
#    'mean_all': 290.68888888888887,
#    'mean_in_use': 296.1735849056604,
#    'birth_years': [1813, 1830, 1840],
#    'death_years': [1810, 1828, 1838]}),
#  ('providing',
#   {'POS': 'ADP',
#    'max_usage': 1388.8,
#    'median_all': 286.8,
#    'median_in_use': 289.1,
#    'mean_all': 346.93981481481484,
#    'mean_in_use': 350.18224299065423,
#    'birth_years': [1809],
#    'death_years': [1806]}),
#  ('thankyou',
#   {'POS': 'PRON',
#    'max_usage': 1308.4,
#    'median_all': 12.3,
#    'median_in_use': 12.600000000000001,
#    'mean_all': 112.21944444444445,
#    'mean_in_use': 113.26822429906542,
#    'birth_years': [1831],
#    'death_years': [1828]}),
#  ('lowand',
#   {'POS': 'CONJ',
#    'max_usage': 1191.8,
#    'median_all': 5.9,
#    'median_in_use': 6.4,
#    'mean_all': 202.7935185185185,
#    'mean_in_use': 205.64976525821598,
#    'birth_years': [1822, 1828],
#    'death_years': [1819, 1826]}),
#  ('animalsl',
#   {'POS': 'DET',
#    'max_usage': 1191.4,
#    'median_all': 0.4,
#    'median_in_use': 1.6,
#    'mean_all': 29.65740740740741,
#    'mean_in_use': 58.77064220183486,
#    'birth_years': [1849, 1870, 1886, 1898, 1904, 1910, 1932, 1949, 1959],
#    'death_years': [1853, 1874, 1890, 1902, 1908, 1918, 1940, 1957, 2015]}),
#  ('varus',
#   {'POS': 'ADP',
#    'max_usage': 1189.4,
#    'median_all': 35.3,
#    'median_in_use': 41.2,
#    'mean_all': 139.6898148148148,
#    'mean_in_use': 153.16243654822335,
#    'birth_years': [1828],
#    'death_years': [1808]}),
#  ('aq',
#   {'POS': 'ADP',
#    'max_usage': 1187.8,
#    'median_all': 6.8,
#    'median_in_use': 6.8,
#    'mean_all': 73.10462962962963,
#    'mean_in_use': 73.78785046728972,
#    'birth_years': [1837],
#    'death_years': [1834]}),
#  ('interf',
#   {'POS': 'ADP',
#    'max_usage': 1154.0,
#    'median_all': 16.9,
#    'median_in_use': 17.4,
#    'mean_all': 107.22962962962963,
#    'mean_in_use': 110.29333333333334,
#    'birth_years': [1811, 1825],
#    'death_years': [1809, 1819]}),
#  ('besonderer',
#   {'POS': 'ADP',
#    'max_usage': 1141.4,
#    'median_all': 397.1,
#    'median_in_use': 447.2,
#    'mean_all': 418.39074074074074,
#    'mean_in_use': 449.6139303482587,
#    'birth_years': [1822],
#    'death_years': [1806]}),
#  ('oror',
#   {'POS': 'CONJ',
#    'max_usage': 1092.2,
#    'median_all': 8.6,
#    'median_in_use': 8.8,
#    'mean_all': 39.4537037037037,
#    'mean_in_use': 40.77511961722488,
#    'birth_years': [1807, 1822, 1839],
#    'death_years': [1805, 1816, 1837]}),
#  ('ofengland',
#   {'POS': 'CONJ',
#    'max_usage': 1086.0,
#    'median_all': 19.1,
#    'median_in_use': 19.2,
#    'mean_all': 56.76759259259259,
#    'mean_in_use': 57.031627906976745,
#    'birth_years': [1943],
#    'death_years': [1941]}),
#  ('nays',
#   {'POS': 'ADP',
#    'max_usage': 1083.2,
#    'median_all': 11.9,
#    'median_in_use': 31.0,
#    'mean_all': 81.7175925925926,
#    'mean_in_use': 116.89403973509934,
#    'birth_years': [1851, 2007],
#    'death_years': [1995, 2012]}),
#  ('blll',
#   {'POS': 'DET',
#    'max_usage': 1074.4,
#    'median_all': 0.5,
#    'median_in_use': 77.4,
#    'mean_all': 81.68518518518519,
#    'mean_in_use': 138.92913385826773,
#    'birth_years': [1863, 1873, 1981, 1988],
#    'death_years': [1867, 1979, 1985, 1997]}),
#  ('anorher',
#   {'POS': 'DET',
#    'max_usage': 1067.6,
#    'median_all': 8.0,
#    'median_in_use': 8.1,
#    'mean_all': 51.91851851851852,
#    'mean_in_use': 53.40190476190476,
#    'birth_years': [1827],
#    'death_years': [1821, 2016]}),
#  ('depict',
#   {'POS': 'PRT',
#    'max_usage': 1007.0,
#    'median_all': 42.4,
#    'median_in_use': 42.7,
#    'mean_all': 176.72222222222223,
#    'mean_in_use': 180.0566037735849,
#    'birth_years': [1806, 1816],
#    'death_years': [1803, 1813]}),
#  ('asaignor',
#   {'POS': 'ADP',
#    'max_usage': 1004.4,
#    'median_all': 1.2,
#    'median_in_use': 7.2,
#    'mean_all': 37.24074074074074,
#    'mean_in_use': 60.48120300751879,
#    'birth_years': [1850, 1934, 1949, 1963, 1973, 2000],
#    'death_years': [1931, 1938, 1959, 1967, 1997, 2004]}),
#  ('lndoor',
#   {'POS': 'ADP',
#    'max_usage': 984.0,
#    'median_all': 1.8,
#    'median_in_use': 5.4,
#    'mean_all': 59.2037037037037,
#    'mean_in_use': 96.15037593984962,
#    'birth_years': [1867, 1887, 1928],
#    'death_years': [1871, 1925, 2016]}),
#  ('aaaignor',
#   {'POS': 'ADP',
#    'max_usage': 956.8,
#    'median_all': 0.0,
#    'median_in_use': 5.8,
#    'mean_all': 29.296296296296298,
#    'mean_in_use': 65.23711340206185,
#    'birth_years': [1856, 1870, 1909, 1927, 1949, 1963, 1970],
#    'death_years': [1860, 1907, 1913, 1931, 1959, 1967, 1997]}),
#  ('behind',
#   {'POS': 'PRT',
#    'max_usage': 956.2,
#    'median_all': 34.099999999999994,
#    'median_in_use': 35.2,
#    'mean_all': 124.14166666666667,
#    'mean_in_use': 127.08341232227488,
#    'birth_years': [1819, 1838],
#    'death_years': [1816, 1834]}),
#  ('after',
#   {'POS': 'ADP',
#    'max_usage': 953.4,
#    'median_all': 6.4,
#    'median_in_use': 6.8,
#    'mean_all': 53.635185185185186,
#    'mean_in_use': 55.967149758454106,
#    'birth_years': [1823, 1829, 1847],
#    'death_years': [1821, 1827, 1839]}),
#  ('whereafter',
#   {'POS': 'ADP',
#    'max_usage': 946.2,
#    'median_all': 87.3,
#    'median_in_use': 89.8,
#    'mean_all': 226.25,
#    'mean_in_use': 227.30232558139534,
#    'birth_years': [1830],
#    'death_years': [1828]}),
#  ('trout',
#   {'POS': 'PRT',
#    'max_usage': 910.8,
#    'median_all': 196.3,
#    'median_in_use': 196.6,
#    'mean_all': 272.3361111111111,
#    'mean_in_use': 273.60279069767444,
#    'birth_years': [1805],
#    'death_years': [1803]}),
#  ('abscissa',
#   {'POS': 'DET',
#    'max_usage': 899.6,
#    'median_all': 208.5,
#    'median_in_use': 215.0,
#    'mean_all': 262.93888888888887,
#    'mean_in_use': 264.16186046511626,
#    'birth_years': [1807],
#    'death_years': [1805]}),
#  ('behaviour',
#   {'POS': 'PRT',
#    'max_usage': 894.0,
#    'median_all': 5.2,
#    'median_in_use': 6.300000000000001,
#    'mean_all': 112.20370370370371,
#    'mean_in_use': 118.80392156862744,
#    'birth_years': [1818, 1835, 1871],
#    'death_years': [1816, 1832, 1861]}),
#  ('theologia',
#   {'POS': 'DET',
#    'max_usage': 883.0,
#    'median_all': 40.400000000000006,
#    'median_in_use': 40.6,
#    'mean_all': 120.52222222222223,
#    'mean_in_use': 121.64859813084112,
#    'birth_years': [1806],
#    'death_years': [1803]}),
#  ('fucr',
#   {'POS': 'ADP',
#    'max_usage': 883.0,
#    'median_all': 2.4,
#    'median_in_use': 5.4,
#    'mean_all': 37.56018518518518,
#    'mean_in_use': 60.096296296296295,
#    'birth_years': [1866, 1882],
#    'death_years': [1870, 2011]})]

# %%
save_json(top_death_all,'','Death Lexemes')
save_csv(top_death_all,'','Death Lexemes')
# Out:
# SAVED:  Death Lexemes.json 1104
# SAVED:  Death Lexemes.csv 1104

# %% [markdown]
# ### Hypothesis #3: Single Instances are more reliable than those that oscillate in and out

# %% [markdown]
# Birth

# %%
single_birth_lexemes = dict()
for lexeme, entries in birth_lexemes.items():
    if len(entries['birth_years'])==1:
        single_birth_lexemes[lexeme]=entries

# %%
len(single_birth_lexemes.keys())
# Out:
# 15469

# %%
top_single_birth_max_usage = top_counts(single_birth_lexemes,'max_usage')
top_single_birth_median_all = top_counts(single_birth_lexemes,'median_all')
top_single_birth_median_in_use = top_counts(single_birth_lexemes,'median_in_use')
top_single_birth_mean_all = top_counts(single_birth_lexemes,'mean_all')
top_single_birth_mean_in_use = top_counts(single_birth_lexemes,'mean_in_use')
top_single_birth_all = {**top_single_birth_max_usage,**top_single_birth_median_all,**top_single_birth_median_in_use,**top_single_birth_mean_all,**top_single_birth_mean_in_use}
len(top_single_birth_all)
# Out:
# 1095

# %%
list((k,v) for k,v in top_single_birth_all.items())[:50]
# Out:
# [('thethethethe',
#   {'POS': 'DET',
#    'max_usage': 18730.8,
#    'median_all': 0.0,
#    'median_in_use': 3.4,
#    'mean_all': 425.5925925925926,
#    'mean_in_use': 2484.5405405405404,
#    'birth_years': [1981],
#    'death_years': []}),
#  ('annja',
#   {'POS': 'DET',
#    'max_usage': 8853.0,
#    'median_all': 0.0,
#    'median_in_use': 833.8000000000001,
#    'mean_all': 255.88425925925927,
#    'mean_in_use': 2302.9583333333335,
#    'birth_years': [1994],
#    'death_years': []}),
#  ('andand',
#   {'POS': 'CONJ',
#    'max_usage': 8266.8,
#    'median_all': 12.6,
#    'median_in_use': 13.0,
#    'mean_all': 317.7916666666667,
#    'mean_in_use': 326.87142857142857,
#    'birth_years': [1808],
#    'death_years': []}),
#  ('meself',
#   {'POS': 'PRON',
#    'max_usage': 8122.0,
#    'median_all': 585.8,
#    'median_in_use': 590.0,
#    'mean_all': 910.325,
#    'mean_in_use': 923.1464788732394,
#    'birth_years': [1805],
#    'death_years': []}),
#  ('pyr',
#   {'POS': 'ADP',
#    'max_usage': 7774.2,
#    'median_all': 9.8,
#    'median_in_use': 9.8,
#    'mean_all': 124.72592592592592,
#    'mean_in_use': 127.68151658767772,
#    'birth_years': [1807],
#    'death_years': []}),
#  ('thethethethethe',
#   {'POS': 'DET',
#    'max_usage': 7263.4,
#    'median_all': 0.0,
#    'median_in_use': 62.2,
#    'mean_all': 171.68703703703704,
#    'mean_in_use': 1612.3652173913044,
#    'birth_years': [1995],
#    'death_years': []}),
#  ('lsbn',
#   {'POS': 'ADP',
#    'max_usage': 5166.4,
#    'median_all': 0.0,
#    'median_in_use': 1374.4,
#    'mean_all': 476.11574074074076,
#    'mean_in_use': 1685.9180327868853,
#    'birth_years': [1957],
#    'death_years': []}),
#  ('epub',
#   {'POS': 'PRON',
#    'max_usage': 4562.6,
#    'median_all': 0.0,
#    'median_in_use': 11.4,
#    'mean_all': 109.26759259259259,
#    'mean_in_use': 561.947619047619,
#    'birth_years': [1976],
#    'death_years': []}),
#  ('andandandandand',
#   {'POS': 'CONJ',
#    'max_usage': 4474.2,
#    'median_all': 0.0,
#    'median_in_use': 58.4,
#    'mean_all': 107.76296296296296,
#    'mean_in_use': 1012.0347826086957,
#    'birth_years': [1995],
#    'death_years': []}),
#  ('ofofofofof',
#   {'POS': 'ADP',
#    'max_usage': 4371.8,
#    'median_all': 0.0,
#    'median_in_use': 68.8,
#    'mean_all': 106.45833333333333,
#    'mean_in_use': 792.9310344827586,
#    'birth_years': [1989],
#    'death_years': []}),
#  ('dut',
#   {'POS': 'PRON',
#    'max_usage': 4020.2,
#    'median_all': 6.2,
#    'median_in_use': 6.4,
#    'mean_all': 46.919444444444444,
#    'mean_in_use': 48.26,
#    'birth_years': [1808],
#    'death_years': []}),
#  ('abdomen',
#   {'POS': 'ADP',
#    'max_usage': 3720.2,
#    'median_all': 597.5999999999999,
#    'median_in_use': 597.8,
#    'mean_all': 867.1185185185185,
#    'mean_in_use': 871.1516279069767,
#    'birth_years': [1803],
#    'death_years': []}),
#  ('subhead',
#   {'POS': 'CONJ',
#    'max_usage': 3079.8,
#    'median_all': 2.0,
#    'median_in_use': 101.2,
#    'mean_all': 161.59259259259258,
#    'mean_in_use': 272.6875,
#    'birth_years': [1890],
#    'death_years': []}),
#  ('queer',
#   {'POS': 'CONJ',
#    'max_usage': 3076.6,
#    'median_all': 168.60000000000002,
#    'median_in_use': 169.8,
#    'mean_all': 266.8898148148148,
#    'mean_in_use': 268.13116279069766,
#    'birth_years': [1803],
#    'death_years': []}),
#  ('howard',
#   {'POS': 'PRT',
#    'max_usage': 2991.2,
#    'median_all': 58.099999999999994,
#    'median_in_use': 74.5,
#    'mean_all': 241.25925925925927,
#    'mean_in_use': 260.56,
#    'birth_years': [1818],
#    'death_years': []}),
#  ('ospf',
#   {'POS': 'ADP',
#    'max_usage': 2918.2,
#    'median_all': 0.0,
#    'median_in_use': 1935.6,
#    'mean_all': 192.51018518518518,
#    'mean_in_use': 1599.3153846153846,
#    'birth_years': [1992],
#    'death_years': []}),
#  ('almond',
#   {'POS': 'CONJ',
#    'max_usage': 2599.0,
#    'median_all': 60.7,
#    'median_in_use': 74.8,
#    'mean_all': 283.9037037037037,
#    'mean_in_use': 303.58019801980197,
#    'birth_years': [1816],
#    'death_years': []}),
#  ('nail',
#   {'POS': 'DET',
#    'max_usage': 2574.0,
#    'median_all': 121.5,
#    'median_in_use': 130.4,
#    'mean_all': 382.1277777777778,
#    'mean_in_use': 398.74202898550726,
#    'birth_years': [1811],
#    'death_years': []}),
#  ('secondhand',
#   {'POS': 'CONJ',
#    'max_usage': 2546.0,
#    'median_all': 431.4,
#    'median_in_use': 462.4,
#    'mean_all': 693.6972222222222,
#    'mean_in_use': 700.1803738317757,
#    'birth_years': [1804],
#    'death_years': []}),
#  ('forfor',
#   {'POS': 'ADP',
#    'max_usage': 2443.6,
#    'median_all': 11.0,
#    'median_in_use': 11.1,
#    'mean_all': 106.51203703703703,
#    'mean_in_use': 107.50747663551402,
#    'birth_years': [1804],
#    'death_years': []}),
#  ('amorphous',
#   {'POS': 'ADP',
#    'max_usage': 2423.6,
#    'median_all': 129.6,
#    'median_in_use': 130.2,
#    'mean_all': 429.5111111111111,
#    'mean_in_use': 431.5088372093023,
#    'birth_years': [1803],
#    'death_years': []}),
#  ('anhydrite',
#   {'POS': 'DET',
#    'max_usage': 2277.0,
#    'median_all': 195.7,
#    'median_in_use': 296.6,
#    'mean_all': 549.6287037037038,
#    'mean_in_use': 584.8266009852217,
#    'birth_years': [1815],
#    'death_years': []}),
#  ('ininininin',
#   {'POS': 'ADP',
#    'max_usage': 2254.2,
#    'median_all': 0.0,
#    'median_in_use': 36.6,
#    'mean_all': 54.73240740740741,
#    'mean_in_use': 514.0086956521739,
#    'birth_years': [1995],
#    'death_years': []}),
#  ('twee',
#   {'POS': 'DET',
#    'max_usage': 2239.8,
#    'median_all': 29.299999999999997,
#    'median_in_use': 29.5,
#    'mean_all': 129.16203703703704,
#    'mean_in_use': 130.36915887850466,
#    'birth_years': [1804],
#    'death_years': []}),
#  ('neem',
#   {'POS': 'DET',
#    'max_usage': 2219.2,
#    'median_all': 4.5,
#    'median_in_use': 9.1,
#    'mean_all': 260.5064814814815,
#    'mean_in_use': 330.9964705882353,
#    'birth_years': [1848],
#    'death_years': []}),
#  ('ihren',
#   {'POS': 'ADP',
#    'max_usage': 2214.6,
#    'median_all': 51.6,
#    'median_in_use': 52.6,
#    'mean_all': 117.33796296296296,
#    'mean_in_use': 123.63414634146342,
#    'birth_years': [1813],
#    'death_years': []}),
#  ('benzo',
#   {'POS': 'ADP',
#    'max_usage': 2167.4,
#    'median_all': 46.1,
#    'median_in_use': 93.6,
#    'mean_all': 321.0675925925926,
#    'mean_in_use': 447.4232258064516,
#    'birth_years': [1863],
#    'death_years': []}),
#  ('siphon',
#   {'POS': 'ADP',
#    'max_usage': 2025.0,
#    'median_all': 691.3,
#    'median_in_use': 713.2,
#    'mean_all': 776.9055555555556,
#    'mean_in_use': 787.8478873239436,
#    'birth_years': [1805],
#    'death_years': []}),
#  ('itjust',
#   {'POS': 'PRON',
#    'max_usage': 1991.6,
#    'median_all': 10.0,
#    'median_in_use': 10.3,
#    'mean_all': 82.96944444444445,
#    'mean_in_use': 83.7448598130841,
#    'birth_years': [1804],
#    'death_years': []}),
#  ('xxx',
#   {'POS': 'PRON',
#    'max_usage': 1988.6,
#    'median_all': 125.4,
#    'median_in_use': 127.6,
#    'mean_all': 334.06296296296296,
#    'mean_in_use': 335.6167441860465,
#    'birth_years': [1803],
#    'death_years': []}),
#  ('americanus',
#   {'POS': 'ADP',
#    'max_usage': 1903.6,
#    'median_all': 436.4,
#    'median_in_use': 448.79999999999995,
#    'mean_all': 486.64537037037036,
#    'mean_in_use': 495.82735849056604,
#    'birth_years': [1806],
#    'death_years': []}),
#  ('ofvarious',
#   {'POS': 'ADP',
#    'max_usage': 1894.4,
#    'median_all': 7.4,
#    'median_in_use': 7.5,
#    'mean_all': 84.8462962962963,
#    'mean_in_use': 85.63925233644859,
#    'birth_years': [1804],
#    'death_years': []}),
#  ('beliefin',
#   {'POS': 'ADP',
#    'max_usage': 1859.8,
#    'median_all': 15.5,
#    'median_in_use': 15.8,
#    'mean_all': 93.58703703703704,
#    'mean_in_use': 94.02232558139535,
#    'birth_years': [1803],
#    'death_years': []}),
#  ('femur',
#   {'POS': 'ADP',
#    'max_usage': 1807.8,
#    'median_all': 151.8,
#    'median_in_use': 174.1,
#    'mean_all': 329.9527777777778,
#    'mean_in_use': 352.82079207920793,
#    'birth_years': [1816],
#    'death_years': []}),
#  ('withwith',
#   {'POS': 'ADP',
#    'max_usage': 1763.2,
#    'median_all': 9.0,
#    'median_in_use': 9.0,
#    'mean_all': 71.9462962962963,
#    'mean_in_use': 72.95962441314553,
#    'birth_years': [1805],
#    'death_years': []}),
#  ('bybybyby',
#   {'POS': 'ADP',
#    'max_usage': 1736.8,
#    'median_all': 0.0,
#    'median_in_use': 18.200000000000003,
#    'mean_all': 39.39259259259259,
#    'mean_in_use': 531.8,
#    'birth_years': [2002],
#    'death_years': []}),
#  ('cyclin',
#   {'POS': 'ADP',
#    'max_usage': 1545.4,
#    'median_all': 0.0,
#    'median_in_use': 77.3,
#    'mean_all': 141.3101851851852,
#    'mean_in_use': 508.71666666666664,
#    'birth_years': [1958],
#    'death_years': []}),
#  ('thatthatthatthat',
#   {'POS': 'DET',
#    'max_usage': 1541.8,
#    'median_all': 0.0,
#    'median_in_use': 3.6,
#    'mean_all': 34.37592592592593,
#    'mean_in_use': 436.77647058823527,
#    'birth_years': [2001],
#    'death_years': []}),
#  ('lce',
#   {'POS': 'ADP',
#    'max_usage': 1517.0,
#    'median_all': 67.2,
#    'median_in_use': 80.2,
#    'mean_all': 263.9925925925926,
#    'mean_in_use': 283.69353233830844,
#    'birth_years': [1817],
#    'death_years': []}),
#  ('lndex',
#   {'POS': 'ADP',
#    'max_usage': 1513.0,
#    'median_all': 0.4,
#    'median_in_use': 14.100000000000001,
#    'mean_all': 76.70185185185186,
#    'mean_in_use': 150.61454545454546,
#    'birth_years': [1908],
#    'death_years': []}),
#  ('ullamcorper',
#   {'POS': 'ADP',
#    'max_usage': 1468.2,
#    'median_all': 0.0,
#    'median_in_use': 277.0,
#    'mean_all': 32.830555555555556,
#    'mean_in_use': 472.76,
#    'birth_years': [2003],
#    'death_years': []}),
#  ('volutpat',
#   {'POS': 'CONJ',
#    'max_usage': 1427.2,
#    'median_all': 0.0,
#    'median_in_use': 220.0,
#    'mean_all': 28.20462962962963,
#    'mean_in_use': 507.68333333333334,
#    'birth_years': [2006],
#    'death_years': []}),
#  ('accomplice',
#   {'POS': 'DET',
#    'max_usage': 1415.8,
#    'median_all': 96.3,
#    'median_in_use': 106.1,
#    'mean_all': 259.9916666666667,
#    'mean_in_use': 280.791,
#    'birth_years': [1818],
#    'death_years': []}),
#  ('persistence',
#   {'POS': 'ADP',
#    'max_usage': 1368.0,
#    'median_all': 56.9,
#    'median_in_use': 73.6,
#    'mean_all': 212.8925925925926,
#    'mean_in_use': 267.353488372093,
#    'birth_years': [1846],
#    'death_years': []}),
#  ('thumbnail',
#   {'POS': 'DET',
#    'max_usage': 1349.6,
#    'median_all': 1.9,
#    'median_in_use': 53.6,
#    'mean_all': 112.78703703703704,
#    'mean_in_use': 194.896,
#    'birth_years': [1893],
#    'death_years': []}),
#  ('throughput',
#   {'POS': 'PRON',
#    'max_usage': 1332.6,
#    'median_all': 0.0,
#    'median_in_use': 221.4,
#    'mean_all': 203.70555555555555,
#    'mean_in_use': 435.64752475247525,
#    'birth_years': [1917],
#    'death_years': []}),
#  ('algebra',
#   {'POS': 'ADP',
#    'max_usage': 1278.6,
#    'median_all': 54.6,
#    'median_in_use': 54.8,
#    'mean_all': 253.67592592592592,
#    'mean_in_use': 256.04672897196264,
#    'birth_years': [1804],
#    'death_years': []}),
#  ('meropenem',
#   {'POS': 'PRON',
#    'max_usage': 1262.8,
#    'median_all': 0.0,
#    'median_in_use': 312.9,
#    'mean_all': 81.87592592592593,
#    'mean_in_use': 465.4,
#    'birth_years': [1980],
#    'death_years': []}),
#  ('thisthisthisthis',
#   {'POS': 'DET',
#    'max_usage': 1261.0,
#    'median_all': 0.0,
#    'median_in_use': 2.6,
#    'mean_all': 28.19351851851852,
#    'mean_in_use': 358.22352941176473,
#    'birth_years': [2001],
#    'death_years': []}),
#  ('forforforforfor',
#   {'POS': 'ADP',
#    'max_usage': 1241.4,
#    'median_all': 0.0,
#    'median_in_use': 17.8,
#    'mean_all': 29.997222222222224,
#    'mean_in_use': 281.7130434782609,
#    'birth_years': [1995],
#    'death_years': []})]

# %%
save_json(top_single_birth_all,'','Single Birth Lexemes')
save_csv(top_single_birth_all,'','Single Birth Lexemes')
# Out:
# SAVED:  Single Birth Lexemes.json 1095
# SAVED:  Single Birth Lexemes.csv 1095

# %% [markdown]
# Death

# %%
single_death_lexemes = dict()
for lexeme, entries in death_lexemes.items():
    if len(entries['death_years'])==1:
        single_death_lexemes[lexeme]=entries

# %%
len(single_death_lexemes.keys())
# Out:
# 13682

# %%
top_single_death_max_usage = top_counts(single_death_lexemes,'max_usage')
top_single_death_median_all = top_counts(single_death_lexemes,'median_all')
top_single_death_median_in_use = top_counts(single_death_lexemes,'median_in_use')
top_single_death_mean_all = top_counts(single_death_lexemes,'mean_all')
top_single_death_mean_in_use = top_counts(single_death_lexemes,'mean_in_use')
top_single_death_all = {**top_single_death_max_usage,**top_single_death_median_all,**top_single_death_median_in_use,**top_single_death_mean_all,**top_single_death_mean_in_use}
len(top_single_death_all)
# Out:
# 988

# %%
list((k,v) for k,v in top_single_death_all.items())[:50]
# Out:
# [('anand',
#   {'POS': 'CONJ',
#    'max_usage': 8461.8,
#    'median_all': 73.80000000000001,
#    'median_in_use': 76.5,
#    'mean_all': 1434.974074074074,
#    'mean_in_use': 1448.385046728972,
#    'birth_years': [1809],
#    'death_years': [1806]}),
#  ('yerself',
#   {'POS': 'PRON',
#    'max_usage': 7420.4,
#    'median_all': 336.79999999999995,
#    'median_in_use': 351.79999999999995,
#    'mean_all': 749.3518518518518,
#    'mean_in_use': 785.7281553398059,
#    'birth_years': [1814],
#    'death_years': [1803]}),
#  ('wurde',
#   {'POS': 'ADP',
#    'max_usage': 5163.6,
#    'median_all': 141.0,
#    'median_in_use': 142.9,
#    'mean_all': 422.06666666666666,
#    'mean_in_use': 426.011214953271,
#    'birth_years': [1813],
#    'death_years': [1810]}),
#  ('assignor',
#   {'POS': 'ADP',
#    'max_usage': 4165.2,
#    'median_all': 947.4,
#    'median_in_use': 957.8,
#    'mean_all': 1173.9898148148147,
#    'mean_in_use': 1190.5248826291079,
#    'birth_years': [1808],
#    'death_years': [1804]}),
#  ('alfa',
#   {'POS': 'DET',
#    'max_usage': 3350.6,
#    'median_all': 64.69999999999999,
#    'median_in_use': 64.8,
#    'mean_all': 346.44537037037037,
#    'mean_in_use': 348.0567441860465,
#    'birth_years': [1827],
#    'death_years': [1825]}),
#  ('listener',
#   {'POS': 'ADP',
#    'max_usage': 2714.2,
#    'median_all': 115.6,
#    'median_in_use': 115.6,
#    'mean_all': 400.89074074074074,
#    'mean_in_use': 402.7553488372093,
#    'birth_years': [1807],
#    'death_years': [1805]}),
#  ('fofr',
#   {'POS': 'ADP',
#    'max_usage': 2557.8,
#    'median_all': 4.1,
#    'median_in_use': 4.2,
#    'mean_all': 67.49074074074075,
#    'mean_in_use': 67.8046511627907,
#    'birth_years': [1842],
#    'death_years': [1840]}),
#  ('kangaroo',
#   {'POS': 'DET',
#    'max_usage': 2286.2,
#    'median_all': 321.4,
#    'median_in_use': 323.2,
#    'mean_all': 585.8388888888888,
#    'mean_in_use': 588.5637209302325,
#    'birth_years': [1806],
#    'death_years': [1804]}),
#  ('xix',
#   {'POS': 'CONJ',
#    'max_usage': 2222.6,
#    'median_all': 169.5,
#    'median_in_use': 174.8,
#    'mean_all': 405.40092592592595,
#    'mean_in_use': 407.286511627907,
#    'birth_years': [1807],
#    'death_years': [1805]}),
#  ('nonemployer',
#   {'POS': 'CONJ',
#    'max_usage': 1999.2,
#    'median_all': 0.0,
#    'median_in_use': 4.6,
#    'mean_all': 50.61574074074074,
#    'mean_in_use': 352.6774193548387,
#    'birth_years': [1975],
#    'death_years': [2005]}),
#  ('becouse',
#   {'POS': 'ADP',
#    'max_usage': 1749.2,
#    'median_all': 28.5,
#    'median_in_use': 29.2,
#    'mean_all': 250.3740740740741,
#    'mean_in_use': 251.53860465116279,
#    'birth_years': [1810],
#    'death_years': [1808]}),
#  ('instill',
#   {'POS': 'ADP',
#    'max_usage': 1680.0,
#    'median_all': 82.8,
#    'median_in_use': 83.2,
#    'mean_all': 279.1111111111111,
#    'mean_in_use': 283.0422535211268,
#    'birth_years': [1830],
#    'death_years': [1826]}),
#  ('lraq',
#   {'POS': 'ADP',
#    'max_usage': 1439.2,
#    'median_all': 0.0,
#    'median_in_use': 53.0,
#    'mean_all': 71.41666666666667,
#    'mean_in_use': 214.25,
#    'birth_years': [1945],
#    'death_years': [2016]}),
#  ('providing',
#   {'POS': 'ADP',
#    'max_usage': 1388.8,
#    'median_all': 286.8,
#    'median_in_use': 289.1,
#    'mean_all': 346.93981481481484,
#    'mean_in_use': 350.18224299065423,
#    'birth_years': [1809],
#    'death_years': [1806]}),
#  ('thankyou',
#   {'POS': 'PRON',
#    'max_usage': 1308.4,
#    'median_all': 12.3,
#    'median_in_use': 12.600000000000001,
#    'mean_all': 112.21944444444445,
#    'mean_in_use': 113.26822429906542,
#    'birth_years': [1831],
#    'death_years': [1828]}),
#  ('varus',
#   {'POS': 'ADP',
#    'max_usage': 1189.4,
#    'median_all': 35.3,
#    'median_in_use': 41.2,
#    'mean_all': 139.6898148148148,
#    'mean_in_use': 153.16243654822335,
#    'birth_years': [1828],
#    'death_years': [1808]}),
#  ('aq',
#   {'POS': 'ADP',
#    'max_usage': 1187.8,
#    'median_all': 6.8,
#    'median_in_use': 6.8,
#    'mean_all': 73.10462962962963,
#    'mean_in_use': 73.78785046728972,
#    'birth_years': [1837],
#    'death_years': [1834]}),
#  ('besonderer',
#   {'POS': 'ADP',
#    'max_usage': 1141.4,
#    'median_all': 397.1,
#    'median_in_use': 447.2,
#    'mean_all': 418.39074074074074,
#    'mean_in_use': 449.6139303482587,
#    'birth_years': [1822],
#    'death_years': [1806]}),
#  ('ofengland',
#   {'POS': 'CONJ',
#    'max_usage': 1086.0,
#    'median_all': 19.1,
#    'median_in_use': 19.2,
#    'mean_all': 56.76759259259259,
#    'mean_in_use': 57.031627906976745,
#    'birth_years': [1943],
#    'death_years': [1941]}),
#  ('whereafter',
#   {'POS': 'ADP',
#    'max_usage': 946.2,
#    'median_all': 87.3,
#    'median_in_use': 89.8,
#    'mean_all': 226.25,
#    'mean_in_use': 227.30232558139534,
#    'birth_years': [1830],
#    'death_years': [1828]}),
#  ('trout',
#   {'POS': 'PRT',
#    'max_usage': 910.8,
#    'median_all': 196.3,
#    'median_in_use': 196.6,
#    'mean_all': 272.3361111111111,
#    'mean_in_use': 273.60279069767444,
#    'birth_years': [1805],
#    'death_years': [1803]}),
#  ('abscissa',
#   {'POS': 'DET',
#    'max_usage': 899.6,
#    'median_all': 208.5,
#    'median_in_use': 215.0,
#    'mean_all': 262.93888888888887,
#    'mean_in_use': 264.16186046511626,
#    'birth_years': [1807],
#    'death_years': [1805]}),
#  ('theologia',
#   {'POS': 'DET',
#    'max_usage': 883.0,
#    'median_all': 40.400000000000006,
#    'median_in_use': 40.6,
#    'mean_all': 120.52222222222223,
#    'mean_in_use': 121.64859813084112,
#    'birth_years': [1806],
#    'death_years': [1803]}),
#  ('occult',
#   {'POS': 'ADP',
#    'max_usage': 863.8,
#    'median_all': 39.7,
#    'median_in_use': 40.7,
#    'mean_all': 126.70277777777778,
#    'mean_in_use': 129.09339622641508,
#    'birth_years': [1815],
#    'death_years': [1810]}),
#  ('angina',
#   {'POS': 'DET',
#    'max_usage': 857.6,
#    'median_all': 69.30000000000001,
#    'median_in_use': 69.4,
#    'mean_all': 185.675,
#    'mean_in_use': 186.53860465116279,
#    'birth_years': [1809],
#    'death_years': [1807]}),
#  ('backgammon',
#   {'POS': 'PRT',
#    'max_usage': 855.8,
#    'median_all': 72.30000000000001,
#    'median_in_use': 73.1,
#    'mean_all': 132.8074074074074,
#    'mean_in_use': 135.3132075471698,
#    'birth_years': [1810],
#    'death_years': [1805]}),
#  ('annexa',
#   {'POS': 'DET',
#    'max_usage': 829.6,
#    'median_all': 21.9,
#    'median_in_use': 22.2,
#    'mean_all': 94.55925925925926,
#    'mean_in_use': 94.99906976744187,
#    'birth_years': [1805],
#    'death_years': [1803]}),
#  ('annulata',
#   {'POS': 'DET',
#    'max_usage': 771.2,
#    'median_all': 179.1,
#    'median_in_use': 180.0,
#    'mean_all': 203.60555555555555,
#    'mean_in_use': 204.55255813953488,
#    'birth_years': [1806],
#    'death_years': [1804]}),
#  ('inclusive',
#   {'POS': 'ADP',
#    'max_usage': 755.6,
#    'median_all': 209.6,
#    'median_in_use': 211.0,
#    'mean_all': 212.46296296296296,
#    'mean_in_use': 214.44859813084113,
#    'birth_years': [1808],
#    'death_years': [1805]}),
#  ('benzazepin',
#   {'POS': 'ADP',
#    'max_usage': 744.2,
#    'median_all': 0.0,
#    'median_in_use': 269.8,
#    'mean_all': 17.96759259259259,
#    'mean_in_use': 352.8181818181818,
#    'birth_years': [1983],
#    'death_years': [1993]}),
#  ('chrome',
#   {'POS': 'DET',
#    'max_usage': 739.2,
#    'median_all': 375.70000000000005,
#    'median_in_use': 414.8,
#    'mean_all': 327.3009259259259,
#    'mean_in_use': 351.72636815920396,
#    'birth_years': [1820],
#    'death_years': [1804]}),
#  ('lfthe',
#   {'POS': 'DET',
#    'max_usage': 735.2,
#    'median_all': 18.1,
#    'median_in_use': 18.4,
#    'mean_all': 65.97314814814816,
#    'mean_in_use': 66.28,
#    'birth_years': [1929],
#    'death_years': [1927]}),
#  ('talus',
#   {'POS': 'ADP',
#    'max_usage': 719.8,
#    'median_all': 152.8,
#    'median_in_use': 152.8,
#    'mean_all': 224.65,
#    'mean_in_use': 225.69488372093022,
#    'birth_years': [1827],
#    'death_years': [1825]}),
#  ('irself',
#   {'POS': 'PRON',
#    'max_usage': 705.6,
#    'median_all': 7.0,
#    'median_in_use': 7.0,
#    'mean_all': 34.18333333333333,
#    'mean_in_use': 34.34232558139535,
#    'birth_years': [1829],
#    'death_years': [1827]}),
#  ('befote',
#   {'POS': 'ADP',
#    'max_usage': 694.6,
#    'median_all': 11.2,
#    'median_in_use': 11.2,
#    'mean_all': 36.07314814814815,
#    'mean_in_use': 36.24093023255814,
#    'birth_years': [],
#    'death_years': [2016]}),
#  ('liefore',
#   {'POS': 'ADP',
#    'max_usage': 683.8,
#    'median_all': 89.8,
#    'median_in_use': 90.0,
#    'mean_all': 141.40185185185186,
#    'mean_in_use': 142.7233644859813,
#    'birth_years': [],
#    'death_years': [2015]}),
#  ('sie',
#   {'POS': 'ADP',
#    'max_usage': 676.6,
#    'median_all': 17.6,
#    'median_in_use': 17.6,
#    'mean_all': 43.93055555555556,
#    'mean_in_use': 44.97156398104266,
#    'birth_years': [1811],
#    'death_years': [1805]}),
#  ('lietween',
#   {'POS': 'ADP',
#    'max_usage': 644.8,
#    'median_all': 70.0,
#    'median_in_use': 70.4,
#    'mean_all': 106.01574074074074,
#    'mean_in_use': 106.50883720930233,
#    'birth_years': [],
#    'death_years': [2016]}),
#  ('ireat',
#   {'POS': 'ADP',
#    'max_usage': 637.8,
#    'median_all': 71.5,
#    'median_in_use': 71.6,
#    'mean_all': 116.61759259259259,
#    'mean_in_use': 117.16,
#    'birth_years': [],
#    'death_years': [2016]}),
#  ('ofsin',
#   {'POS': 'ADP',
#    'max_usage': 636.0,
#    'median_all': 9.7,
#    'median_in_use': 9.9,
#    'mean_all': 31.35185185185185,
#    'mean_in_use': 31.64485981308411,
#    'birth_years': [1944],
#    'death_years': [1941]}),
#  ('nspf',
#   {'POS': 'ADP',
#    'max_usage': 635.8,
#    'median_all': 0.0,
#    'median_in_use': 107.4,
#    'mean_all': 53.81944444444444,
#    'mean_in_use': 145.3125,
#    'birth_years': [1928],
#    'death_years': [2007]}),
#  ('weave',
#   {'POS': 'PRON',
#    'max_usage': 635.8,
#    'median_all': 168.2,
#    'median_in_use': 172.1,
#    'mean_all': 180.96666666666667,
#    'mean_in_use': 182.65794392523364,
#    'birth_years': [1809],
#    'death_years': [1806]}),
#  ('androgynous',
#   {'POS': 'CONJ',
#    'max_usage': 618.0,
#    'median_all': 25.5,
#    'median_in_use': 25.6,
#    'mean_all': 111.93981481481481,
#    'mean_in_use': 112.46046511627907,
#    'birth_years': [1814],
#    'death_years': [1812]}),
#  ('itit',
#   {'POS': 'PRON',
#    'max_usage': 617.8,
#    'median_all': 8.4,
#    'median_in_use': 8.8,
#    'mean_all': 24.475925925925925,
#    'mean_in_use': 25.295693779904305,
#    'birth_years': [1847],
#    'death_years': [1839]}),
#  ('plumosus',
#   {'POS': 'CONJ',
#    'max_usage': 598.6,
#    'median_all': 121.1,
#    'median_in_use': 134.9,
#    'mean_all': 146.1648148148148,
#    'mean_in_use': 154.7627450980392,
#    'birth_years': [1824],
#    'death_years': [1811]}),
#  ('sooo',
#   {'POS': 'DET',
#    'max_usage': 584.0,
#    'median_all': 32.2,
#    'median_in_use': 32.6,
#    'mean_all': 66.5925925925926,
#    'mean_in_use': 66.90232558139535,
#    'birth_years': [1837],
#    'death_years': [1835]}),
#  ('thot',
#   {'POS': 'PRON',
#    'max_usage': 584.0,
#    'median_all': 60.4,
#    'median_in_use': 61.0,
#    'mean_all': 105.17129629629629,
#    'mean_in_use': 105.66046511627907,
#    'birth_years': [1806],
#    'death_years': [1804]}),
#  ('tiptoe',
#   {'POS': 'PRON',
#    'max_usage': 553.6,
#    'median_all': 30.0,
#    'median_in_use': 30.6,
#    'mean_all': 60.45925925925926,
#    'mean_in_use': 61.89194312796209,
#    'birth_years': [1812],
#    'death_years': [1806]}),
#  ('of',
#   {'POS': 'PRT',
#    'max_usage': 545.2,
#    'median_all': 110.0,
#    'median_in_use': 112.8,
#    'mean_all': 126.55555555555556,
#    'mean_in_use': 127.14418604651163,
#    'birth_years': [1806],
#    'death_years': [1804]}),
#  ('bora',
#   {'POS': 'DET',
#    'max_usage': 540.4,
#    'median_all': 7.8,
#    'median_in_use': 8.0,
#    'mean_all': 34.4,
#    'mean_in_use': 34.88450704225352,
#    'birth_years': [1808],
#    'death_years': [1804]})]

# %%
save_json(top_single_death_all,'','Single Death Lexemes')
save_csv(top_single_death_all,'','Single Death Lexemes')
# Out:
# SAVED:  Single Death Lexemes.json 988
# SAVED:  Single Death Lexemes.csv 988
